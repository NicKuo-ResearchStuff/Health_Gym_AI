# %% [markdown]
# ---
# **Copyright (c) 2025. Nicholas Kuo, UNSW**
# All rights reserved.
#
# This file forms part of the *Health Gym* and is released under the terms of the
# MIT Licence Agreement.
#
# This is an updated version (dated 23 September 2025) of the original code,
# available at:
# [https://github.com/Nic5472K/ScientificData2021_HealthGym](https://github.com/Nic5472K/ScientificData2021_HealthGym)
#
# The original implementation accompanied the publication:
# > *The Health Gym: synthetic clinical data for the development of reinforcement learning algorithms for healthcare*
# > *Scientific Data (Nature), 2022.*
# > DOI: [10.1038/s41597-022-01784-7](https://doi.org/10.1038/s41597-022-01784-7)
# ---

# %%
# ========================
# Standard Library
# ========================
import os
import random
import itertools
from copy import deepcopy
from collections import defaultdict
from typing import Dict, List, Tuple, Optional

# ========================
# Core Scientific Stack
# ========================
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype
from scipy import stats
from scipy.special import boxcox as sp_boxcox

# ========================
# Machine Learning Utilities
# ========================
from sklearn.model_selection import train_test_split

# ========================
# Deep Learning (PyTorch)
# ========================
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch import autograd
from torch.utils.data import DataLoader, TensorDataset

# ========================
# Visualization
# ========================
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def seed_all(seed: int = 42, deterministic: bool = True) -> None:
    import os, random, numpy as np, torch

    # Python built-ins
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # NumPy
    np.random.seed(seed)

    # PyTorch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    # cuDNN settings
    torch.backends.cudnn.deterministic = deterministic
    torch.backends.cudnn.benchmark = not deterministic

    if torch.cuda.is_available():
        torch.backends.cuda.matmul.allow_tf32 = False
        torch.backends.cudnn.allow_tf32 = False

# %%
seed_all()

# === Categorical Mapping Utilities (simple & tidy) ===
BINCAT_STR2INT = {
    "Gender": {"Male": 0, "Female": 1},
    "Ethnic": {"Asian": 0, "African": 1, "Caucasian": 2, "Other": 3},
    "Base Drug Combo": {
        "FTC + TDF": 0, "3TC + ABC": 1, "FTC + TAF": 2,
        "DRV + FTC + TDF": 3, "FTC + RTVB + TDF": 4, "Other": 5
    },
    "Extra PI": {"DRV": 0, "RTVB": 1, "LPV": 2, "RTV": 3, "ATV": 4, "Not Applied": 5},
    "Extra pk-En": {"False": 0, "True": 1},   # ← fixed typo
}

BINCAT_INT2STR = {
    "Gender": {0: "Male", 1: "Female"},
    "Ethnic": {0: "Asian", 1: "African", 2: "Caucasian", 3: "Other"},
    "Base Drug Combo": {
        0: "FTC + TDF", 1: "3TC + ABC", 2: "FTC + TAF",
        3: "DRV + FTC + TDF", 4: "FTC + RTVB + TDF", 5: "Other"
    },
    "Extra PI": {0: "DRV", 1: "RTVB", 2: "LPV", 3: "RTV", 4: "ATV", 5: "Not Applied"},
    "Extra pk-En": {0: "False", 1: "True"},   # ← fixed typo
}

def BinCat2Num(df: pd.DataFrame, allow_already_int: bool = True) -> pd.DataFrame:
    """
    Map categorical string columns → integer codes (0..K-1).
    If allow_already_int=True, columns already coded as ints in the valid range are left as-is.
    """
    out = df.copy()
    for col, mapping in BINCAT_STR2INT.items():
        if col not in out.columns:
            continue
        s = out[col]
        if allow_already_int and pd.api.types.is_integer_dtype(s):
            # Validate codes are within allowed range
            allowed = set(mapping.values())
            bad = set(pd.Series(s.dropna().unique(), dtype=int)) - allowed
            if bad:
                raise ValueError(f"Unexpected integer codes in '{col}': {sorted(bad)}")
            continue
        mapped = s.map(mapping)
        if mapped.isnull().any():
            bad_vals = s[mapped.isnull()].unique()
            raise ValueError(f"Unmapped values in column '{col}': {bad_vals}")
        out[col] = mapped.astype(int)
    return out

def BinCat2Str(df: pd.DataFrame) -> pd.DataFrame:
    """Map categorical integer codes → string labels."""
    out = df.copy()
    for col, mapping in BINCAT_INT2STR.items():
        if col in out.columns:
            out[col] = out[col].map(mapping)
    return out

# %%
seed_all()

# ========================
# Fit Box–Cox parameters
# ========================
def compute_boxcox_params(
    df: pd.DataFrame,
    columns: List[str] = ("VL", "CD4"),
    eps: float = 1e-3,
) -> Dict[str, dict]:
    """
    Fit Box–Cox λ per column on (x + eps), and store min/range of the
    transformed values for later [0,1] scaling.
    """
    params: Dict[str, dict] = {}
    for col in columns:
        x = df[col].dropna().astype(float).to_numpy()
        x = x + eps  # ensure positivity

        # Handle empty/degenerate columns safely
        if x.size == 0 or not np.all(np.isfinite(x)) or np.min(x) <= 0 or np.ptp(x) == 0:
            params[col] = {"lambda": 1.0, "min": 0.0, "range": 1.0, "eps": eps}
            continue

        bc, lam = stats.boxcox(x)  # returns transformed values + MLE λ
        bc_min = float(np.min(bc))
        bc_rng = float(np.max(bc) - bc_min) or 1.0  # avoid zero range

        params[col] = {"lambda": float(lam), "min": bc_min, "range": bc_rng, "eps": eps}
    return params


# ========================
# Box–Cox + Min–Max → [0,1]
# ========================
def apply_boxcox_minmax_transform(
    df: pd.DataFrame,
    params: Dict[str, dict],
    columns: List[str] = ("VL", "CD4"),
) -> pd.DataFrame:
    """
    Apply Box–Cox with fitted λ, then scale to [0,1] via stored min/range.
    NaNs are preserved.
    """
    out = df.copy()
    for col in columns:
        if col not in out.columns:
            continue
        p = params[col]
        mask = out[col].notna().to_numpy()
        if not mask.any():
            continue

        x = out.loc[mask, col].astype(float).to_numpy() + p["eps"]
        bc = sp_boxcox(x, p["lambda"])  # fixed-λ forward transform
        scaled = (bc - p["min"]) / p["range"]
        out.loc[mask, col] = scaled
    return out


# ========================
# Inverse Box–Cox (Torch)
# ========================
def inverse_boxcox_torch(bc: torch.Tensor, lmbda: float, eps: float = 1e-3) -> torch.Tensor:
    """
    Invert Box–Cox (on Box–Coxed values) to original x (minus eps shift).
    """
    if lmbda == 0.0:
        return torch.exp(bc) - eps
    base = torch.clamp(lmbda * bc + 1.0, min=1e-12)  # numeric safety
    return torch.pow(base, 1.0 / lmbda) - eps


# ========================
# Back-transform features
# ========================
def backtransform_art_tensor(
    tensor: torch.Tensor,
    feature_names: List[str],
    transform_params: Dict[str, dict],
    real_columns: List[str] = ("VL", "CD4"),
) -> pd.DataFrame:
    """
    Expects `tensor` with real cols in scaled Box–Cox space ([0,1]).
    Steps: unscale to Box–Cox → inverse Box–Cox → subtract eps.
    """
    x = tensor.detach().clone()
    idx_map = {n: i for i, n in enumerate(feature_names)}

    for col in real_columns:
        if col not in idx_map:
            continue
        i = idx_map[col]
        p = transform_params[col]
        bc = x[:, i] * p["range"] + p["min"]
        x[:, i] = inverse_boxcox_torch(bc, p["lambda"], p["eps"])

    return pd.DataFrame(x.cpu().numpy(), columns=feature_names)

# %%
seed_all()

# === Load and Preprocess Raw Data ===
raw_url = "https://figshare.com/ndownloader/files/40584980"
DROP_COLS = ["VL (M)", "CD4 (M)", "Drug (M)"]

# 1) Read only the columns we need
_all_cols = pd.read_csv(raw_url, nrows=0).columns.tolist()
usecols = [c for c in _all_cols if c not in DROP_COLS]
All_Data = pd.read_csv(raw_url, usecols=usecols)

# 2) Map numeric codes -> human-readable labels (with typo fixed)
NUM2STR = {
    "Gender":          {1: "Male", 2: "Female"},
    "Ethnic":          {1: "Asian", 2: "African", 3: "Caucasian", 4: "Other"},
    "Base Drug Combo": {
        0: "FTC + TDF", 1: "3TC + ABC", 2: "FTC + TAF",
        3: "DRV + FTC + TDF", 4: "FTC + RTVB + TDF", 5: "Other"
    },
    "Comp. INI":       {0: "DTG", 1: "RAL", 2: "EVG", 3: "Not Applied"},
    "Comp. NNRTI":     {0: "NVP", 1: "EFV", 2: "RPV", 3: "Not Applied"},
    "Extra PI":        {0: "DRV", 1: "RTVB", 2: "LPV", 3: "RTV", 4: "ATV", 5: "Not Applied"},
    "Extra pk-En":     {0: "False", 1: "True"},   # <-- fixed typo
}

for col, mapping in NUM2STR.items():
    if col in All_Data.columns:
        mapped = All_Data[col].map(mapping)
        if mapped.isnull().any():
            bad = All_Data.loc[mapped.isnull(), col].unique()
            raise ValueError(f"Unmapped codes in '{col}': {bad}")
        All_Data[col] = mapped.astype("category")

for cont in ("VL", "CD4"):
    if cont in All_Data.columns:
        All_Data[cont] = pd.to_numeric(All_Data[cont], errors="coerce")

# %%
seed_all()

# === Create smaller demo dataset for collaborators ===
SEL_COLS = [
    "VL", "CD4", "Gender", "Ethnic", "Base Drug Combo",
    "Extra PI", "Extra pk-En", "PatientID", "Timestep"
]

# Filter by PatientID, select only wanted columns, reset index
Sub_Data = (
    All_Data.loc[All_Data["PatientID"] < 300, SEL_COLS]
            .reset_index(drop=True)
)

missing = set(SEL_COLS) - set(All_Data.columns)
if missing:
    raise KeyError(f"Missing expected columns in All_Data: {missing}")

# %%
seed_all()
# --- Canonical column names for downstream ---
REAL_COLS = ["VL", "CD4"]
CAT_SIZES = {
    "Gender": 2,
    "Ethnic": 4,
    "Base_Drug_Combo": 6,
    "Extra_PI": 6,
    "Extra_pk_En": 2,
}

# Embedding sizes policy
EMB_SIZE_FOR = {
    "real": lambda k: 1,     # passthrough
    "bin":  lambda k: 2,     # small embedding for binary
    "cat":  lambda k: 4,     # fixed 4-dim for multiclass
}

def build_dtype(real_cols, cat_sizes, emb_policy=EMB_SIZE_FOR, start_idx=0):
    rows = []
    idx = start_idx
    i = 0

    # Reals
    for name in real_cols:
        k = 1
        emb = emb_policy["real"](k)
        rows.append([i, name, "real", k, emb, idx, idx + k])
        idx += k; i += 1

    # Categorical (emit num_classes one-hot dims)
    for name, k in cat_sizes.items():
        ftype = "bin" if k == 2 else "cat"
        emb = emb_policy[ftype](k)
        rows.append([i, name, ftype, k, emb, idx, idx + k])
        idx += k; i += 1

    dtype = pd.DataFrame(rows, columns=[
        "index", "name", "type", "num_classes",
        "embedding_size", "index_start", "index_end"
    ])
    return dtype

def validate_dtype(dtype: pd.DataFrame, expected_total=None):
    d = dtype.sort_values("index").reset_index(drop=True)
    # contiguous spans
    starts = d["index_start"].to_numpy()
    ends   = d["index_end"].to_numpy()
    assert np.all(starts[1:] == ends[:-1]), "Spans must be contiguous"
    # monotonic & positive widths
    assert np.all(ends > starts), "Each span must have positive width"
    # total width
    total = int(ends[-1])
    if expected_total is not None:
        assert total == expected_total, f"Total dims {total} != expected {expected_total}"
    return total

def expand_feature_names(dtype: pd.DataFrame):
    names = []
    for _, r in dtype.iterrows():
        if r["type"] == "real":
            names.append(r["name"])
        else:
            k = int(r["num_classes"])
            names.extend([f"{r['name']}_{j}" for j in range(k)])
    return names

# ---- Building schema ----
dtype = build_dtype(REAL_COLS, CAT_SIZES)
TOTAL_DIM = validate_dtype(dtype)
FEATURE_NAMES = expand_feature_names(dtype)
assert len(FEATURE_NAMES) == TOTAL_DIM

# %%
dtype
# Out:
#    index             name  type  num_classes  embedding_size  index_start  \
# 0      0               VL  real            1               1            0
# 1      1              CD4  real            1               1            1
# 2      2           Gender   bin            2               2            2
# 3      3           Ethnic   cat            4               4            4
# 4      4  Base_Drug_Combo   cat            6               4            8
# 5      5         Extra_PI   cat            6               4           14
# 6      6      Extra_pk_En   bin            2               2           20
#
#    index_end
# 0          1
# 1          2
# 2          4
# 3          8
# 4         14
# 5         20
# 6         22

# %%
seed_all()

from typing import Tuple, Optional
def Execute_C003(
    df: pd.DataFrame,
    batch_size: int,
    cur_len: int = 10,
    drop_incomplete: bool = True,
    num_workers: int = 0,
    pin_memory: bool = False,
    generator: Optional[torch.Generator] = None,
) -> Tuple[DataLoader, torch.Tensor]:
    x_np = df.to_numpy(dtype=np.float32, copy=False)
    n_rows, feats_len = x_np.shape

    if n_rows < cur_len:
        raise ValueError(f"Not enough rows ({n_rows}) for a sequence of length {cur_len}.")

    remainder = n_rows % cur_len
    if remainder != 0:
        if drop_incomplete:
            n_rows = n_rows - remainder
            x_np = x_np[:n_rows]
        else:
            raise ValueError(f"{n_rows} rows not divisible by cur_len={cur_len}.")

    n_seq = n_rows // cur_len
    x_np = x_np.reshape(n_seq, cur_len, feats_len)

    x_t = torch.from_numpy(x_np)  # [n_seq, cur_len, feats]
    lengths = torch.full((n_seq,), cur_len, dtype=torch.long)
    dataset = TensorDataset(x_t, lengths)

    trn_loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        drop_last=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        generator=generator,
    )

    all_batches = [xb for xb, _ in trn_loader]
    all_trainable = torch.cat(all_batches, dim=0)

    return trn_loader, all_trainable

# %%
seed_all()

# 1) Map categoricals to ints using your simple mapper (expects spaced names)
Sub_Data = BinCat2Num(Sub_Data)

# 2) Rename once so columns match your dtype/schema (snake_case)
NAME_MAP = {
    "Base Drug Combo": "Base_Drug_Combo",
    "Extra PI":        "Extra_PI",
    "Extra pk-En":     "Extra_pk_En",
}
Sub_Data = Sub_Data.rename(columns=NAME_MAP)

# 3) Fit Box–Cox params on real columns
REAL_COLS = [r["name"] for _, r in dtype.query("type == 'real'").iterrows()]
art_transformation_params = compute_boxcox_params(Sub_Data, columns=REAL_COLS)

# 4) Helpers to expand dtype → feature names (reals + one-hot blocks)
def expand_feature_names_from_dtype(dtype_df: pd.DataFrame):
    names = []
    for _, r in dtype_df.iterrows():
        if r["type"] == "real":
            names.append(r["name"])
        else:
            names += [f"{r['name']}_{j}" for j in range(int(r["num_classes"]))]
    return names

FEATURE_NAMES = expand_feature_names_from_dtype(dtype)

def design_from_dtype(df: pd.DataFrame, dtype_df: pd.DataFrame, params: dict) -> pd.DataFrame:
    real_cols = [r["name"] for _, r in dtype_df.query("type == 'real'").iterrows()]
    cat_blocks = [(r["name"], int(r["num_classes"])) for _, r in dtype_df.query("type != 'real'").iterrows()]

    # sanity: required columns
    required = set(real_cols + [n for n, _ in cat_blocks])
    missing = required - set(df.columns)
    if missing:
        raise KeyError(f"Missing required columns for design matrix: {sorted(missing)}")

    # Reals → Box–Cox + [0,1]
    X_real = apply_boxcox_minmax_transform(df[real_cols].copy(), params, columns=real_cols)

    # Categoricals → stable one-hot (0..K-1)
    X_cat_parts = []
    for name, k in cat_blocks:
        s = df[name].astype("Int64")
        s = pd.Categorical(s, categories=list(range(k)))
        dmy = pd.get_dummies(s, prefix=name, prefix_sep="_", dtype=np.int8)
        needed = [f"{name}_{j}" for j in range(k)]
        for c in needed:
            if c not in dmy.columns:
                dmy[c] = 0
        X_cat_parts.append(dmy[needed])

    X_cat = pd.concat(X_cat_parts, axis=1) if X_cat_parts else pd.DataFrame(index=df.index)
    X = pd.concat([X_real, X_cat], axis=1).reindex(columns=FEATURE_NAMES, fill_value=0)
    return X

# 5) Build curriculum loaders
CURRICULUM_LENGTHS = [10, 20, 30, 40, 50, 60]
BATCH_SIZE = 256

def slice_by_len(df: pd.DataFrame, L: int) -> pd.DataFrame:
    if "Timestep" not in df.columns:
        raise KeyError("Expected 'Timestep' column in input dataframe.")
    return df.loc[df["Timestep"] < L].reset_index(drop=True)

g = torch.Generator().manual_seed(42)  # reproducible shuffles

only10_60 = {}
for L in CURRICULUM_LENGTHS:
    dfL = slice_by_len(Sub_Data, L)
    XL = design_from_dtype(dfL, dtype, art_transformation_params)
    loader_L, _ = Execute_C003(XL, batch_size=BATCH_SIZE, cur_len=L, drop_incomplete=True, generator=g)
    only10_60[L] = loader_L

# 6) Pool for correlation/eval with longest length
X_all = design_from_dtype(Sub_Data, dtype, art_transformation_params)
_, All_Trainable_Data = Execute_C003(X_all, batch_size=BATCH_SIZE, cur_len=60, drop_incomplete=True, generator=g)

# %%
seed_all()

def correlation(x: torch.Tensor, eps: float = 1e-8) -> torch.Tensor:

    # Flatten samples, keep features
    f = x.shape[-1]
    x = x.reshape(-1, f).to(dtype=torch.float32)

    n = x.shape[0]
    if n < 2:
        return torch.eye(f, dtype=x.dtype, device=x.device)

    # Center
    x = x - x.mean(dim=0, keepdim=True)

    # Standardize with sample std (unbiased=True)
    std = x.std(dim=0, unbiased=True)
    # Avoid div-by-zero for constant columns
    std = torch.where(std < eps, torch.ones_like(std), std)
    x = x / std

    # Pearson correlation = (X^T X) / (n - 1)
    corr = (x.transpose(0, 1) @ x) / (n - 1)

    # Clamp tiny numerical drift, enforce diag = 1
    corr = corr.clamp(min=-1.0, max=1.0)
    corr.fill_diagonal_(1.0)
    return corr

correlation_real = correlation(All_Trainable_Data)

# %%
seed_all()

class MyLSTM(nn.Module):
    def __init__(self, ID, HD):
        super().__init__()
        self.ID = ID
        self.HD = HD
        self.i2h = nn.Linear(ID, HD * 4)
        self.h2h = nn.Linear(HD, HD * 4)

    def forward(self, x0):
        Q_k = torch.zeros(x0.shape[0], self.HD, device=x0.device)
        S_k = torch.zeros(x0.shape[0], self.HD, device=x0.device)
        Q_all = []
        for t in range(x0.shape[1]):
            X_k = x0[:, t, :]
            F_i, I_i, A_i, O_i = self.i2h(X_k).chunk(4, dim=1)
            F_h, I_h, A_h, O_h = self.h2h(Q_k).chunk(4, dim=1)
            F_k = torch.sigmoid(F_i + F_h)
            I_k = torch.sigmoid(I_i + I_h)
            A_k = torch.tanh(A_i + A_h)
            O_k = torch.sigmoid(O_i + O_h)
            S_k = F_k * S_k + I_k * A_k
            Q_k = O_k * torch.tanh(S_k)
            Q_all.append(Q_k.unsqueeze(1))
        Q_all = torch.cat(Q_all, dim=1)
        return Q_all, (Q_k, S_k)


class Generator(nn.Module):
    def __init__(self, Hyper006_ID, Hyper007_HD, data_types):
        super().__init__()
        ID, HD = Hyper006_ID, Hyper007_HD
        self.rnn_f = MyLSTM(ID, HD)
        self.rnn_r = MyLSTM(ID, HD)
        self.linear1 = nn.Linear(2 * HD, HD)
        self.linear2 = nn.Linear(HD, HD)
        self.linear3 = nn.Linear(HD, max(data_types["index_end"]))
        self.leakyReLU = nn.LeakyReLU(0.1)
        self.output_activations = []
        max_real = max(data_types.loc[data_types["type"] == "real", "index_end"])
        self.output_activations.append(lambda x: torch.sigmoid(x[..., 0:max_real]))
        for _, row in data_types.iterrows():
            if row["type"] != "real":
                idxs, idxe = row["index_start"], row["index_end"]
                self.output_activations.append(
                    lambda x, idxs=idxs, idxe=idxe: torch.softmax(x[..., idxs:idxe], dim=-1)
                )

    def forward(self, x0):
        x1_f, _ = self.rnn_f(x0)
        x1_r, _ = self.rnn_r(x0.flip(dims=[1]))
        x1 = torch.cat((x1_f, x1_r), dim=2)
        x2 = self.leakyReLU(self.linear1(x1))
        x3 = self.leakyReLU(self.linear2(x2))
        x4 = self.linear3(x3)
        x_list = [f(x4) for f in self.output_activations]
        return torch.cat(x_list, dim=-1)


class Discriminator(nn.Module):
    def __init__(self, Hyper007_HD, data_types):
        super().__init__()
        HD, OD = Hyper007_HD, 1
        self.max_real = max(data_types.loc[data_types["type"] == "real", "index_end"])
        self.embedding_layers = nn.ModuleList()
        self.soft_embedding = []
        for _, row in data_types.iterrows():
            if row["type"] != "real":
                self.embedding_layers.append(nn.Embedding(row["num_classes"], row["embedding_size"]))
                idxs, idxe = row["index_start"], row["index_end"]
                self.soft_embedding.append(
                    lambda x, W, idxs=idxs, idxe=idxe: x[..., idxs:idxe] @ W
                )
        self.linear1 = nn.Linear(sum(data_types["embedding_size"]), HD)
        self.linear2 = nn.Linear(HD, HD)
        self.rnn_f = MyLSTM(HD, HD)
        self.rnn_r = MyLSTM(HD, HD)
        self.linear3 = nn.Linear(2 * HD, OD)
        self.leakyReLU = nn.LeakyReLU(0.1)

    def forward(self, x0):
        x_list = [x0[..., :self.max_real]] + [
            f(x0, emb.weight) for f, emb in zip(self.soft_embedding, self.embedding_layers)
        ]
        x1 = torch.cat(x_list, dim=-1)
        x2 = self.leakyReLU(self.linear1(x1))
        x3 = self.leakyReLU(self.linear2(x2))
        _, (x4_f, _) = self.rnn_f(x3)
        _, (x4_r, _) = self.rnn_r(x3.flip(dims=[1]))
        x4 = torch.cat((x4_f, x4_r), dim=1)
        return self.linear3(x4)

# %%
seed_all()

def LoadPreTrain(content=[False, 'G_SD', 'D_SD', 0]):
    if content[0]:
        G_SD = torch.load(content[1])
        D_SD = torch.load(content[2])
        return G_SD, D_SD
    return 0, 0


class Execute_D004:
    def __init__(self,
                 Hyper001_BatchSize, Hyper002_Epochs,
                 Hyper003_G_iter, Hyper004_GP_Lambda, Hyper005_C_Lambda,
                 Hyper006_ID, Hyper007_HD,
                 Hyper008_LR, Hyper009_Betas,
                 data_types,
                 correlation_real,
                 continue_info=[False, 'G_SD', 'D_SD', 0]):
        super().__init__()
        self.batch_size = Hyper001_BatchSize
        self.epochs = Hyper002_Epochs
        self.G_iter = Hyper003_G_iter
        self.gp_weight = Hyper004_GP_Lambda
        self.c_weight = Hyper005_C_Lambda
        self.ID = Hyper006_ID
        self.HD = Hyper007_HD
        self.lr = Hyper008_LR
        self.betas = Hyper009_Betas
        self.correlation_real = correlation_real.cuda()
        self.CUDA = torch.cuda.is_available()
        self.G = Generator(Hyper006_ID, Hyper007_HD, data_types)
        self.D = Discriminator(Hyper007_HD, data_types)
        if self.CUDA:
            self.G = self.G.cuda()
            self.D = self.D.cuda()
        G_SD, D_SD = LoadPreTrain(continue_info)
        if G_SD != 0:
            self.G.load_state_dict(G_SD)
            self.D.load_state_dict(D_SD)
            self.PreviousEpoch = continue_info[3]
        else:
            self.PreviousEpoch = 0
        self.D_opt = optim.Adam(self.D.parameters(), lr=self.lr, betas=self.betas)
        self.G_opt = optim.Adam(self.G.parameters(), lr=self.lr, betas=self.betas)

    def generate_data(self, seq_len, num_samples=None):
        if num_samples is None:
            num_samples = self.batch_size
        z = torch.rand((num_samples, seq_len, self.ID)).cuda()
        return self.G(z)

    def _critic_train_iteration(self, data_real):
        data_fake = self.generate_data(data_real.shape[1], data_real.shape[0])
        D_real = self.D(data_real)
        D_fake = self.D(data_fake)
        with torch.backends.cudnn.flags(enabled=False):
            gradient_penalty = self._gradient_penalty(data_real, data_fake)
        self.D_opt.zero_grad()
        D_loss = D_fake.mean() - D_real.mean() + gradient_penalty
        D_loss.backward()
        self.D_opt.step()
        return D_loss.item(), gradient_penalty.item(), D_real.mean().item(), D_fake.mean().item()

    def _generator_train_iteration(self, seq_len):
        data_fake = self.generate_data(seq_len)
        D_fake = self.D(data_fake)
        corr_loss = self._correlation_loss(data_fake)
        self.G_opt.zero_grad()
        G_loss = -D_fake.mean() + self.c_weight * corr_loss
        G_loss.backward()
        self.G_opt.step()
        return G_loss.item(), corr_loss.item()

    def _correlation_loss(self, data_fake):
        correlation_fake = correlation(data_fake)
        criterion = nn.L1Loss(reduction="mean")
        temp = torch.rand_like(correlation_fake)
        temp_fake = torch.min(temp, torch.abs(correlation_fake))
        temp_real = torch.min(temp, torch.abs(self.correlation_real))
        correlation_fake = temp_fake * torch.sign(correlation_fake)
        correlation_real = temp_real * torch.sign(self.correlation_real)
        return criterion(correlation_fake, correlation_real)

    def _gradient_penalty(self, data_real, data_fake):
        alpha = torch.rand((self.batch_size, 1, 1)).cuda().expand_as(data_real)
        interpolated = alpha * data_real + (1 - alpha) * data_fake
        prob_interpolated = self.D(interpolated)
        gradients = autograd.grad(
            outputs=prob_interpolated,
            inputs=interpolated,
            grad_outputs=torch.ones_like(prob_interpolated).cuda(),
            create_graph=True,
            retain_graph=True,
        )[0]
        gradients = gradients.view(self.batch_size, -1)
        gradients_norm = torch.sqrt(torch.sum(gradients ** 2, dim=1) + 1e-12)
        return self.gp_weight * ((gradients_norm - 1) ** 2).mean()

    def train(self, All_loader):
        All_Length = sorted(All_loader.keys())
        for epoch in range(self.epochs - self.PreviousEpoch):
            for Cur_Len in All_Length:
                Cur_loader = All_loader[Cur_Len]
                for batch_idx, (data_real, _) in enumerate(Cur_loader):
                    data_real = data_real.cuda()
                    for _ in range(self.G_iter):
                        D_Loss, GP, D_real_mean, D_fake_mean = self._critic_train_iteration(data_real)
                    G_Loss, Corr_Loss = self._generator_train_iteration(seq_len=Cur_Len)
                    if (np.mod(batch_idx + 1, round(len(Cur_loader) / 5)) == 0) or \
                       (batch_idx + 1 == len(Cur_loader)):
                        print(f"[Epoch {self.PreviousEpoch + epoch + 1}] "
                              f"L={Cur_Len} step {batch_idx + 1}/{len(Cur_loader)} | "
                              f"D_loss={D_Loss:.4f} GP={GP:.4f} "
                              f"D_real={D_real_mean:.4f} D_fake={D_fake_mean:.4f} | "
                              f"G_loss={G_Loss:.4f} Corr={Corr_Loss:.4f}")

# %%
seed_all()

# ========================
# Experimental setup
# ========================
Hyper001_BatchSize = 256
Hyper002_Epochs    = 100

# ========================
# Training setup
# ========================
Hyper003_G_iter    = 5
Hyper004_GP_Lambda = 10
Hyper005_C_Lambda  = 10

# ========================
# Network setup
# ========================
Hyper006_ID        = 128
Hyper007_HD        = 128

# ========================
# Optimisation setup
# ========================
Hyper008_LR        = 1e-3
Hyper009_Betas     = (0.9, 0.99)

# ========================
# Pre-training continuation
# ========================
Hyper010_Continue  = False
Hyper011_G_SD      = "YDZ002_G_StateDict_Epoch0"
Hyper012_D_SD      = "YDZ002_D_StateDict_Epoch0"
Hyper013_PreEpoch  = 0

# %%
wgan_gp = Execute_D004(
                Hyper001_BatchSize, Hyper002_Epochs,
                Hyper003_G_iter, Hyper004_GP_Lambda, Hyper005_C_Lambda,
                Hyper006_ID, Hyper007_HD,
                Hyper008_LR, Hyper009_Betas,
                dtype,
                correlation_real,
                [Hyper010_Continue,
                 Hyper011_G_SD, Hyper012_D_SD,
                 Hyper013_PreEpoch])

# %%
wgan_gp.train(only10_60)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:829: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:179.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /tmp/ipython-input-3244134220.py:110: RuntimeWarning: divide by zero encountered in remainder
#   if (np.mod(batch_idx + 1, round(len(Cur_loader) / 5)) == 0) or \
# [Epoch 1] L=10 step 1/1 | D_loss=6.7719 GP=6.9851 D_real=0.1717 D_fake=-0.0416 | G_loss=1.8916 Corr=0.1809
# [Epoch 1] L=20 step 1/1 | D_loss=-0.1515 GP=1.1337 D_real=0.8050 D_fake=-0.4802 | G_loss=2.8250 Corr=0.2126
# [Epoch 1] L=30 step 1/1 | D_loss=-0.5037 GP=3.1309 D_real=2.2363 D_fake=-1.3984 | G_loss=2.8644 Corr=0.1605
# [Epoch 1] L=40 step 1/1 | D_loss=-2.2868 GP=0.1253 D_real=1.7146 D_fake=-0.6975 | G_loss=1.9341 Corr=0.1331
# [Epoch 1] L=50 step 1/1 | D_loss=-2.3454 GP=0.4004 D_real=2.3394 D_fake=-0.4064 | G_loss=1.6259 Corr=0.1228
# [Epoch 1] L=60 step 1/1 | D_loss=-3.0247 GP=0.1825 D_real=2.7041 D_fake=-0.5030 | G_loss=1.5908 Corr=0.1036
# [Epoch 2] L=10 step 1/1 | D_loss=-2.6256 GP=0.4297 D_real=2.5533 D_fake=-0.5020 | G_loss=1.7281 Corr=0.1268
# [Epoch 2] L=20 step 1/1 | D_loss=-3.5852 GP=0.6088 D_real=3.7728 D_fake=-0.4211 | G_loss=1.4950 Corr=0.1037
# [Epoch 2] L=30 step 1/1 | D_loss=-4.4907 GP=0.4733 D_real=4.1767 D_fake=-0.7874 | G_loss=1.9355 Corr=0.1058
# [Epoch 2] L=40 step 1/1 | D_loss=-5.7232 GP=0.2877 D_real=4.9748 D_fake=-1.0360 | G_loss=2.0303 Corr=0.0966
# [Epoch 2] L=50 step 1/1 | D_loss=-7.2808 GP=0.6908 D_real=6.5243 D_fake=-1.4473 | G_loss=2.3552 Corr=0.0896
# [Epoch 2] L=60 step 1/1 | D_loss=-8.7147 GP=0.5210 D_real=7.3011 D_fake=-1.9347 | G_loss=2.8343 Corr=0.0882
# [Epoch 3] L=10 step 1/1 | D_loss=-4.2597 GP=0.0570 D_real=3.2305 D_fake=-1.0862 | G_loss=2.1908 Corr=0.1132
# [Epoch 3] L=20 step 1/1 | D_loss=-6.5686 GP=0.7693 D_real=5.8319 D_fake=-1.5060 | G_loss=2.3760 Corr=0.0870
# [Epoch 3] L=30 step 1/1 | D_loss=-8.0925 GP=2.2210 D_real=7.2362 D_fake=-3.0773 | G_loss=3.7954 Corr=0.0784
# [Epoch 3] L=40 step 1/1 | D_loss=-9.8630 GP=1.0796 D_real=7.6875 D_fake=-3.2551 | G_loss=4.1346 Corr=0.0713
# [Epoch 3] L=50 step 1/1 | D_loss=-10.7131 GP=2.0790 D_real=9.0845 D_fake=-3.7075 | G_loss=4.4431 Corr=0.0637
# [Epoch 3] L=60 step 1/1 | D_loss=-12.0367 GP=1.2680 D_real=9.6491 D_fake=-3.6556 | G_loss=4.5533 Corr=0.0606
# [Epoch 4] L=10 step 1/1 | D_loss=-4.0180 GP=0.1533 D_real=1.9542 D_fake=-2.2171 | G_loss=2.9375 Corr=0.0667
# [Epoch 4] L=20 step 1/1 | D_loss=-5.8793 GP=4.7847 D_real=6.4212 D_fake=-4.2427 | G_loss=4.5367 Corr=0.0613
# [Epoch 4] L=30 step 1/1 | D_loss=-9.2507 GP=0.6985 D_real=5.6432 D_fake=-4.3060 | G_loss=5.0957 Corr=0.0595
# [Epoch 4] L=40 step 1/1 | D_loss=-10.8341 GP=1.6875 D_real=7.9595 D_fake=-4.5622 | G_loss=5.2697 Corr=0.0572
# [Epoch 4] L=50 step 1/1 | D_loss=-11.7091 GP=2.5186 D_real=8.9795 D_fake=-5.2483 | G_loss=5.9026 Corr=0.0561
# [Epoch 4] L=60 step 1/1 | D_loss=-12.8758 GP=1.8456 D_real=9.6769 D_fake=-5.0445 | G_loss=6.1050 Corr=0.0512
# [Epoch 5] L=10 step 1/1 | D_loss=-4.6346 GP=0.0902 D_real=2.1694 D_fake=-2.5554 | G_loss=3.1148 Corr=0.0647
# [Epoch 5] L=20 step 1/1 | D_loss=-7.6510 GP=1.7535 D_real=5.0395 D_fake=-4.3651 | G_loss=5.2113 Corr=0.0552
# [Epoch 5] L=30 step 1/1 | D_loss=-9.1360 GP=0.8286 D_real=5.5066 D_fake=-4.4580 | G_loss=4.8517 Corr=0.0497
# [Epoch 5] L=40 step 1/1 | D_loss=-10.8051 GP=3.9207 D_real=9.1217 D_fake=-5.6041 | G_loss=6.0435 Corr=0.0461
# [Epoch 5] L=50 step 1/1 | D_loss=-12.5199 GP=2.1531 D_real=10.0652 D_fake=-4.6078 | G_loss=5.3066 Corr=0.0463
# [Epoch 5] L=60 step 1/1 | D_loss=-13.8077 GP=2.3425 D_real=10.3130 D_fake=-5.8373 | G_loss=6.4092 Corr=0.0427
# [Epoch 6] L=10 step 1/1 | D_loss=-4.9776 GP=0.0997 D_real=2.6279 D_fake=-2.4494 | G_loss=3.1133 Corr=0.0714
# [Epoch 6] L=20 step 1/1 | D_loss=-7.5736 GP=2.4348 D_real=6.1469 D_fake=-3.8615 | G_loss=4.3887 Corr=0.0481
# [Epoch 6] L=30 step 1/1 | D_loss=-9.6449 GP=1.1558 D_real=6.8162 D_fake=-3.9846 | G_loss=4.3107 Corr=0.0396
# [Epoch 6] L=40 step 1/1 | D_loss=-11.5818 GP=2.3925 D_real=8.0623 D_fake=-5.9120 | G_loss=5.8710 Corr=0.0390
# [Epoch 6] L=50 step 1/1 | D_loss=-12.9937 GP=2.7242 D_real=9.7173 D_fake=-6.0006 | G_loss=5.9544 Corr=0.0387
# [Epoch 6] L=60 step 1/1 | D_loss=-14.2124 GP=1.8821 D_real=10.1270 D_fake=-5.9675 | G_loss=6.2896 Corr=0.0408
# [Epoch 7] L=10 step 1/1 | D_loss=-5.2117 GP=0.2510 D_real=3.0485 D_fake=-2.4142 | G_loss=3.0271 Corr=0.0642
# [Epoch 7] L=20 step 1/1 | D_loss=-7.7985 GP=1.5105 D_real=5.7304 D_fake=-3.5786 | G_loss=4.1344 Corr=0.0505
# [Epoch 7] L=30 step 1/1 | D_loss=-9.8681 GP=2.1129 D_real=7.6288 D_fake=-4.3521 | G_loss=4.7733 Corr=0.0457
# [Epoch 7] L=40 step 1/1 | D_loss=-11.6837 GP=2.6985 D_real=9.5288 D_fake=-4.8534 | G_loss=5.2807 Corr=0.0424
# [Epoch 7] L=50 step 1/1 | D_loss=-13.0441 GP=2.5985 D_real=10.4631 D_fake=-5.1794 | G_loss=5.7473 Corr=0.0383
# [Epoch 7] L=60 step 1/1 | D_loss=-14.2695 GP=1.4173 D_real=9.4032 D_fake=-6.2835 | G_loss=7.0795 Corr=0.0373
# [Epoch 8] L=10 step 1/1 | D_loss=-5.3077 GP=0.7065 D_real=3.5177 D_fake=-2.4964 | G_loss=2.9063 Corr=0.0454
# [Epoch 8] L=20 step 1/1 | D_loss=-7.5245 GP=0.4343 D_real=4.2695 D_fake=-3.6893 | G_loss=4.4138 Corr=0.0488
# [Epoch 8] L=30 step 1/1 | D_loss=-9.7293 GP=1.1221 D_real=5.7496 D_fake=-5.1018 | G_loss=5.3008 Corr=0.0397
# [Epoch 8] L=40 step 1/1 | D_loss=-11.5842 GP=2.5025 D_real=8.9436 D_fake=-5.1431 | G_loss=5.3087 Corr=0.0372
# [Epoch 8] L=50 step 1/1 | D_loss=-12.9220 GP=3.5066 D_real=10.7154 D_fake=-5.7132 | G_loss=5.6913 Corr=0.0376
# [Epoch 8] L=60 step 1/1 | D_loss=-14.4740 GP=2.6417 D_real=11.3988 D_fake=-5.7169 | G_loss=6.0814 Corr=0.0357
# [Epoch 9] L=10 step 1/1 | D_loss=-5.2804 GP=0.5920 D_real=4.0615 D_fake=-1.8109 | G_loss=2.6038 Corr=0.0784
# [Epoch 9] L=20 step 1/1 | D_loss=-7.6149 GP=0.4748 D_real=5.7000 D_fake=-2.3897 | G_loss=2.7844 Corr=0.0394
# [Epoch 9] L=30 step 1/1 | D_loss=-9.6365 GP=2.0455 D_real=7.9038 D_fake=-3.7782 | G_loss=4.1863 Corr=0.0432
# [Epoch 9] L=40 step 1/1 | D_loss=-11.4149 GP=2.9863 D_real=9.2566 D_fake=-5.1447 | G_loss=5.6938 Corr=0.0406
# [Epoch 9] L=50 step 1/1 | D_loss=-12.4831 GP=3.5321 D_real=10.5628 D_fake=-5.4524 | G_loss=5.7536 Corr=0.0393
# [Epoch 9] L=60 step 1/1 | D_loss=-14.4827 GP=2.6375 D_real=12.0500 D_fake=-5.0702 | G_loss=5.4586 Corr=0.0368
# [Epoch 10] L=10 step 1/1 | D_loss=-5.1115 GP=0.2753 D_real=3.5995 D_fake=-1.7874 | G_loss=2.3032 Corr=0.0579
# [Epoch 10] L=20 step 1/1 | D_loss=-7.6164 GP=1.1579 D_real=6.1840 D_fake=-2.5904 | G_loss=3.0257 Corr=0.0450
# [Epoch 10] L=30 step 1/1 | D_loss=-9.5516 GP=1.0939 D_real=6.8913 D_fake=-3.7542 | G_loss=4.2685 Corr=0.0426
# [Epoch 10] L=40 step 1/1 | D_loss=-11.4514 GP=1.8341 D_real=8.7194 D_fake=-4.5662 | G_loss=5.0007 Corr=0.0349
# [Epoch 10] L=50 step 1/1 | D_loss=-12.6649 GP=2.0220 D_real=9.4185 D_fake=-5.2684 | G_loss=5.8067 Corr=0.0333
# [Epoch 10] L=60 step 1/1 | D_loss=-13.5870 GP=2.6670 D_real=9.9563 D_fake=-6.2977 | G_loss=6.1094 Corr=0.0381
# [Epoch 11] L=10 step 1/1 | D_loss=-5.1008 GP=0.3256 D_real=3.5429 D_fake=-1.8835 | G_loss=2.3604 Corr=0.0505
# [Epoch 11] L=20 step 1/1 | D_loss=-7.5733 GP=0.8949 D_real=5.9695 D_fake=-2.4987 | G_loss=2.8789 Corr=0.0424
# [Epoch 11] L=30 step 1/1 | D_loss=-9.2675 GP=2.4382 D_real=8.6840 D_fake=-3.0216 | G_loss=3.3290 Corr=0.0432
# [Epoch 11] L=40 step 1/1 | D_loss=-11.1241 GP=2.6967 D_real=9.9775 D_fake=-3.8433 | G_loss=4.5694 Corr=0.0414
# [Epoch 11] L=50 step 1/1 | D_loss=-12.5874 GP=3.0579 D_real=10.6320 D_fake=-5.0133 | G_loss=5.3577 Corr=0.0374
# [Epoch 11] L=60 step 1/1 | D_loss=-13.8203 GP=2.8611 D_real=11.5984 D_fake=-5.0830 | G_loss=5.4359 Corr=0.0362
# [Epoch 12] L=10 step 1/1 | D_loss=-4.9660 GP=0.2002 D_real=3.3088 D_fake=-1.8574 | G_loss=2.3735 Corr=0.0530
# [Epoch 12] L=20 step 1/1 | D_loss=-7.2076 GP=0.9741 D_real=4.8396 D_fake=-3.3422 | G_loss=3.8139 Corr=0.0346
# [Epoch 12] L=30 step 1/1 | D_loss=-9.3012 GP=1.3316 D_real=6.4789 D_fake=-4.1539 | G_loss=4.5281 Corr=0.0334
# [Epoch 12] L=40 step 1/1 | D_loss=-11.1165 GP=2.3004 D_real=8.6602 D_fake=-4.7566 | G_loss=4.8020 Corr=0.0303
# [Epoch 12] L=50 step 1/1 | D_loss=-12.5288 GP=2.7669 D_real=9.6354 D_fake=-5.6603 | G_loss=5.9177 Corr=0.0292
# [Epoch 12] L=60 step 1/1 | D_loss=-13.8477 GP=3.4171 D_real=11.2737 D_fake=-5.9911 | G_loss=5.4867 Corr=0.0281
# [Epoch 13] L=10 step 1/1 | D_loss=-4.9463 GP=0.2653 D_real=3.4883 D_fake=-1.7233 | G_loss=2.1486 Corr=0.0468
# [Epoch 13] L=20 step 1/1 | D_loss=-7.3237 GP=0.6540 D_real=6.0319 D_fake=-1.9457 | G_loss=2.2010 Corr=0.0326
# [Epoch 13] L=30 step 1/1 | D_loss=-9.2030 GP=1.9681 D_real=8.9041 D_fake=-2.2670 | G_loss=2.4862 Corr=0.0338
# [Epoch 13] L=40 step 1/1 | D_loss=-10.8030 GP=2.0727 D_real=10.1622 D_fake=-2.7135 | G_loss=3.1237 Corr=0.0344
# [Epoch 13] L=50 step 1/1 | D_loss=-12.2000 GP=1.8451 D_real=10.2350 D_fake=-3.8100 | G_loss=4.1790 Corr=0.0319
# [Epoch 13] L=60 step 1/1 | D_loss=-13.4612 GP=2.8004 D_real=10.4750 D_fake=-5.7867 | G_loss=6.2011 Corr=0.0319
# [Epoch 14] L=10 step 1/1 | D_loss=-4.8555 GP=0.2602 D_real=2.8288 D_fake=-2.2869 | G_loss=2.8136 Corr=0.0482
# [Epoch 14] L=20 step 1/1 | D_loss=-6.9958 GP=0.6092 D_real=3.7631 D_fake=-3.8419 | G_loss=4.3129 Corr=0.0374
# [Epoch 14] L=30 step 1/1 | D_loss=-8.9760 GP=1.4586 D_real=5.9260 D_fake=-4.5086 | G_loss=4.7177 Corr=0.0391
# [Epoch 14] L=40 step 1/1 | D_loss=-10.4750 GP=2.4783 D_real=8.8245 D_fake=-4.1288 | G_loss=3.7970 Corr=0.0347
# [Epoch 14] L=50 step 1/1 | D_loss=-11.8604 GP=2.1879 D_real=10.7515 D_fake=-3.2968 | G_loss=3.6124 Corr=0.0320
# [Epoch 14] L=60 step 1/1 | D_loss=-12.8365 GP=1.8673 D_real=11.1030 D_fake=-3.6009 | G_loss=4.1576 Corr=0.0289
# [Epoch 15] L=10 step 1/1 | D_loss=-4.7500 GP=0.3216 D_real=3.4771 D_fake=-1.5946 | G_loss=2.1598 Corr=0.0553
# [Epoch 15] L=20 step 1/1 | D_loss=-6.8503 GP=0.5948 D_real=5.1901 D_fake=-2.2550 | G_loss=2.9613 Corr=0.0662
# [Epoch 15] L=30 step 1/1 | D_loss=-8.6282 GP=1.0876 D_real=6.7977 D_fake=-2.9180 | G_loss=3.3421 Corr=0.0537
# [Epoch 15] L=40 step 1/1 | D_loss=-10.3911 GP=1.1209 D_real=8.3693 D_fake=-3.1428 | G_loss=3.8244 Corr=0.0497
# [Epoch 15] L=50 step 1/1 | D_loss=-11.7904 GP=1.9249 D_real=9.3555 D_fake=-4.3598 | G_loss=5.1380 Corr=0.0464
# [Epoch 15] L=60 step 1/1 | D_loss=-12.4894 GP=1.4980 D_real=9.1616 D_fake=-4.8258 | G_loss=5.7244 Corr=0.0431
# [Epoch 16] L=10 step 1/1 | D_loss=-4.6499 GP=0.9153 D_real=3.5122 D_fake=-2.0530 | G_loss=2.9979 Corr=0.0965
# [Epoch 16] L=20 step 1/1 | D_loss=-5.8685 GP=0.0650 D_real=3.3959 D_fake=-2.5376 | G_loss=3.4264 Corr=0.0724
# [Epoch 16] L=30 step 1/1 | D_loss=-8.4740 GP=1.4700 D_real=6.0571 D_fake=-3.8870 | G_loss=4.2629 Corr=0.0744
# [Epoch 16] L=40 step 1/1 | D_loss=-9.5012 GP=3.8207 D_real=8.4725 D_fake=-4.8493 | G_loss=4.8789 Corr=0.0594
# [Epoch 16] L=50 step 1/1 | D_loss=-11.3817 GP=3.1955 D_real=9.9506 D_fake=-4.6265 | G_loss=5.3776 Corr=0.0512
# [Epoch 16] L=60 step 1/1 | D_loss=-12.8949 GP=2.5850 D_real=10.0365 D_fake=-5.4435 | G_loss=6.2143 Corr=0.0500
# [Epoch 17] L=10 step 1/1 | D_loss=-4.6334 GP=0.4427 D_real=2.8688 D_fake=-2.2073 | G_loss=2.9883 Corr=0.0742
# [Epoch 17] L=20 step 1/1 | D_loss=-6.5940 GP=0.2442 D_real=3.4166 D_fake=-3.4215 | G_loss=3.9467 Corr=0.0474
# [Epoch 17] L=30 step 1/1 | D_loss=-8.2610 GP=2.2178 D_real=5.0829 D_fake=-5.3959 | G_loss=5.6951 Corr=0.0532
# [Epoch 17] L=40 step 1/1 | D_loss=-10.0086 GP=2.6640 D_real=6.8819 D_fake=-5.7907 | G_loss=6.0921 Corr=0.0510
# [Epoch 17] L=50 step 1/1 | D_loss=-11.4438 GP=2.1862 D_real=7.7120 D_fake=-5.9179 | G_loss=6.4582 Corr=0.0489
# [Epoch 17] L=60 step 1/1 | D_loss=-12.4315 GP=1.8134 D_real=7.7675 D_fake=-6.4774 | G_loss=6.9213 Corr=0.0447
# [Epoch 18] L=10 step 1/1 | D_loss=-4.4435 GP=0.8709 D_real=3.1983 D_fake=-2.1162 | G_loss=2.7562 Corr=0.0615
# [Epoch 18] L=20 step 1/1 | D_loss=-5.5058 GP=0.1366 D_real=2.1717 D_fake=-3.4706 | G_loss=4.2935 Corr=0.0525
# [Epoch 18] L=30 step 1/1 | D_loss=-7.7631 GP=1.5774 D_real=2.8958 D_fake=-6.4448 | G_loss=6.5726 Corr=0.0465
# [Epoch 18] L=40 step 1/1 | D_loss=-9.3272 GP=2.7844 D_real=5.9999 D_fake=-6.1117 | G_loss=5.7002 Corr=0.0464
# [Epoch 18] L=50 step 1/1 | D_loss=-10.6244 GP=1.0366 D_real=7.4006 D_fake=-4.2604 | G_loss=4.6850 Corr=0.0413
# [Epoch 18] L=60 step 1/1 | D_loss=-12.1111 GP=1.4514 D_real=9.1564 D_fake=-4.4060 | G_loss=5.0438 Corr=0.0443
# [Epoch 19] L=10 step 1/1 | D_loss=-4.3870 GP=0.3960 D_real=2.8055 D_fake=-1.9775 | G_loss=2.6086 Corr=0.0589
# [Epoch 19] L=20 step 1/1 | D_loss=-6.4790 GP=0.4862 D_real=3.9197 D_fake=-3.0455 | G_loss=3.5623 Corr=0.0484
# [Epoch 19] L=30 step 1/1 | D_loss=-8.0944 GP=2.2382 D_real=5.8801 D_fake=-4.4525 | G_loss=4.8298 Corr=0.0449
# [Epoch 19] L=40 step 1/1 | D_loss=-9.8454 GP=2.1488 D_real=7.1570 D_fake=-4.8372 | G_loss=5.4540 Corr=0.0402
# [Epoch 19] L=50 step 1/1 | D_loss=-10.9605 GP=1.8731 D_real=6.9681 D_fake=-5.8656 | G_loss=6.2929 Corr=0.0384
# [Epoch 19] L=60 step 1/1 | D_loss=-11.7938 GP=2.2230 D_real=7.3818 D_fake=-6.6350 | G_loss=6.7902 Corr=0.0362
# [Epoch 20] L=10 step 1/1 | D_loss=-4.2659 GP=0.2001 D_real=2.2637 D_fake=-2.2023 | G_loss=2.9317 Corr=0.0701
# [Epoch 20] L=20 step 1/1 | D_loss=-6.3953 GP=0.6012 D_real=3.6858 D_fake=-3.3107 | G_loss=3.7037 Corr=0.0465
# [Epoch 20] L=30 step 1/1 | D_loss=-8.0211 GP=2.2455 D_real=5.7298 D_fake=-4.5368 | G_loss=4.8936 Corr=0.0383
# [Epoch 20] L=40 step 1/1 | D_loss=-9.5382 GP=1.7641 D_real=6.4054 D_fake=-4.8969 | G_loss=5.5538 Corr=0.0410
# [Epoch 20] L=50 step 1/1 | D_loss=-10.8059 GP=1.6757 D_real=6.7427 D_fake=-5.7389 | G_loss=6.0730 Corr=0.0370
# [Epoch 20] L=60 step 1/1 | D_loss=-11.9269 GP=2.1601 D_real=7.6550 D_fake=-6.4321 | G_loss=6.6644 Corr=0.0353
# [Epoch 21] L=10 step 1/1 | D_loss=-4.3353 GP=0.2571 D_real=2.3351 D_fake=-2.2574 | G_loss=2.7902 Corr=0.0551
# [Epoch 21] L=20 step 1/1 | D_loss=-6.4191 GP=0.7030 D_real=3.7289 D_fake=-3.3931 | G_loss=3.7602 Corr=0.0361
# [Epoch 21] L=30 step 1/1 | D_loss=-8.1813 GP=1.7666 D_real=5.5536 D_fake=-4.3943 | G_loss=4.6833 Corr=0.0352
# [Epoch 21] L=40 step 1/1 | D_loss=-9.5222 GP=2.0998 D_real=6.4588 D_fake=-5.1632 | G_loss=5.4014 Corr=0.0367
# [Epoch 21] L=50 step 1/1 | D_loss=-10.7575 GP=2.2893 D_real=7.7029 D_fake=-5.3439 | G_loss=5.6002 Corr=0.0384
# [Epoch 21] L=60 step 1/1 | D_loss=-11.8927 GP=2.1584 D_real=8.3409 D_fake=-5.7101 | G_loss=5.9846 Corr=0.0370
# [Epoch 22] L=10 step 1/1 | D_loss=-4.3376 GP=0.2703 D_real=2.6680 D_fake=-1.9398 | G_loss=2.6632 Corr=0.0716
# [Epoch 22] L=20 step 1/1 | D_loss=-6.3101 GP=0.6936 D_real=4.2912 D_fake=-2.7125 | G_loss=3.2269 Corr=0.0541
# [Epoch 22] L=30 step 1/1 | D_loss=-7.9782 GP=1.8037 D_real=6.1044 D_fake=-3.6774 | G_loss=4.1474 Corr=0.0613
# [Epoch 22] L=40 step 1/1 | D_loss=-9.4677 GP=2.5228 D_real=7.6220 D_fake=-4.3685 | G_loss=4.8593 Corr=0.0473
# [Epoch 22] L=50 step 1/1 | D_loss=-10.9783 GP=2.1097 D_real=7.8753 D_fake=-5.2127 | G_loss=5.5567 Corr=0.0499
# [Epoch 22] L=60 step 1/1 | D_loss=-12.0281 GP=1.8017 D_real=7.7149 D_fake=-6.1149 | G_loss=6.5304 Corr=0.0471
# [Epoch 23] L=10 step 1/1 | D_loss=-4.3599 GP=0.4496 D_real=2.7735 D_fake=-2.0360 | G_loss=3.3358 Corr=0.1293
# [Epoch 23] L=20 step 1/1 | D_loss=-6.2893 GP=0.3511 D_real=3.9486 D_fake=-2.6919 | G_loss=3.1119 Corr=0.0417
# [Epoch 23] L=30 step 1/1 | D_loss=-8.2233 GP=1.7878 D_real=6.5039 D_fake=-3.5071 | G_loss=3.7955 Corr=0.0563
# [Epoch 23] L=40 step 1/1 | D_loss=-9.3958 GP=3.2802 D_real=8.4462 D_fake=-4.2297 | G_loss=4.6175 Corr=0.0556
# [Epoch 23] L=50 step 1/1 | D_loss=-10.9514 GP=2.3071 D_real=8.3562 D_fake=-4.9023 | G_loss=5.5989 Corr=0.0597
# [Epoch 23] L=60 step 1/1 | D_loss=-11.7700 GP=2.5359 D_real=8.0981 D_fake=-6.2077 | G_loss=6.6270 Corr=0.0592
# [Epoch 24] L=10 step 1/1 | D_loss=-4.3610 GP=0.6507 D_real=2.5458 D_fake=-2.4659 | G_loss=3.2335 Corr=0.0746
# [Epoch 24] L=20 step 1/1 | D_loss=-6.0400 GP=0.2162 D_real=2.6490 D_fake=-3.6072 | G_loss=4.0223 Corr=0.0474
# [Epoch 24] L=30 step 1/1 | D_loss=-8.1381 GP=1.8240 D_real=5.8403 D_fake=-4.1218 | G_loss=4.3120 Corr=0.0535
# [Epoch 24] L=40 step 1/1 | D_loss=-9.2777 GP=2.6926 D_real=7.1392 D_fake=-4.8311 | G_loss=4.9808 Corr=0.0458
# [Epoch 24] L=50 step 1/1 | D_loss=-10.4630 GP=3.1220 D_real=8.6088 D_fake=-4.9762 | G_loss=5.1092 Corr=0.0410
# [Epoch 24] L=60 step 1/1 | D_loss=-12.0205 GP=2.5223 D_real=9.2129 D_fake=-5.3299 | G_loss=5.2938 Corr=0.0420
# [Epoch 25] L=10 step 1/1 | D_loss=-4.2655 GP=0.3678 D_real=2.9648 D_fake=-1.6685 | G_loss=2.3214 Corr=0.0677
# [Epoch 25] L=20 step 1/1 | D_loss=-6.3851 GP=0.5421 D_real=4.8024 D_fake=-2.1247 | G_loss=2.5606 Corr=0.0446
# [Epoch 25] L=30 step 1/1 | D_loss=-8.1549 GP=2.0172 D_real=7.6465 D_fake=-2.5257 | G_loss=2.8597 Corr=0.0494
# [Epoch 25] L=40 step 1/1 | D_loss=-9.5228 GP=2.8754 D_real=9.4231 D_fake=-2.9750 | G_loss=3.3753 Corr=0.0494
# [Epoch 25] L=50 step 1/1 | D_loss=-10.8620 GP=2.9369 D_real=10.0176 D_fake=-3.7813 | G_loss=4.1975 Corr=0.0506
# [Epoch 25] L=60 step 1/1 | D_loss=-12.0904 GP=3.0047 D_real=10.5589 D_fake=-4.5362 | G_loss=4.6291 Corr=0.0482
# [Epoch 26] L=10 step 1/1 | D_loss=-4.2217 GP=0.2174 D_real=2.7461 D_fake=-1.6930 | G_loss=2.5298 Corr=0.0741
# [Epoch 26] L=20 step 1/1 | D_loss=-6.5035 GP=1.0043 D_real=4.7061 D_fake=-2.8017 | G_loss=3.2219 Corr=0.0490
# [Epoch 26] L=30 step 1/1 | D_loss=-8.1311 GP=2.0848 D_real=6.9089 D_fake=-3.3070 | G_loss=3.7404 Corr=0.0544
# [Epoch 26] L=40 step 1/1 | D_loss=-9.2063 GP=3.1868 D_real=9.1016 D_fake=-3.2914 | G_loss=3.8260 Corr=0.0474
# [Epoch 26] L=50 step 1/1 | D_loss=-10.4651 GP=2.8204 D_real=8.8529 D_fake=-4.4326 | G_loss=4.5702 Corr=0.0388
# [Epoch 26] L=60 step 1/1 | D_loss=-11.4691 GP=1.5362 D_real=9.4118 D_fake=-3.5935 | G_loss=3.5295 Corr=0.0383
# [Epoch 27] L=10 step 1/1 | D_loss=-4.0530 GP=0.3581 D_real=2.9767 D_fake=-1.4343 | G_loss=2.2838 Corr=0.0862
# [Epoch 27] L=20 step 1/1 | D_loss=-6.2208 GP=1.4218 D_real=5.7466 D_fake=-1.8960 | G_loss=2.3864 Corr=0.0503
# [Epoch 27] L=30 step 1/1 | D_loss=-7.8620 GP=1.6268 D_real=7.1881 D_fake=-2.3007 | G_loss=2.8625 Corr=0.0552
# [Epoch 27] L=40 step 1/1 | D_loss=-9.5281 GP=2.0332 D_real=8.6987 D_fake=-2.8625 | G_loss=3.4218 Corr=0.0493
# [Epoch 27] L=50 step 1/1 | D_loss=-10.9347 GP=2.0760 D_real=9.4449 D_fake=-3.5659 | G_loss=4.1719 Corr=0.0446
# [Epoch 27] L=60 step 1/1 | D_loss=-12.1627 GP=2.0937 D_real=9.1564 D_fake=-5.1000 | G_loss=5.4787 Corr=0.0427
# [Epoch 28] L=10 step 1/1 | D_loss=-4.3888 GP=0.4184 D_real=2.6703 D_fake=-2.1369 | G_loss=2.7221 Corr=0.0576
# [Epoch 28] L=20 step 1/1 | D_loss=-6.3832 GP=0.6820 D_real=3.9852 D_fake=-3.0800 | G_loss=3.5512 Corr=0.0438
# [Epoch 28] L=30 step 1/1 | D_loss=-8.0671 GP=1.1531 D_real=5.7099 D_fake=-3.5103 | G_loss=3.7427 Corr=0.0371
# [Epoch 28] L=40 step 1/1 | D_loss=-9.4754 GP=1.8727 D_real=8.4351 D_fake=-2.9129 | G_loss=3.1403 Corr=0.0402
# [Epoch 28] L=50 step 1/1 | D_loss=-10.9409 GP=2.0225 D_real=9.5672 D_fake=-3.3962 | G_loss=3.5228 Corr=0.0426
# [Epoch 28] L=60 step 1/1 | D_loss=-12.0939 GP=1.7667 D_real=10.0862 D_fake=-3.7744 | G_loss=3.4715 Corr=0.0411
# [Epoch 29] L=10 step 1/1 | D_loss=-4.3746 GP=0.3358 D_real=3.5149 D_fake=-1.1955 | G_loss=1.7107 Corr=0.0472
# [Epoch 29] L=20 step 1/1 | D_loss=-6.3952 GP=0.8073 D_real=5.7271 D_fake=-1.4754 | G_loss=1.8357 Corr=0.0381
# [Epoch 29] L=30 step 1/1 | D_loss=-8.0409 GP=1.9749 D_real=8.2265 D_fake=-1.7893 | G_loss=2.0615 Corr=0.0360
# [Epoch 29] L=40 step 1/1 | D_loss=-9.4234 GP=2.8352 D_real=10.1428 D_fake=-2.1158 | G_loss=2.5098 Corr=0.0352
# [Epoch 29] L=50 step 1/1 | D_loss=-10.8473 GP=2.7180 D_real=11.2960 D_fake=-2.2693 | G_loss=2.5144 Corr=0.0310
# [Epoch 29] L=60 step 1/1 | D_loss=-12.3090 GP=2.2841 D_real=12.4208 D_fake=-2.1723 | G_loss=2.3910 Corr=0.0303
# [Epoch 30] L=10 step 1/1 | D_loss=-4.3639 GP=0.2151 D_real=3.5652 D_fake=-1.0138 | G_loss=1.3250 Corr=0.0316
# [Epoch 30] L=20 step 1/1 | D_loss=-6.6170 GP=0.9412 D_real=6.2461 D_fake=-1.3121 | G_loss=1.6073 Corr=0.0282
# [Epoch 30] L=30 step 1/1 | D_loss=-8.4059 GP=1.9392 D_real=8.5828 D_fake=-1.7622 | G_loss=2.0193 Corr=0.0298
# [Epoch 30] L=40 step 1/1 | D_loss=-9.8440 GP=2.4068 D_real=10.2793 D_fake=-1.9715 | G_loss=2.1794 Corr=0.0278
# [Epoch 30] L=50 step 1/1 | D_loss=-11.0050 GP=2.3397 D_real=10.7938 D_fake=-2.5509 | G_loss=2.7915 Corr=0.0247
# [Epoch 30] L=60 step 1/1 | D_loss=-12.4032 GP=2.1817 D_real=11.6799 D_fake=-2.9051 | G_loss=3.2530 Corr=0.0227
# [Epoch 31] L=10 step 1/1 | D_loss=-4.4962 GP=0.3606 D_real=3.4067 D_fake=-1.4500 | G_loss=1.7973 Corr=0.0330
# [Epoch 31] L=20 step 1/1 | D_loss=-6.6174 GP=0.6735 D_real=5.2184 D_fake=-2.0724 | G_loss=2.4014 Corr=0.0230
# [Epoch 31] L=30 step 1/1 | D_loss=-8.2880 GP=1.1936 D_real=6.7018 D_fake=-2.7797 | G_loss=3.0229 Corr=0.0291
# [Epoch 31] L=40 step 1/1 | D_loss=-9.8636 GP=2.1888 D_real=8.4670 D_fake=-3.5854 | G_loss=3.6066 Corr=0.0228
# [Epoch 31] L=50 step 1/1 | D_loss=-11.3744 GP=2.4535 D_real=9.8544 D_fake=-3.9736 | G_loss=3.9241 Corr=0.0230
# [Epoch 31] L=60 step 1/1 | D_loss=-12.5693 GP=2.7805 D_real=10.7687 D_fake=-4.5811 | G_loss=4.5345 Corr=0.0228
# [Epoch 32] L=10 step 1/1 | D_loss=-4.5301 GP=0.3727 D_real=3.2195 D_fake=-1.6833 | G_loss=2.0007 Corr=0.0268
# [Epoch 32] L=20 step 1/1 | D_loss=-6.3264 GP=0.6993 D_real=4.7642 D_fake=-2.2615 | G_loss=2.5145 Corr=0.0239
# [Epoch 32] L=30 step 1/1 | D_loss=-8.1746 GP=1.8689 D_real=6.7119 D_fake=-3.3317 | G_loss=3.4501 Corr=0.0228
# [Epoch 32] L=40 step 1/1 | D_loss=-9.4086 GP=3.1637 D_real=8.6058 D_fake=-3.9665 | G_loss=4.0759 Corr=0.0223
# [Epoch 32] L=50 step 1/1 | D_loss=-11.3237 GP=2.9171 D_real=9.8520 D_fake=-4.3888 | G_loss=4.4942 Corr=0.0211
# [Epoch 32] L=60 step 1/1 | D_loss=-12.2756 GP=2.3607 D_real=9.6945 D_fake=-4.9418 | G_loss=5.0791 Corr=0.0198
# [Epoch 33] L=10 step 1/1 | D_loss=-4.4623 GP=0.2927 D_real=2.6640 D_fake=-2.0909 | G_loss=2.4002 Corr=0.0290
# [Epoch 33] L=20 step 1/1 | D_loss=-6.4697 GP=0.6260 D_real=3.9317 D_fake=-3.1640 | G_loss=3.4585 Corr=0.0254
# [Epoch 33] L=30 step 1/1 | D_loss=-8.2705 GP=1.9682 D_real=5.9712 D_fake=-4.2675 | G_loss=4.3594 Corr=0.0214
# [Epoch 33] L=40 step 1/1 | D_loss=-9.5801 GP=2.4703 D_real=7.4221 D_fake=-4.6282 | G_loss=4.5221 Corr=0.0221
# [Epoch 33] L=50 step 1/1 | D_loss=-11.1810 GP=2.9900 D_real=8.8536 D_fake=-5.3175 | G_loss=5.5399 Corr=0.0213
# [Epoch 33] L=60 step 1/1 | D_loss=-12.3180 GP=2.8488 D_real=10.3283 D_fake=-4.8385 | G_loss=4.7695 Corr=0.0242
# [Epoch 34] L=10 step 1/1 | D_loss=-4.4935 GP=0.3122 D_real=3.4437 D_fake=-1.3621 | G_loss=1.5542 Corr=0.0263
# [Epoch 34] L=20 step 1/1 | D_loss=-6.5951 GP=0.8447 D_real=6.1326 D_fake=-1.3072 | G_loss=1.4847 Corr=0.0222
# [Epoch 34] L=30 step 1/1 | D_loss=-8.2251 GP=1.3664 D_real=8.3626 D_fake=-1.2289 | G_loss=1.2655 Corr=0.0222
# [Epoch 34] L=40 step 1/1 | D_loss=-9.7905 GP=2.1006 D_real=10.7713 D_fake=-1.1198 | G_loss=1.1424 Corr=0.0198
# [Epoch 34] L=50 step 1/1 | D_loss=-11.1904 GP=1.6557 D_real=11.6779 D_fake=-1.1681 | G_loss=1.4767 Corr=0.0187
# [Epoch 34] L=60 step 1/1 | D_loss=-12.0441 GP=0.9784 D_real=11.0354 D_fake=-1.9871 | G_loss=2.6026 Corr=0.0202
# [Epoch 35] L=10 step 1/1 | D_loss=-4.4326 GP=0.4773 D_real=3.5774 D_fake=-1.3325 | G_loss=1.5940 Corr=0.0236
# [Epoch 35] L=20 step 1/1 | D_loss=-6.4402 GP=0.4306 D_real=4.7780 D_fake=-2.0927 | G_loss=2.4839 Corr=0.0219
# [Epoch 35] L=30 step 1/1 | D_loss=-8.4038 GP=1.3255 D_real=6.6107 D_fake=-3.1186 | G_loss=3.2165 Corr=0.0178
# [Epoch 35] L=40 step 1/1 | D_loss=-9.9282 GP=2.5074 D_real=8.1292 D_fake=-4.3064 | G_loss=4.1482 Corr=0.0191
# [Epoch 35] L=50 step 1/1 | D_loss=-11.3820 GP=2.6301 D_real=9.2845 D_fake=-4.7276 | G_loss=4.2034 Corr=0.0186
# [Epoch 35] L=60 step 1/1 | D_loss=-12.6102 GP=2.9209 D_real=11.1356 D_fake=-4.3955 | G_loss=4.1069 Corr=0.0192
# [Epoch 36] L=10 step 1/1 | D_loss=-4.3663 GP=0.3798 D_real=3.2416 D_fake=-1.5044 | G_loss=1.7457 Corr=0.0247
# [Epoch 36] L=20 step 1/1 | D_loss=-6.4630 GP=0.6704 D_real=5.1446 D_fake=-1.9888 | G_loss=2.2240 Corr=0.0242
# [Epoch 36] L=30 step 1/1 | D_loss=-8.1865 GP=2.4257 D_real=8.0129 D_fake=-2.5992 | G_loss=2.7291 Corr=0.0210
# [Epoch 36] L=40 step 1/1 | D_loss=-9.8313 GP=3.0048 D_real=9.9234 D_fake=-2.9127 | G_loss=3.0852 Corr=0.0195
# [Epoch 36] L=50 step 1/1 | D_loss=-11.3008 GP=2.6585 D_real=10.6922 D_fake=-3.2671 | G_loss=3.3695 Corr=0.0200
# [Epoch 36] L=60 step 1/1 | D_loss=-12.6834 GP=2.7652 D_real=11.4376 D_fake=-4.0110 | G_loss=4.0302 Corr=0.0180
# [Epoch 37] L=10 step 1/1 | D_loss=-4.4377 GP=0.2552 D_real=2.9637 D_fake=-1.7291 | G_loss=1.9676 Corr=0.0235
# [Epoch 37] L=20 step 1/1 | D_loss=-6.5337 GP=0.7693 D_real=4.7756 D_fake=-2.5274 | G_loss=2.7917 Corr=0.0232
# [Epoch 37] L=30 step 1/1 | D_loss=-8.1405 GP=1.4373 D_real=6.4359 D_fake=-3.1419 | G_loss=3.3407 Corr=0.0219
# [Epoch 37] L=40 step 1/1 | D_loss=-9.7788 GP=2.0153 D_real=8.0477 D_fake=-3.7464 | G_loss=3.9070 Corr=0.0188
# [Epoch 37] L=50 step 1/1 | D_loss=-11.1630 GP=3.3080 D_real=9.6139 D_fake=-4.8570 | G_loss=4.7520 Corr=0.0171
# [Epoch 37] L=60 step 1/1 | D_loss=-12.5973 GP=3.2642 D_real=10.9865 D_fake=-4.8750 | G_loss=5.0811 Corr=0.0188
# [Epoch 38] L=10 step 1/1 | D_loss=-4.2925 GP=0.1941 D_real=2.4378 D_fake=-2.0488 | G_loss=2.2996 Corr=0.0216
# [Epoch 38] L=20 step 1/1 | D_loss=-6.4286 GP=1.0243 D_real=4.0611 D_fake=-3.3918 | G_loss=3.6338 Corr=0.0202
# [Epoch 38] L=30 step 1/1 | D_loss=-8.4326 GP=1.8620 D_real=6.2155 D_fake=-4.0791 | G_loss=4.0894 Corr=0.0185
# [Epoch 38] L=40 step 1/1 | D_loss=-9.8704 GP=2.8702 D_real=7.9386 D_fake=-4.8020 | G_loss=4.8427 Corr=0.0187
# [Epoch 38] L=50 step 1/1 | D_loss=-11.0046 GP=2.5978 D_real=8.3126 D_fake=-5.2898 | G_loss=5.6871 Corr=0.0202
# [Epoch 38] L=60 step 1/1 | D_loss=-12.4049 GP=2.0403 D_real=8.9387 D_fake=-5.5065 | G_loss=5.3676 Corr=0.0179
# [Epoch 39] L=10 step 1/1 | D_loss=-4.3763 GP=0.2822 D_real=2.5400 D_fake=-2.1185 | G_loss=2.2914 Corr=0.0237
# [Epoch 39] L=20 step 1/1 | D_loss=-6.3812 GP=0.6020 D_real=4.2629 D_fake=-2.7203 | G_loss=2.9193 Corr=0.0159
# [Epoch 39] L=30 step 1/1 | D_loss=-8.3512 GP=1.7037 D_real=6.4575 D_fake=-3.5974 | G_loss=3.7118 Corr=0.0187
# [Epoch 39] L=40 step 1/1 | D_loss=-9.8940 GP=2.1649 D_real=7.7962 D_fake=-4.2627 | G_loss=4.2797 Corr=0.0201
# [Epoch 39] L=50 step 1/1 | D_loss=-11.2051 GP=2.2222 D_real=9.7053 D_fake=-3.7220 | G_loss=3.5222 Corr=0.0161
# [Epoch 39] L=60 step 1/1 | D_loss=-12.5583 GP=1.9817 D_real=11.2836 D_fake=-3.2563 | G_loss=3.3850 Corr=0.0171
# [Epoch 40] L=10 step 1/1 | D_loss=-4.4684 GP=0.3665 D_real=3.1787 D_fake=-1.6562 | G_loss=1.9108 Corr=0.0229
# [Epoch 40] L=20 step 1/1 | D_loss=-6.6627 GP=0.6564 D_real=4.9730 D_fake=-2.3461 | G_loss=2.5745 Corr=0.0193
# [Epoch 40] L=30 step 1/1 | D_loss=-8.2559 GP=1.6342 D_real=6.8312 D_fake=-3.0588 | G_loss=3.1957 Corr=0.0210
# [Epoch 40] L=40 step 1/1 | D_loss=-9.7930 GP=2.6953 D_real=8.9509 D_fake=-3.5373 | G_loss=3.5602 Corr=0.0191
# [Epoch 40] L=50 step 1/1 | D_loss=-11.3213 GP=2.1437 D_real=9.5424 D_fake=-3.9226 | G_loss=4.0320 Corr=0.0187
# [Epoch 40] L=60 step 1/1 | D_loss=-12.5336 GP=2.9404 D_real=10.8632 D_fake=-4.6108 | G_loss=4.5648 Corr=0.0181
# [Epoch 41] L=10 step 1/1 | D_loss=-4.4658 GP=0.3153 D_real=2.8324 D_fake=-1.9487 | G_loss=2.2272 Corr=0.0244
# [Epoch 41] L=20 step 1/1 | D_loss=-6.4355 GP=0.6283 D_real=4.2212 D_fake=-2.8427 | G_loss=3.0883 Corr=0.0219
# [Epoch 41] L=30 step 1/1 | D_loss=-8.3143 GP=1.8433 D_real=6.6653 D_fake=-3.4923 | G_loss=3.5860 Corr=0.0204
# [Epoch 41] L=40 step 1/1 | D_loss=-10.1344 GP=2.6000 D_real=8.7331 D_fake=-4.0013 | G_loss=4.0426 Corr=0.0179
# [Epoch 41] L=50 step 1/1 | D_loss=-11.1506 GP=2.5408 D_real=9.1330 D_fake=-4.5584 | G_loss=4.6616 Corr=0.0179
# [Epoch 41] L=60 step 1/1 | D_loss=-12.7358 GP=3.0776 D_real=11.7039 D_fake=-4.1095 | G_loss=4.2077 Corr=0.0180
# [Epoch 42] L=10 step 1/1 | D_loss=-4.4576 GP=0.2226 D_real=2.9550 D_fake=-1.7252 | G_loss=1.9598 Corr=0.0210
# [Epoch 42] L=20 step 1/1 | D_loss=-6.4914 GP=0.8260 D_real=4.8772 D_fake=-2.4401 | G_loss=2.6427 Corr=0.0199
# [Epoch 42] L=30 step 1/1 | D_loss=-8.4153 GP=1.8503 D_real=6.9956 D_fake=-3.2700 | G_loss=3.4450 Corr=0.0200
# [Epoch 42] L=40 step 1/1 | D_loss=-9.9220 GP=2.4470 D_real=8.4236 D_fake=-3.9453 | G_loss=4.0501 Corr=0.0184
# [Epoch 42] L=50 step 1/1 | D_loss=-11.5009 GP=2.6681 D_real=9.9825 D_fake=-4.1865 | G_loss=4.0105 Corr=0.0160
# [Epoch 42] L=60 step 1/1 | D_loss=-12.3061 GP=1.3662 D_real=11.1719 D_fake=-2.5004 | G_loss=2.2922 Corr=0.0177
# [Epoch 43] L=10 step 1/1 | D_loss=-4.2866 GP=0.4137 D_real=3.6322 D_fake=-1.0681 | G_loss=1.2670 Corr=0.0216
# [Epoch 43] L=20 step 1/1 | D_loss=-6.4889 GP=0.9685 D_real=6.2257 D_fake=-1.2317 | G_loss=1.3992 Corr=0.0169
# [Epoch 43] L=30 step 1/1 | D_loss=-8.2797 GP=2.1840 D_real=8.9665 D_fake=-1.4972 | G_loss=1.6087 Corr=0.0206
# [Epoch 43] L=40 step 1/1 | D_loss=-9.8827 GP=3.1526 D_real=11.4099 D_fake=-1.6255 | G_loss=1.7431 Corr=0.0188
# [Epoch 43] L=50 step 1/1 | D_loss=-11.1876 GP=2.4757 D_real=12.1393 D_fake=-1.5240 | G_loss=1.6951 Corr=0.0169
# [Epoch 43] L=60 step 1/1 | D_loss=-12.3680 GP=2.0862 D_real=12.8118 D_fake=-1.6424 | G_loss=1.9265 Corr=0.0164
# [Epoch 44] L=10 step 1/1 | D_loss=-4.2886 GP=0.1818 D_real=3.5308 D_fake=-0.9396 | G_loss=1.1794 Corr=0.0244
# [Epoch 44] L=20 step 1/1 | D_loss=-6.8242 GP=1.0979 D_real=6.8783 D_fake=-1.0437 | G_loss=1.2453 Corr=0.0223
# [Epoch 44] L=30 step 1/1 | D_loss=-8.2563 GP=1.4040 D_real=8.4975 D_fake=-1.1628 | G_loss=1.4332 Corr=0.0212
# [Epoch 44] L=40 step 1/1 | D_loss=-9.8782 GP=2.2682 D_real=10.6083 D_fake=-1.5381 | G_loss=1.7711 Corr=0.0211
# [Epoch 44] L=50 step 1/1 | D_loss=-10.8827 GP=3.0718 D_real=11.9853 D_fake=-1.9693 | G_loss=2.0589 Corr=0.0175
# [Epoch 44] L=60 step 1/1 | D_loss=-12.6076 GP=2.8548 D_real=13.0769 D_fake=-2.3855 | G_loss=2.6794 Corr=0.0164
# [Epoch 45] L=10 step 1/1 | D_loss=-4.4521 GP=0.4719 D_real=3.3599 D_fake=-1.5642 | G_loss=1.8515 Corr=0.0248
# [Epoch 45] L=20 step 1/1 | D_loss=-6.5399 GP=0.4963 D_real=4.7912 D_fake=-2.2450 | G_loss=2.5213 Corr=0.0207
# [Epoch 45] L=30 step 1/1 | D_loss=-8.3773 GP=1.2334 D_real=6.9235 D_fake=-2.6873 | G_loss=2.9017 Corr=0.0207
# [Epoch 45] L=40 step 1/1 | D_loss=-9.6388 GP=2.4684 D_real=9.0086 D_fake=-3.0986 | G_loss=3.0489 Corr=0.0181
# [Epoch 45] L=50 step 1/1 | D_loss=-11.3825 GP=2.9638 D_real=10.4762 D_fake=-3.8701 | G_loss=3.8628 Corr=0.0159
# [Epoch 45] L=60 step 1/1 | D_loss=-12.7241 GP=2.9182 D_real=10.8977 D_fake=-4.7445 | G_loss=4.6302 Corr=0.0198
# [Epoch 46] L=10 step 1/1 | D_loss=-4.5005 GP=0.2888 D_real=2.9071 D_fake=-1.8822 | G_loss=2.1366 Corr=0.0237
# [Epoch 46] L=20 step 1/1 | D_loss=-6.6287 GP=0.9846 D_real=4.8766 D_fake=-2.7367 | G_loss=2.9037 Corr=0.0192
# [Epoch 46] L=30 step 1/1 | D_loss=-8.4451 GP=1.9118 D_real=6.7825 D_fake=-3.5745 | G_loss=3.7939 Corr=0.0196
# [Epoch 46] L=40 step 1/1 | D_loss=-10.1174 GP=2.5014 D_real=8.6107 D_fake=-4.0081 | G_loss=4.0481 Corr=0.0196
# [Epoch 46] L=50 step 1/1 | D_loss=-11.4701 GP=2.8281 D_real=10.2653 D_fake=-4.0329 | G_loss=4.0801 Corr=0.0172
# [Epoch 46] L=60 step 1/1 | D_loss=-12.8703 GP=2.5535 D_real=11.6179 D_fake=-3.8058 | G_loss=3.5763 Corr=0.0153
# [Epoch 47] L=10 step 1/1 | D_loss=-4.4213 GP=0.1958 D_real=3.2140 D_fake=-1.4030 | G_loss=1.6961 Corr=0.0293
# [Epoch 47] L=20 step 1/1 | D_loss=-6.6493 GP=1.2979 D_real=6.0586 D_fake=-1.8886 | G_loss=1.9993 Corr=0.0190
# [Epoch 47] L=30 step 1/1 | D_loss=-8.0587 GP=2.1430 D_real=7.5040 D_fake=-2.6977 | G_loss=2.8917 Corr=0.0236
# [Epoch 47] L=40 step 1/1 | D_loss=-9.7719 GP=2.2789 D_real=9.2464 D_fake=-2.8045 | G_loss=2.8418 Corr=0.0221
# [Epoch 47] L=50 step 1/1 | D_loss=-11.4930 GP=2.1916 D_real=10.8269 D_fake=-2.8576 | G_loss=2.7782 Corr=0.0186
# [Epoch 47] L=60 step 1/1 | D_loss=-12.7278 GP=2.2563 D_real=12.2986 D_fake=-2.6855 | G_loss=2.5285 Corr=0.0192
# [Epoch 48] L=10 step 1/1 | D_loss=-4.2586 GP=0.1420 D_real=3.3491 D_fake=-1.0515 | G_loss=1.3832 Corr=0.0316
# [Epoch 48] L=20 step 1/1 | D_loss=-6.4133 GP=1.7585 D_real=6.5553 D_fake=-1.6165 | G_loss=1.7817 Corr=0.0189
# [Epoch 48] L=30 step 1/1 | D_loss=-8.3188 GP=1.8166 D_real=8.1115 D_fake=-2.0239 | G_loss=2.3073 Corr=0.0215
# [Epoch 48] L=40 step 1/1 | D_loss=-9.8862 GP=2.0660 D_real=9.4040 D_fake=-2.5481 | G_loss=2.5710 Corr=0.0176
# [Epoch 48] L=50 step 1/1 | D_loss=-11.3557 GP=2.6036 D_real=11.3371 D_fake=-2.6223 | G_loss=2.6025 Corr=0.0163
# [Epoch 48] L=60 step 1/1 | D_loss=-12.8057 GP=3.5069 D_real=13.4460 D_fake=-2.8665 | G_loss=2.7278 Corr=0.0188
# [Epoch 49] L=10 step 1/1 | D_loss=-3.9870 GP=0.0596 D_real=3.0457 D_fake=-1.0009 | G_loss=1.2561 Corr=0.0266
# [Epoch 49] L=20 step 1/1 | D_loss=-6.2788 GP=2.2442 D_real=5.8984 D_fake=-2.6246 | G_loss=2.9902 Corr=0.0182
# [Epoch 49] L=30 step 1/1 | D_loss=-8.3585 GP=1.2535 D_real=6.5853 D_fake=-3.0267 | G_loss=3.1524 Corr=0.0203
# [Epoch 49] L=40 step 1/1 | D_loss=-10.0608 GP=2.1728 D_real=8.3245 D_fake=-3.9091 | G_loss=3.8863 Corr=0.0221
# [Epoch 49] L=50 step 1/1 | D_loss=-11.1841 GP=3.7312 D_real=11.2748 D_fake=-3.6405 | G_loss=3.3934 Corr=0.0204
# [Epoch 49] L=60 step 1/1 | D_loss=-12.4224 GP=3.7638 D_real=13.5351 D_fake=-2.6511 | G_loss=2.6253 Corr=0.0182
# [Epoch 50] L=10 step 1/1 | D_loss=-4.0082 GP=0.0823 D_real=3.4164 D_fake=-0.6741 | G_loss=0.9648 Corr=0.0377
# [Epoch 50] L=20 step 1/1 | D_loss=-6.2284 GP=1.3252 D_real=6.1248 D_fake=-1.4288 | G_loss=1.9844 Corr=0.0236
# [Epoch 50] L=30 step 1/1 | D_loss=-8.1113 GP=0.8552 D_real=6.3765 D_fake=-2.5900 | G_loss=2.8947 Corr=0.0235
# [Epoch 50] L=40 step 1/1 | D_loss=-9.8992 GP=2.1852 D_real=8.6055 D_fake=-3.4789 | G_loss=3.5952 Corr=0.0195
# [Epoch 50] L=50 step 1/1 | D_loss=-10.8268 GP=3.3397 D_real=9.0787 D_fake=-5.0878 | G_loss=4.9415 Corr=0.0185
# [Epoch 50] L=60 step 1/1 | D_loss=-12.4243 GP=3.9034 D_real=10.6869 D_fake=-5.6408 | G_loss=5.5325 Corr=0.0207
# [Epoch 51] L=10 step 1/1 | D_loss=-4.1428 GP=0.1213 D_real=2.0084 D_fake=-2.2557 | G_loss=2.4755 Corr=0.0233
# [Epoch 51] L=20 step 1/1 | D_loss=-6.5528 GP=1.4920 D_real=4.5543 D_fake=-3.4904 | G_loss=3.7159 Corr=0.0202
# [Epoch 51] L=30 step 1/1 | D_loss=-8.2690 GP=1.4610 D_real=5.8602 D_fake=-3.8698 | G_loss=4.0707 Corr=0.0186
# [Epoch 51] L=40 step 1/1 | D_loss=-9.9595 GP=2.8984 D_real=8.1412 D_fake=-4.7168 | G_loss=4.6472 Corr=0.0158
# [Epoch 51] L=50 step 1/1 | D_loss=-11.2375 GP=3.5834 D_real=9.6154 D_fake=-5.2055 | G_loss=5.2445 Corr=0.0172
# [Epoch 51] L=60 step 1/1 | D_loss=-12.5930 GP=3.0065 D_real=11.0666 D_fake=-4.5329 | G_loss=4.4476 Corr=0.0163
# [Epoch 52] L=10 step 1/1 | D_loss=-4.4451 GP=0.2361 D_real=2.9742 D_fake=-1.7070 | G_loss=1.8692 Corr=0.0211
# [Epoch 52] L=20 step 1/1 | D_loss=-6.6449 GP=0.9556 D_real=5.6330 D_fake=-1.9675 | G_loss=2.1579 Corr=0.0201
# [Epoch 52] L=30 step 1/1 | D_loss=-8.4509 GP=1.1242 D_real=7.4344 D_fake=-2.1407 | G_loss=2.4211 Corr=0.0247
# [Epoch 52] L=40 step 1/1 | D_loss=-10.1135 GP=1.7308 D_real=9.2529 D_fake=-2.5914 | G_loss=2.8311 Corr=0.0222
# [Epoch 52] L=50 step 1/1 | D_loss=-11.3731 GP=2.1873 D_real=10.3690 D_fake=-3.1914 | G_loss=3.3848 Corr=0.0192
# [Epoch 52] L=60 step 1/1 | D_loss=-12.0639 GP=3.3234 D_real=11.8900 D_fake=-3.4974 | G_loss=3.2961 Corr=0.0173
# [Epoch 53] L=10 step 1/1 | D_loss=-4.5669 GP=0.2838 D_real=3.1969 D_fake=-1.6538 | G_loss=1.9877 Corr=0.0315
# [Epoch 53] L=20 step 1/1 | D_loss=-6.6201 GP=0.8315 D_real=5.3523 D_fake=-2.0993 | G_loss=2.2649 Corr=0.0182
# [Epoch 53] L=30 step 1/1 | D_loss=-8.3810 GP=2.1274 D_real=8.1659 D_fake=-2.3425 | G_loss=2.5170 Corr=0.0227
# [Epoch 53] L=40 step 1/1 | D_loss=-9.8086 GP=2.5331 D_real=9.9705 D_fake=-2.3713 | G_loss=2.6230 Corr=0.0233
# [Epoch 53] L=50 step 1/1 | D_loss=-11.4122 GP=3.5088 D_real=11.7902 D_fake=-3.1308 | G_loss=3.0867 Corr=0.0218
# [Epoch 53] L=60 step 1/1 | D_loss=-12.2393 GP=3.4052 D_real=12.5603 D_fake=-3.0843 | G_loss=3.0174 Corr=0.0155
# [Epoch 54] L=10 step 1/1 | D_loss=-4.1485 GP=0.0912 D_real=3.2240 D_fake=-1.0157 | G_loss=1.2582 Corr=0.0258
# [Epoch 54] L=20 step 1/1 | D_loss=-6.3372 GP=1.9270 D_real=6.6840 D_fake=-1.5802 | G_loss=1.8316 Corr=0.0249
# [Epoch 54] L=30 step 1/1 | D_loss=-8.3083 GP=1.1824 D_real=7.5681 D_fake=-1.9226 | G_loss=2.2396 Corr=0.0186
# [Epoch 54] L=40 step 1/1 | D_loss=-9.8270 GP=1.6259 D_real=9.0874 D_fake=-2.3656 | G_loss=2.5324 Corr=0.0213
# [Epoch 54] L=50 step 1/1 | D_loss=-11.3484 GP=1.8635 D_real=10.0643 D_fake=-3.1476 | G_loss=3.2359 Corr=0.0182
# [Epoch 54] L=60 step 1/1 | D_loss=-12.7626 GP=3.1101 D_real=12.4000 D_fake=-3.4726 | G_loss=3.2217 Corr=0.0188
# [Epoch 55] L=10 step 1/1 | D_loss=-4.2832 GP=0.0977 D_real=3.7957 D_fake=-0.5853 | G_loss=0.7338 Corr=0.0223
# [Epoch 55] L=20 step 1/1 | D_loss=-6.3150 GP=1.1066 D_real=6.1951 D_fake=-1.2265 | G_loss=1.5681 Corr=0.0214
# [Epoch 55] L=30 step 1/1 | D_loss=-8.0303 GP=2.7263 D_real=8.7376 D_fake=-2.0190 | G_loss=2.2350 Corr=0.0184
# [Epoch 55] L=40 step 1/1 | D_loss=-9.9051 GP=1.9731 D_real=9.0337 D_fake=-2.8445 | G_loss=2.8713 Corr=0.0174
# [Epoch 55] L=50 step 1/1 | D_loss=-11.0381 GP=4.2429 D_real=11.4999 D_fake=-3.7811 | G_loss=3.6453 Corr=0.0177
# [Epoch 55] L=60 step 1/1 | D_loss=-12.6779 GP=3.1791 D_real=11.9264 D_fake=-3.9306 | G_loss=3.6630 Corr=0.0170
# [Epoch 56] L=10 step 1/1 | D_loss=-3.8384 GP=0.1043 D_real=2.8724 D_fake=-1.0704 | G_loss=1.2508 Corr=0.0250
# [Epoch 56] L=20 step 1/1 | D_loss=-6.0639 GP=1.2591 D_real=5.7507 D_fake=-1.5723 | G_loss=1.6460 Corr=0.0209
# [Epoch 56] L=30 step 1/1 | D_loss=-7.9411 GP=2.2527 D_real=8.9066 D_fake=-1.2872 | G_loss=1.4880 Corr=0.0230
# [Epoch 56] L=40 step 1/1 | D_loss=-9.6116 GP=2.3023 D_real=10.2166 D_fake=-1.6974 | G_loss=1.6813 Corr=0.0215
# [Epoch 56] L=50 step 1/1 | D_loss=-11.3377 GP=3.0271 D_real=12.6669 D_fake=-1.6979 | G_loss=1.8378 Corr=0.0205
# [Epoch 56] L=60 step 1/1 | D_loss=-12.5147 GP=3.0189 D_real=13.5640 D_fake=-1.9697 | G_loss=1.9586 Corr=0.0190
# [Epoch 57] L=10 step 1/1 | D_loss=-4.3303 GP=0.1818 D_real=3.8852 D_fake=-0.6269 | G_loss=0.8095 Corr=0.0229
# [Epoch 57] L=20 step 1/1 | D_loss=-6.5604 GP=1.4652 D_real=7.3347 D_fake=-0.6909 | G_loss=0.8788 Corr=0.0185
# [Epoch 57] L=30 step 1/1 | D_loss=-8.0888 GP=1.1832 D_real=8.5918 D_fake=-0.6802 | G_loss=0.9051 Corr=0.0168
# [Epoch 57] L=40 step 1/1 | D_loss=-9.9113 GP=2.2365 D_real=10.8316 D_fake=-1.3161 | G_loss=1.4287 Corr=0.0167
# [Epoch 57] L=50 step 1/1 | D_loss=-10.9606 GP=4.0225 D_real=13.2202 D_fake=-1.7629 | G_loss=1.6612 Corr=0.0167
# [Epoch 57] L=60 step 1/1 | D_loss=-12.5891 GP=3.5827 D_real=14.2927 D_fake=-1.8792 | G_loss=1.9528 Corr=0.0169
# [Epoch 58] L=10 step 1/1 | D_loss=-4.2973 GP=0.1079 D_real=3.4741 D_fake=-0.9310 | G_loss=1.0831 Corr=0.0208
# [Epoch 58] L=20 step 1/1 | D_loss=-6.5015 GP=1.3731 D_real=6.9692 D_fake=-0.9055 | G_loss=1.0987 Corr=0.0193
# [Epoch 58] L=30 step 1/1 | D_loss=-8.3373 GP=1.3237 D_real=8.6702 D_fake=-0.9909 | G_loss=1.2484 Corr=0.0206
# [Epoch 58] L=40 step 1/1 | D_loss=-9.9145 GP=2.3005 D_real=10.3043 D_fake=-1.9107 | G_loss=2.0280 Corr=0.0188
# [Epoch 58] L=50 step 1/1 | D_loss=-11.2493 GP=3.2630 D_real=12.5702 D_fake=-1.9421 | G_loss=1.9424 Corr=0.0169
# [Epoch 58] L=60 step 1/1 | D_loss=-12.4438 GP=2.6615 D_real=13.0703 D_fake=-2.0350 | G_loss=2.0939 Corr=0.0142
# [Epoch 59] L=10 step 1/1 | D_loss=-4.2380 GP=0.1256 D_real=3.3981 D_fake=-0.9656 | G_loss=1.1673 Corr=0.0238
# [Epoch 59] L=20 step 1/1 | D_loss=-6.6091 GP=1.2703 D_real=6.7331 D_fake=-1.1463 | G_loss=1.3546 Corr=0.0167
# [Epoch 59] L=30 step 1/1 | D_loss=-8.2252 GP=1.2719 D_real=8.2779 D_fake=-1.2192 | G_loss=1.3776 Corr=0.0169
# [Epoch 59] L=40 step 1/1 | D_loss=-9.8470 GP=2.8053 D_real=10.6401 D_fake=-2.0122 | G_loss=2.0859 Corr=0.0167
# [Epoch 59] L=50 step 1/1 | D_loss=-11.2155 GP=3.3454 D_real=12.0099 D_fake=-2.5511 | G_loss=2.7057 Corr=0.0169
# [Epoch 59] L=60 step 1/1 | D_loss=-12.5824 GP=3.1356 D_real=13.0362 D_fake=-2.6817 | G_loss=2.6657 Corr=0.0169
# [Epoch 60] L=10 step 1/1 | D_loss=-4.3786 GP=0.1265 D_real=3.4237 D_fake=-1.0814 | G_loss=1.2651 Corr=0.0218
# [Epoch 60] L=20 step 1/1 | D_loss=-6.5847 GP=1.0902 D_real=6.3652 D_fake=-1.3097 | G_loss=1.5342 Corr=0.0172
# [Epoch 60] L=30 step 1/1 | D_loss=-8.3016 GP=1.5061 D_real=8.1545 D_fake=-1.6532 | G_loss=1.8139 Corr=0.0177
# [Epoch 60] L=40 step 1/1 | D_loss=-9.8827 GP=2.4949 D_real=9.5814 D_fake=-2.7961 | G_loss=2.8150 Corr=0.0163
# [Epoch 60] L=50 step 1/1 | D_loss=-11.4087 GP=2.9229 D_real=10.9248 D_fake=-3.4068 | G_loss=3.3577 Corr=0.0163
# [Epoch 60] L=60 step 1/1 | D_loss=-12.6595 GP=2.8994 D_real=11.6748 D_fake=-3.8841 | G_loss=3.4614 Corr=0.0164
# [Epoch 61] L=10 step 1/1 | D_loss=-4.4766 GP=0.2622 D_real=3.5445 D_fake=-1.1943 | G_loss=1.3427 Corr=0.0196
# [Epoch 61] L=20 step 1/1 | D_loss=-6.5925 GP=0.8328 D_real=6.1860 D_fake=-1.2394 | G_loss=1.3914 Corr=0.0166
# [Epoch 61] L=30 step 1/1 | D_loss=-8.1815 GP=2.2768 D_real=8.9188 D_fake=-1.5395 | G_loss=1.6358 Corr=0.0176
# [Epoch 61] L=40 step 1/1 | D_loss=-9.8034 GP=2.3578 D_real=10.3055 D_fake=-1.8556 | G_loss=2.0769 Corr=0.0174
# [Epoch 61] L=50 step 1/1 | D_loss=-11.3251 GP=2.9505 D_real=12.2925 D_fake=-1.9832 | G_loss=1.9813 Corr=0.0170
# [Epoch 61] L=60 step 1/1 | D_loss=-12.2454 GP=3.9585 D_real=13.3296 D_fake=-2.8744 | G_loss=2.7451 Corr=0.0158
# [Epoch 62] L=10 step 1/1 | D_loss=-4.1869 GP=0.0525 D_real=3.0672 D_fake=-1.1722 | G_loss=1.3461 Corr=0.0200
# [Epoch 62] L=20 step 1/1 | D_loss=-6.4758 GP=1.5213 D_real=6.3737 D_fake=-1.6235 | G_loss=1.7426 Corr=0.0161
# [Epoch 62] L=30 step 1/1 | D_loss=-8.2625 GP=1.9069 D_real=8.1696 D_fake=-1.9997 | G_loss=2.2081 Corr=0.0164
# [Epoch 62] L=40 step 1/1 | D_loss=-9.8139 GP=2.4457 D_real=9.5814 D_fake=-2.6781 | G_loss=2.7533 Corr=0.0158
# [Epoch 62] L=50 step 1/1 | D_loss=-10.9132 GP=3.4400 D_real=11.5740 D_fake=-2.7792 | G_loss=2.6747 Corr=0.0158
# [Epoch 62] L=60 step 1/1 | D_loss=-12.4706 GP=3.9153 D_real=13.4103 D_fake=-2.9755 | G_loss=2.8040 Corr=0.0146
# [Epoch 63] L=10 step 1/1 | D_loss=-3.7954 GP=0.0706 D_real=2.9829 D_fake=-0.8831 | G_loss=0.9962 Corr=0.0197
# [Epoch 63] L=20 step 1/1 | D_loss=-6.2824 GP=1.8623 D_real=6.9960 D_fake=-1.1487 | G_loss=1.4099 Corr=0.0182
# [Epoch 63] L=30 step 1/1 | D_loss=-8.1717 GP=1.2591 D_real=8.5310 D_fake=-0.8998 | G_loss=1.0078 Corr=0.0206
# [Epoch 63] L=40 step 1/1 | D_loss=-9.5976 GP=2.7373 D_real=11.1000 D_fake=-1.2350 | G_loss=1.1651 Corr=0.0175
# [Epoch 63] L=50 step 1/1 | D_loss=-11.3178 GP=3.3410 D_real=13.0464 D_fake=-1.6124 | G_loss=1.7438 Corr=0.0172
# [Epoch 63] L=60 step 1/1 | D_loss=-12.4826 GP=3.8886 D_real=14.3499 D_fake=-2.0213 | G_loss=1.9110 Corr=0.0160
# [Epoch 64] L=10 step 1/1 | D_loss=-4.1083 GP=0.0855 D_real=3.6931 D_fake=-0.5008 | G_loss=0.6822 Corr=0.0216
# [Epoch 64] L=20 step 1/1 | D_loss=-6.4678 GP=1.5989 D_real=7.1809 D_fake=-0.8858 | G_loss=1.2275 Corr=0.0193
# [Epoch 64] L=30 step 1/1 | D_loss=-8.1794 GP=1.0572 D_real=8.1354 D_fake=-1.1011 | G_loss=1.2272 Corr=0.0178
# [Epoch 64] L=40 step 1/1 | D_loss=-9.6420 GP=3.2812 D_real=11.3151 D_fake=-1.6081 | G_loss=1.7388 Corr=0.0178
# [Epoch 64] L=50 step 1/1 | D_loss=-11.1873 GP=3.5992 D_real=12.7212 D_fake=-2.0653 | G_loss=2.2024 Corr=0.0177
# [Epoch 64] L=60 step 1/1 | D_loss=-12.3938 GP=3.1268 D_real=13.4362 D_fake=-2.0844 | G_loss=1.9862 Corr=0.0164
# [Epoch 65] L=10 step 1/1 | D_loss=-4.2019 GP=0.0750 D_real=3.6298 D_fake=-0.6470 | G_loss=0.8266 Corr=0.0220
# [Epoch 65] L=20 step 1/1 | D_loss=-6.6740 GP=1.5187 D_real=7.5029 D_fake=-0.6898 | G_loss=0.8976 Corr=0.0167
# [Epoch 65] L=30 step 1/1 | D_loss=-8.1165 GP=0.9393 D_real=8.4522 D_fake=-0.6036 | G_loss=0.8566 Corr=0.0189
# [Epoch 65] L=40 step 1/1 | D_loss=-9.7430 GP=2.2748 D_real=10.5384 D_fake=-1.4794 | G_loss=1.6370 Corr=0.0165
# [Epoch 65] L=50 step 1/1 | D_loss=-10.9043 GP=3.9420 D_real=13.1438 D_fake=-1.7025 | G_loss=1.8265 Corr=0.0167
# [Epoch 65] L=60 step 1/1 | D_loss=-12.6457 GP=2.8681 D_real=13.6499 D_fake=-1.8639 | G_loss=2.0504 Corr=0.0165
# [Epoch 66] L=10 step 1/1 | D_loss=-4.3008 GP=0.1827 D_real=3.4662 D_fake=-1.0173 | G_loss=1.2405 Corr=0.0246
# [Epoch 66] L=20 step 1/1 | D_loss=-6.5470 GP=0.7746 D_real=6.2144 D_fake=-1.1071 | G_loss=1.3227 Corr=0.0202
# [Epoch 66] L=30 step 1/1 | D_loss=-8.3202 GP=1.4411 D_real=8.4818 D_fake=-1.2796 | G_loss=1.4898 Corr=0.0215
# [Epoch 66] L=40 step 1/1 | D_loss=-9.8219 GP=2.2047 D_real=10.2447 D_fake=-1.7819 | G_loss=1.8770 Corr=0.0186
# [Epoch 66] L=50 step 1/1 | D_loss=-10.9512 GP=2.8809 D_real=11.8646 D_fake=-1.9674 | G_loss=2.0171 Corr=0.0193
# [Epoch 66] L=60 step 1/1 | D_loss=-12.5051 GP=3.0028 D_real=13.7442 D_fake=-1.7637 | G_loss=1.6286 Corr=0.0182
# [Epoch 67] L=10 step 1/1 | D_loss=-4.4155 GP=0.3768 D_real=4.1899 D_fake=-0.6024 | G_loss=0.8166 Corr=0.0242
# [Epoch 67] L=20 step 1/1 | D_loss=-6.3490 GP=0.4349 D_real=6.4718 D_fake=-0.3121 | G_loss=0.5180 Corr=0.0203
# [Epoch 67] L=30 step 1/1 | D_loss=-8.0623 GP=2.2918 D_real=9.7590 D_fake=-0.5950 | G_loss=0.7758 Corr=0.0204
# [Epoch 67] L=40 step 1/1 | D_loss=-9.4183 GP=2.5472 D_real=10.9431 D_fake=-1.0224 | G_loss=1.3361 Corr=0.0219
# [Epoch 67] L=50 step 1/1 | D_loss=-11.0332 GP=2.4704 D_real=12.1936 D_fake=-1.3099 | G_loss=1.2975 Corr=0.0184
# [Epoch 67] L=60 step 1/1 | D_loss=-12.5378 GP=2.2937 D_real=14.4222 D_fake=-0.4093 | G_loss=0.5162 Corr=0.0190
# [Epoch 68] L=10 step 1/1 | D_loss=-4.1101 GP=0.1924 D_real=4.0931 D_fake=-0.2095 | G_loss=0.3903 Corr=0.0230
# [Epoch 68] L=20 step 1/1 | D_loss=-6.4149 GP=1.3523 D_real=7.7497 D_fake=-0.0175 | G_loss=0.2461 Corr=0.0202
# [Epoch 68] L=30 step 1/1 | D_loss=-8.1681 GP=1.1062 D_real=9.1306 D_fake=-0.1438 | G_loss=0.5268 Corr=0.0201
# [Epoch 68] L=40 step 1/1 | D_loss=-9.3636 GP=2.0532 D_real=10.3580 D_fake=-1.0588 | G_loss=1.0315 Corr=0.0217
# [Epoch 68] L=50 step 1/1 | D_loss=-10.6678 GP=3.6381 D_real=12.3306 D_fake=-1.9754 | G_loss=1.9113 Corr=0.0203
# [Epoch 68] L=60 step 1/1 | D_loss=-12.1039 GP=4.1708 D_real=14.2451 D_fake=-2.0296 | G_loss=2.1191 Corr=0.0188
# [Epoch 69] L=10 step 1/1 | D_loss=-4.1334 GP=0.1849 D_real=3.3511 D_fake=-0.9673 | G_loss=1.2172 Corr=0.0255
# [Epoch 69] L=20 step 1/1 | D_loss=-6.3185 GP=1.0751 D_real=6.4825 D_fake=-0.9110 | G_loss=1.2124 Corr=0.0333
# [Epoch 69] L=30 step 1/1 | D_loss=-8.0047 GP=1.9212 D_real=9.1315 D_fake=-0.7944 | G_loss=1.0022 Corr=0.0316
# [Epoch 69] L=40 step 1/1 | D_loss=-9.6141 GP=2.2695 D_real=11.2964 D_fake=-0.5872 | G_loss=0.8259 Corr=0.0281
# [Epoch 69] L=50 step 1/1 | D_loss=-10.8203 GP=2.4300 D_real=13.0003 D_fake=-0.2499 | G_loss=0.3702 Corr=0.0251
# [Epoch 69] L=60 step 1/1 | D_loss=-11.9401 GP=2.7232 D_real=14.8478 D_fake=0.1845 | G_loss=-0.2881 Corr=0.0293
# [Epoch 70] L=10 step 1/1 | D_loss=-3.8146 GP=0.0691 D_real=4.4891 D_fake=0.6055 | G_loss=-0.3266 Corr=0.0299
# [Epoch 70] L=20 step 1/1 | D_loss=-5.9675 GP=1.0743 D_real=7.9059 D_fake=0.8641 | G_loss=0.2307 Corr=0.0511
# [Epoch 70] L=30 step 1/1 | D_loss=-8.8835 GP=1.6665 D_real=10.1836 D_fake=-0.3664 | G_loss=0.6833 Corr=0.0564
# [Epoch 70] L=40 step 1/1 | D_loss=-7.5726 GP=2.4586 D_real=13.1844 D_fake=3.1531 | G_loss=-2.7711 Corr=0.0326
# [Epoch 70] L=50 step 1/1 | D_loss=-8.3133 GP=2.2439 D_real=13.6205 D_fake=3.0634 | G_loss=-2.1466 Corr=0.0491
# [Epoch 70] L=60 step 1/1 | D_loss=-10.5690 GP=1.9267 D_real=14.4202 D_fake=1.9245 | G_loss=-1.1410 Corr=0.0691
# [Epoch 71] L=10 step 1/1 | D_loss=-3.1983 GP=0.2530 D_real=4.2816 D_fake=0.8303 | G_loss=-0.0230 Corr=0.0851
# [Epoch 71] L=20 step 1/1 | D_loss=-4.4716 GP=1.5538 D_real=6.8326 D_fake=0.8072 | G_loss=0.1332 Corr=0.0828
# [Epoch 71] L=30 step 1/1 | D_loss=-6.7710 GP=1.0401 D_real=8.2778 D_fake=0.4667 | G_loss=0.4557 Corr=0.0835
# [Epoch 71] L=40 step 1/1 | D_loss=-8.8447 GP=2.2773 D_real=11.9686 D_fake=0.8466 | G_loss=-0.3410 Corr=0.0718
# [Epoch 71] L=50 step 1/1 | D_loss=-10.3663 GP=2.8296 D_real=14.1854 D_fake=0.9895 | G_loss=-0.4120 Corr=0.0635
# [Epoch 71] L=60 step 1/1 | D_loss=-11.3433 GP=1.8028 D_real=15.1769 D_fake=2.0308 | G_loss=-1.6303 Corr=0.0586
# [Epoch 72] L=10 step 1/1 | D_loss=-3.6449 GP=0.2009 D_real=5.6943 D_fake=1.8486 | G_loss=-1.0005 Corr=0.0923
# [Epoch 72] L=20 step 1/1 | D_loss=-5.9983 GP=0.4686 D_real=8.4957 D_fake=2.0288 | G_loss=-1.0083 Corr=0.0646
# [Epoch 72] L=30 step 1/1 | D_loss=-7.9124 GP=2.1824 D_real=11.3213 D_fake=1.2265 | G_loss=-0.8275 Corr=0.0583
# [Epoch 72] L=40 step 1/1 | D_loss=-9.6096 GP=1.5259 D_real=12.2121 D_fake=1.0767 | G_loss=-0.3759 Corr=0.0507
# [Epoch 72] L=50 step 1/1 | D_loss=-10.9069 GP=3.3990 D_real=14.6623 D_fake=0.3564 | G_loss=-0.0326 Corr=0.0475
# [Epoch 72] L=60 step 1/1 | D_loss=-12.1211 GP=2.8949 D_real=15.0421 D_fake=0.0261 | G_loss=0.7862 Corr=0.0484
# [Epoch 73] L=10 step 1/1 | D_loss=-4.0025 GP=0.1435 D_real=4.5490 D_fake=0.4030 | G_loss=0.3146 Corr=0.0783
# ...
# [Epoch 76] L=60 step 1/1 | D_loss=-12.2429 GP=3.6723 D_real=15.6046 D_fake=-0.3107 | G_loss=0.4228 Corr=0.0325
# [Epoch 77] L=10 step 1/1 | D_loss=-4.4210 GP=0.3062 D_real=5.4961 D_fake=0.7688 | G_loss=-0.4563 Corr=0.0350
# [Epoch 77] L=20 step 1/1 | D_loss=-6.3891 GP=0.5665 D_real=8.4386 D_fake=1.4830 | G_loss=-1.1836 Corr=0.0335
# [Epoch 77] L=30 step 1/1 | D_loss=-8.0434 GP=2.2239 D_real=11.5691 D_fake=1.3017 | G_loss=-0.9234 Corr=0.0341
# [Epoch 77] L=40 step 1/1 | D_loss=-9.4446 GP=1.3886 D_real=11.7689 D_fake=0.9357 | G_loss=-0.4800 Corr=0.0325
# [Epoch 77] L=50 step 1/1 | D_loss=-10.9481 GP=3.0491 D_real=13.6794 D_fake=-0.3178 | G_loss=0.6699 Corr=0.0306
# [Epoch 77] L=60 step 1/1 | D_loss=-12.4788 GP=2.8880 D_real=14.5027 D_fake=-0.8642 | G_loss=1.3211 Corr=0.0284
# [Epoch 78] L=10 step 1/1 | D_loss=-4.3420 GP=0.2174 D_real=4.6057 D_fake=0.0463 | G_loss=0.4499 Corr=0.0499
# [Epoch 78] L=20 step 1/1 | D_loss=-6.4325 GP=0.4969 D_real=6.6036 D_fake=-0.3259 | G_loss=0.7133 Corr=0.0327
# [Epoch 78] L=30 step 1/1 | D_loss=-8.0443 GP=1.9056 D_real=8.8324 D_fake=-1.1175 | G_loss=1.4158 Corr=0.0333
# [Epoch 78] L=40 step 1/1 | D_loss=-9.6496 GP=1.9880 D_real=10.6375 D_fake=-1.0001 | G_loss=1.3230 Corr=0.0329
# [Epoch 78] L=50 step 1/1 | D_loss=-11.2012 GP=3.4693 D_real=13.1398 D_fake=-1.5308 | G_loss=1.6266 Corr=0.0354
# [Epoch 78] L=60 step 1/1 | D_loss=-12.2192 GP=3.0750 D_real=14.1606 D_fake=-1.1336 | G_loss=1.4628 Corr=0.0353
# [Epoch 79] L=10 step 1/1 | D_loss=-4.2592 GP=0.2542 D_real=4.5689 D_fake=0.0554 | G_loss=0.3550 Corr=0.0417
# [Epoch 79] L=20 step 1/1 | D_loss=-6.2576 GP=0.4446 D_real=6.7710 D_fake=0.0689 | G_loss=0.2703 Corr=0.0318
# [Epoch 79] L=30 step 1/1 | D_loss=-8.0914 GP=1.7442 D_real=9.6063 D_fake=-0.2292 | G_loss=0.5147 Corr=0.0313
# [Epoch 79] L=40 step 1/1 | D_loss=-9.6069 GP=2.1152 D_real=11.4130 D_fake=-0.3091 | G_loss=0.5685 Corr=0.0315
# [Epoch 79] L=50 step 1/1 | D_loss=-11.0357 GP=2.5113 D_real=13.1536 D_fake=-0.3934 | G_loss=0.8252 Corr=0.0331
# [Epoch 79] L=60 step 1/1 | D_loss=-12.0727 GP=3.5390 D_real=14.3098 D_fake=-1.3018 | G_loss=1.5429 Corr=0.0349
# [Epoch 80] L=10 step 1/1 | D_loss=-4.2191 GP=0.2312 D_real=4.8408 D_fake=0.3905 | G_loss=0.0491 Corr=0.0485
# [Epoch 80] L=20 step 1/1 | D_loss=-6.3958 GP=0.6908 D_real=7.7605 D_fake=0.6738 | G_loss=-0.2979 Corr=0.0348
# [Epoch 80] L=30 step 1/1 | D_loss=-8.1116 GP=1.6330 D_real=9.9440 D_fake=0.1994 | G_loss=0.2001 Corr=0.0353
# [Epoch 80] L=40 step 1/1 | D_loss=-9.1798 GP=2.1869 D_real=11.0786 D_fake=-0.2880 | G_loss=0.5991 Corr=0.0347
# [Epoch 80] L=50 step 1/1 | D_loss=-11.1336 GP=2.6325 D_real=13.8348 D_fake=0.0687 | G_loss=0.1584 Corr=0.0338
# [Epoch 80] L=60 step 1/1 | D_loss=-12.0906 GP=3.4259 D_real=15.0085 D_fake=-0.5080 | G_loss=0.5788 Corr=0.0330
# [Epoch 81] L=10 step 1/1 | D_loss=-4.1715 GP=0.1497 D_real=5.0998 D_fake=0.7786 | G_loss=-0.3858 Corr=0.0430
# [Epoch 81] L=20 step 1/1 | D_loss=-6.3261 GP=1.0247 D_real=8.4987 D_fake=1.1479 | G_loss=-0.7589 Corr=0.0354
# [Epoch 81] L=30 step 1/1 | D_loss=-7.8593 GP=2.0598 D_real=10.4849 D_fake=0.5658 | G_loss=-0.1826 Corr=0.0386
# [Epoch 81] L=40 step 1/1 | D_loss=-9.5063 GP=2.0976 D_real=11.6882 D_fake=0.0843 | G_loss=0.1546 Corr=0.0364
# [Epoch 81] L=50 step 1/1 | D_loss=-10.9295 GP=3.1744 D_real=13.9365 D_fake=-0.1674 | G_loss=0.4401 Corr=0.0370
# [Epoch 81] L=60 step 1/1 | D_loss=-12.2694 GP=3.4436 D_real=14.8295 D_fake=-0.8836 | G_loss=1.0434 Corr=0.0335
# [Epoch 82] L=10 step 1/1 | D_loss=-3.7635 GP=0.0870 D_real=4.4095 D_fake=0.5590 | G_loss=-0.1854 Corr=0.0352
# [Epoch 82] L=20 step 1/1 | D_loss=-5.9627 GP=1.6068 D_real=7.9595 D_fake=0.3900 | G_loss=-0.0832 Corr=0.0338
# [Epoch 82] L=30 step 1/1 | D_loss=-7.9585 GP=1.2842 D_real=9.5061 D_fake=0.2634 | G_loss=0.1939 Corr=0.0402
# [Epoch 82] L=40 step 1/1 | D_loss=-9.4188 GP=2.1935 D_real=11.6334 D_fake=0.0211 | G_loss=0.1861 Corr=0.0349
# [Epoch 82] L=50 step 1/1 | D_loss=-10.4358 GP=2.3016 D_real=13.2642 D_fake=0.5269 | G_loss=-0.1328 Corr=0.0331
# [Epoch 82] L=60 step 1/1 | D_loss=-11.9487 GP=3.5303 D_real=15.5559 D_fake=0.0769 | G_loss=-0.3430 Corr=0.0376
# [Epoch 83] L=10 step 1/1 | D_loss=-3.6442 GP=0.2142 D_real=5.1619 D_fake=1.3035 | G_loss=-0.9180 Corr=0.0456
# [Epoch 83] L=20 step 1/1 | D_loss=-6.0645 GP=1.8409 D_real=9.9365 D_fake=2.0311 | G_loss=-1.5970 Corr=0.0435
# [Epoch 83] L=30 step 1/1 | D_loss=-7.6573 GP=1.0052 D_real=11.0012 D_fake=2.3386 | G_loss=-1.7715 Corr=0.0432
# [Epoch 83] L=40 step 1/1 | D_loss=-9.3208 GP=2.9463 D_real=14.0045 D_fake=1.7373 | G_loss=-1.3612 Corr=0.0354
# [Epoch 83] L=50 step 1/1 | D_loss=-10.9132 GP=2.7350 D_real=15.1029 D_fake=1.4548 | G_loss=-0.9265 Corr=0.0364
# [Epoch 83] L=60 step 1/1 | D_loss=-12.2601 GP=3.4041 D_real=16.4869 D_fake=0.8227 | G_loss=-0.5966 Corr=0.0412
# [Epoch 84] L=10 step 1/1 | D_loss=-3.6116 GP=0.1368 D_real=4.6042 D_fake=0.8558 | G_loss=-0.4630 Corr=0.0444
# [Epoch 84] L=20 step 1/1 | D_loss=-6.0233 GP=1.1358 D_real=8.6063 D_fake=1.4472 | G_loss=-1.1012 Corr=0.0375
# [Epoch 84] L=30 step 1/1 | D_loss=-7.8749 GP=1.0669 D_real=11.0264 D_fake=2.0845 | G_loss=-1.6036 Corr=0.0464
# [Epoch 84] L=40 step 1/1 | D_loss=-8.8868 GP=3.4338 D_real=13.7416 D_fake=1.4210 | G_loss=-1.0738 Corr=0.0456
# [Epoch 84] L=50 step 1/1 | D_loss=-10.5129 GP=2.3363 D_real=13.9760 D_fake=1.1267 | G_loss=-0.4129 Corr=0.0401
# [Epoch 84] L=60 step 1/1 | D_loss=-12.1352 GP=2.8379 D_real=15.4479 D_fake=0.4748 | G_loss=-0.3050 Corr=0.0416
# [Epoch 85] L=10 step 1/1 | D_loss=-3.9543 GP=0.1134 D_real=5.6300 D_fake=1.5623 | G_loss=-1.0650 Corr=0.0554
# [Epoch 85] L=20 step 1/1 | D_loss=-6.2078 GP=1.0237 D_real=9.0202 D_fake=1.7886 | G_loss=-1.2319 Corr=0.0467
# [Epoch 85] L=30 step 1/1 | D_loss=-7.9593 GP=1.4170 D_real=11.6339 D_fake=2.2575 | G_loss=-1.8303 Corr=0.0477
# [Epoch 85] L=40 step 1/1 | D_loss=-9.6023 GP=2.5562 D_real=14.4175 D_fake=2.2590 | G_loss=-1.8316 Corr=0.0487
# [Epoch 85] L=50 step 1/1 | D_loss=-11.3153 GP=2.5356 D_real=16.2086 D_fake=2.3577 | G_loss=-1.9288 Corr=0.0473
# [Epoch 85] L=60 step 1/1 | D_loss=-12.4740 GP=3.4901 D_real=17.7871 D_fake=1.8231 | G_loss=-1.2719 Corr=0.0441
# [Epoch 86] L=10 step 1/1 | D_loss=-4.2808 GP=0.1958 D_real=5.8047 D_fake=1.3281 | G_loss=-0.8661 Corr=0.0468
# [Epoch 86] L=20 step 1/1 | D_loss=-6.5090 GP=0.7755 D_real=9.0453 D_fake=1.7607 | G_loss=-1.3437 Corr=0.0422
# [Epoch 86] L=30 step 1/1 | D_loss=-8.0415 GP=1.1757 D_real=11.1460 D_fake=1.9288 | G_loss=-1.4460 Corr=0.0411
# [Epoch 86] L=40 step 1/1 | D_loss=-9.5864 GP=2.6384 D_real=13.6399 D_fake=1.4151 | G_loss=-1.0469 Corr=0.0373
# [Epoch 86] L=50 step 1/1 | D_loss=-11.1907 GP=2.4009 D_real=15.1531 D_fake=1.5615 | G_loss=-1.1066 Corr=0.0347
# [Epoch 86] L=60 step 1/1 | D_loss=-11.7379 GP=3.2038 D_real=16.4373 D_fake=1.4957 | G_loss=-1.2366 Corr=0.0395
# [Epoch 87] L=10 step 1/1 | D_loss=-4.2392 GP=0.3587 D_real=5.9006 D_fake=1.3028 | G_loss=-0.8146 Corr=0.0511
# [Epoch 87] L=20 step 1/1 | D_loss=-6.1864 GP=0.4392 D_real=8.7336 D_fake=2.1080 | G_loss=-1.6827 Corr=0.0408
# [Epoch 87] L=30 step 1/1 | D_loss=-7.8636 GP=2.2154 D_real=12.2106 D_fake=2.1316 | G_loss=-1.7246 Corr=0.0445
# [Epoch 87] L=40 step 1/1 | D_loss=-9.3648 GP=1.8375 D_real=13.3122 D_fake=2.1099 | G_loss=-1.4781 Corr=0.0423
# [Epoch 87] L=50 step 1/1 | D_loss=-10.7764 GP=2.2163 D_real=14.4896 D_fake=1.4970 | G_loss=-0.9155 Corr=0.0497
# [Epoch 87] L=60 step 1/1 | D_loss=-11.6242 GP=3.2524 D_real=15.7270 D_fake=0.8504 | G_loss=-0.5029 Corr=0.0440
# [Epoch 88] L=10 step 1/1 | D_loss=-4.0280 GP=0.1937 D_real=5.6073 D_fake=1.3856 | G_loss=-0.9207 Corr=0.0506
# [Epoch 88] L=20 step 1/1 | D_loss=-6.0589 GP=0.7143 D_real=8.6947 D_fake=1.9215 | G_loss=-1.3668 Corr=0.0493
# [Epoch 88] L=30 step 1/1 | D_loss=-7.8382 GP=1.9395 D_real=11.1169 D_fake=1.3393 | G_loss=-0.8418 Corr=0.0461
# [Epoch 88] L=40 step 1/1 | D_loss=-9.3697 GP=2.1258 D_real=12.5301 D_fake=1.0347 | G_loss=-0.6586 Corr=0.0436
# [Epoch 88] L=50 step 1/1 | D_loss=-10.9186 GP=2.8538 D_real=14.4176 D_fake=0.6452 | G_loss=-0.2485 Corr=0.0454
# [Epoch 88] L=60 step 1/1 | D_loss=-12.3915 GP=3.5128 D_real=16.3873 D_fake=0.4830 | G_loss=-0.0918 Corr=0.0430
# [Epoch 89] L=10 step 1/1 | D_loss=-3.9883 GP=0.0706 D_real=5.1114 D_fake=1.0525 | G_loss=-0.5398 Corr=0.0507
# [Epoch 89] L=20 step 1/1 | D_loss=-6.4309 GP=1.2344 D_real=8.7502 D_fake=1.0849 | G_loss=-0.6080 Corr=0.0456
# [Epoch 89] L=30 step 1/1 | D_loss=-8.2181 GP=1.2600 D_real=10.6147 D_fake=1.1366 | G_loss=-0.7005 Corr=0.0419
# [Epoch 89] L=40 step 1/1 | D_loss=-9.5471 GP=2.3280 D_real=12.9293 D_fake=1.0542 | G_loss=-0.6770 Corr=0.0367
# [Epoch 89] L=50 step 1/1 | D_loss=-10.2751 GP=2.8009 D_real=13.6936 D_fake=0.6177 | G_loss=-0.1492 Corr=0.0427
# [Epoch 89] L=60 step 1/1 | D_loss=-11.4217 GP=3.0000 D_real=14.8813 D_fake=0.4596 | G_loss=0.2216 Corr=0.0463
# [Epoch 90] L=10 step 1/1 | D_loss=-4.0107 GP=0.2041 D_real=4.9660 D_fake=0.7512 | G_loss=-0.2503 Corr=0.0513
# [Epoch 90] L=20 step 1/1 | D_loss=-6.1184 GP=0.7277 D_real=7.6811 D_fake=0.8350 | G_loss=-0.3884 Corr=0.0465
# [Epoch 90] L=30 step 1/1 | D_loss=-7.7596 GP=1.1813 D_real=9.7252 D_fake=0.7843 | G_loss=-0.2302 Corr=0.0467
# [Epoch 90] L=40 step 1/1 | D_loss=-8.9470 GP=2.4060 D_real=11.4711 D_fake=0.1181 | G_loss=0.3966 Corr=0.0484
# [Epoch 90] L=50 step 1/1 | D_loss=-10.0456 GP=3.2161 D_real=12.8871 D_fake=-0.3747 | G_loss=0.6982 Corr=0.0463
# [Epoch 90] L=60 step 1/1 | D_loss=-11.6535 GP=3.1147 D_real=14.6184 D_fake=-0.1499 | G_loss=0.6673 Corr=0.0492
# [Epoch 91] L=10 step 1/1 | D_loss=-3.9561 GP=0.2499 D_real=4.7165 D_fake=0.5105 | G_loss=0.0120 Corr=0.0485
# [Epoch 91] L=20 step 1/1 | D_loss=-5.8614 GP=0.3798 D_real=6.5951 D_fake=0.3538 | G_loss=0.2599 Corr=0.0551
# [Epoch 91] L=30 step 1/1 | D_loss=-7.4825 GP=1.4703 D_real=9.0947 D_fake=0.1419 | G_loss=0.3536 Corr=0.0534
# [Epoch 91] L=40 step 1/1 | D_loss=-8.8580 GP=2.1318 D_real=10.8751 D_fake=-0.1147 | G_loss=0.7378 Corr=0.0530
# [Epoch 91] L=50 step 1/1 | D_loss=-9.5689 GP=2.2004 D_real=11.3533 D_fake=-0.4159 | G_loss=1.0713 Corr=0.0562
# [Epoch 91] L=60 step 1/1 | D_loss=-10.1577 GP=2.9536 D_real=12.5593 D_fake=-0.5519 | G_loss=1.3058 Corr=0.0731
# [Epoch 92] L=10 step 1/1 | D_loss=-3.7643 GP=0.2167 D_real=4.5626 D_fake=0.5816 | G_loss=0.0014 Corr=0.0575
# [Epoch 92] L=20 step 1/1 | D_loss=-5.2564 GP=0.6776 D_real=6.4554 D_fake=0.5214 | G_loss=0.2732 Corr=0.0744
# [Epoch 92] L=30 step 1/1 | D_loss=-6.6520 GP=1.4238 D_real=7.3716 D_fake=-0.7042 | G_loss=1.5808 Corr=0.0848
# [Epoch 92] L=40 step 1/1 | D_loss=-7.9674 GP=2.0679 D_real=9.4585 D_fake=-0.5767 | G_loss=1.2951 Corr=0.0764
# [Epoch 92] L=50 step 1/1 | D_loss=-9.4412 GP=2.0490 D_real=10.1068 D_fake=-1.3834 | G_loss=2.1145 Corr=0.0865
# [Epoch 92] L=60 step 1/1 | D_loss=-10.0990 GP=1.7272 D_real=10.3212 D_fake=-1.5050 | G_loss=2.1746 Corr=0.0796
# [Epoch 93] L=10 step 1/1 | D_loss=-3.6801 GP=0.3877 D_real=5.2534 D_fake=1.1856 | G_loss=-0.4814 Corr=0.0782
# [Epoch 93] L=20 step 1/1 | D_loss=-5.2013 GP=0.3302 D_real=7.0381 D_fake=1.5067 | G_loss=-0.5399 Corr=0.0761
# [Epoch 93] L=30 step 1/1 | D_loss=-6.6150 GP=1.6980 D_real=8.4690 D_fake=0.1560 | G_loss=0.5629 Corr=0.0800
# [Epoch 93] L=40 step 1/1 | D_loss=-8.0984 GP=2.3343 D_real=9.2607 D_fake=-1.1720 | G_loss=2.1123 Corr=0.0885
# [Epoch 93] L=50 step 1/1 | D_loss=-9.7403 GP=2.7528 D_real=10.3223 D_fake=-2.1708 | G_loss=2.7987 Corr=0.0849
# [Epoch 93] L=60 step 1/1 | D_loss=-11.3979 GP=3.0125 D_real=12.1678 D_fake=-2.2426 | G_loss=3.0347 Corr=0.0806
# [Epoch 94] L=10 step 1/1 | D_loss=-3.9698 GP=0.4449 D_real=5.1726 D_fake=0.7580 | G_loss=0.4966 Corr=0.1132
# [Epoch 94] L=20 step 1/1 | D_loss=-5.9712 GP=0.6530 D_real=7.2574 D_fake=0.6332 | G_loss=0.6324 Corr=0.1020
# [Epoch 94] L=30 step 1/1 | D_loss=-7.4131 GP=1.5353 D_real=10.1605 D_fake=1.2122 | G_loss=-0.4950 Corr=0.0980
# [Epoch 94] L=40 step 1/1 | D_loss=-8.4192 GP=1.7174 D_real=12.0265 D_fake=1.8898 | G_loss=-0.6786 Corr=0.0934
# [Epoch 94] L=50 step 1/1 | D_loss=-9.7343 GP=3.3194 D_real=13.3048 D_fake=0.2511 | G_loss=0.4732 Corr=0.0910
# [Epoch 94] L=60 step 1/1 | D_loss=-10.3200 GP=2.9830 D_real=12.9986 D_fake=-0.3045 | G_loss=1.7436 Corr=0.1002
# [Epoch 95] L=10 step 1/1 | D_loss=-3.7146 GP=0.2631 D_real=4.4562 D_fake=0.4784 | G_loss=0.7535 Corr=0.1110
# [Epoch 95] L=20 step 1/1 | D_loss=-5.8386 GP=0.9111 D_real=7.1550 D_fake=0.4053 | G_loss=0.4698 Corr=0.0964
# [Epoch 95] L=30 step 1/1 | D_loss=-7.3015 GP=0.9915 D_real=9.5667 D_fake=1.2737 | G_loss=-0.2618 Corr=0.1018
# [Epoch 95] L=40 step 1/1 | D_loss=-9.0995 GP=2.2807 D_real=12.4545 D_fake=1.0743 | G_loss=-0.3038 Corr=0.1011
# [Epoch 95] L=50 step 1/1 | D_loss=-10.2855 GP=3.2971 D_real=13.5461 D_fake=-0.0366 | G_loss=0.7252 Corr=0.0883
# [Epoch 95] L=60 step 1/1 | D_loss=-12.4462 GP=2.4993 D_real=15.8211 D_fake=0.8757 | G_loss=0.2831 Corr=0.0907
# [Epoch 96] L=10 step 1/1 | D_loss=-4.2040 GP=0.4548 D_real=6.0581 D_fake=1.3993 | G_loss=-0.3765 Corr=0.0902
# [Epoch 96] L=20 step 1/1 | D_loss=-6.3265 GP=0.5626 D_real=8.2925 D_fake=1.4034 | G_loss=-0.4239 Corr=0.0813
# [Epoch 96] L=30 step 1/1 | D_loss=-8.0537 GP=1.4518 D_real=10.8734 D_fake=1.3679 | G_loss=-0.9485 Corr=0.0764
# [Epoch 96] L=40 step 1/1 | D_loss=-9.5270 GP=2.7263 D_real=13.6424 D_fake=1.3890 | G_loss=-0.9298 Corr=0.0795
# [Epoch 96] L=50 step 1/1 | D_loss=-10.7676 GP=2.3522 D_real=14.2934 D_fake=1.1736 | G_loss=-0.5791 Corr=0.0757
# [Epoch 96] L=60 step 1/1 | D_loss=-11.8969 GP=2.1609 D_real=16.5165 D_fake=2.4587 | G_loss=-1.7143 Corr=0.0732
# [Epoch 97] L=10 step 1/1 | D_loss=-4.0992 GP=0.5582 D_real=7.3803 D_fake=2.7228 | G_loss=-1.8891 Corr=0.0797
# [Epoch 97] L=20 step 1/1 | D_loss=-5.8205 GP=0.5092 D_real=10.3659 D_fake=4.0361 | G_loss=-3.1671 Corr=0.0776
# [Epoch 97] L=30 step 1/1 | D_loss=-7.4468 GP=1.6660 D_real=12.5610 D_fake=3.4483 | G_loss=-2.6504 Corr=0.0855
# [Epoch 97] L=40 step 1/1 | D_loss=-8.6925 GP=2.7327 D_real=14.2782 D_fake=2.8529 | G_loss=-2.1171 Corr=0.0800
# [Epoch 97] L=50 step 1/1 | D_loss=-9.8712 GP=2.2108 D_real=13.4204 D_fake=1.3384 | G_loss=-0.6438 Corr=0.0730
# [Epoch 97] L=60 step 1/1 | D_loss=-11.0715 GP=3.8954 D_real=15.2931 D_fake=0.3261 | G_loss=-0.3546 Corr=0.0736
# [Epoch 98] L=10 step 1/1 | D_loss=-3.4649 GP=0.1770 D_real=6.5967 D_fake=2.9548 | G_loss=-2.1742 Corr=0.0748
# [Epoch 98] L=20 step 1/1 | D_loss=-5.4552 GP=1.3558 D_real=9.7948 D_fake=2.9838 | G_loss=-2.1415 Corr=0.0775
# [Epoch 98] L=30 step 1/1 | D_loss=-7.3558 GP=1.1039 D_real=10.6970 D_fake=2.2372 | G_loss=-1.2413 Corr=0.0792
# [Epoch 98] L=40 step 1/1 | D_loss=-9.0464 GP=2.4634 D_real=12.9741 D_fake=1.4644 | G_loss=-0.8021 Corr=0.0760
# [Epoch 98] L=50 step 1/1 | D_loss=-10.2070 GP=2.4904 D_real=13.9140 D_fake=1.2167 | G_loss=-0.4197 Corr=0.0787
# [Epoch 98] L=60 step 1/1 | D_loss=-11.1881 GP=3.5120 D_real=16.7321 D_fake=2.0319 | G_loss=-1.7287 Corr=0.0764
# [Epoch 99] L=10 step 1/1 | D_loss=-3.6884 GP=0.1394 D_real=6.8957 D_fake=3.0679 | G_loss=-2.3027 Corr=0.0698
# [Epoch 99] L=20 step 1/1 | D_loss=-5.7677 GP=1.4466 D_real=10.4827 D_fake=3.2685 | G_loss=-2.4211 Corr=0.0746
# [Epoch 99] L=30 step 1/1 | D_loss=-7.5997 GP=1.3067 D_real=12.2943 D_fake=3.3880 | G_loss=-2.7131 Corr=0.0814
# [Epoch 99] L=40 step 1/1 | D_loss=-9.0769 GP=2.5876 D_real=15.0227 D_fake=3.3582 | G_loss=-2.6045 Corr=0.0830
# [Epoch 99] L=50 step 1/1 | D_loss=-10.1960 GP=2.1796 D_real=14.9792 D_fake=2.6036 | G_loss=-1.8052 Corr=0.0676
# [Epoch 99] L=60 step 1/1 | D_loss=-11.5562 GP=2.7258 D_real=16.6787 D_fake=2.3967 | G_loss=-1.8184 Corr=0.0592
# [Epoch 100] L=10 step 1/1 | D_loss=-3.2039 GP=0.3177 D_real=6.4747 D_fake=2.9531 | G_loss=-2.2359 Corr=0.0732
# [Epoch 100] L=20 step 1/1 | D_loss=-5.5806 GP=1.4087 D_real=10.2357 D_fake=3.2465 | G_loss=-2.5786 Corr=0.0670
# [Epoch 100] L=30 step 1/1 | D_loss=-7.4276 GP=1.1209 D_real=11.8613 D_fake=3.3128 | G_loss=-2.5925 Corr=0.0633
# [Epoch 100] L=40 step 1/1 | D_loss=-8.3701 GP=2.3051 D_real=13.4437 D_fake=2.7684 | G_loss=-2.0858 Corr=0.0626
# [Epoch 100] L=50 step 1/1 | D_loss=-10.1056 GP=2.0123 D_real=14.9764 D_fake=2.8585 | G_loss=-2.2758 Corr=0.0618
# [Epoch 100] L=60 step 1/1 | D_loss=-10.9077 GP=3.1389 D_real=15.9855 D_fake=1.9389 | G_loss=-1.0907 Corr=0.0618

# %%
seed_all()

def _inv_boxcox_torch(y: torch.Tensor, lmbda: float, eps: float = 1e-3) -> torch.Tensor:
    if lmbda == 0:
        return torch.exp(y) - eps
    return torch.pow(lmbda * y + 1.0, 1.0 / lmbda) - eps

@torch.no_grad()
def Execute_C007(
    Data: torch.Tensor,
    dtype_schema,
    transform_params: dict,
    real_columns=("VL", "CD4"),
    eps: float = 1e-3,
) -> torch.Tensor:
    device = Data.device
    out_cols = []
    name_to_row = {row["name"]: row for _, row in dtype_schema.iterrows()}

    for name in dtype_schema["name"]:
        row = name_to_row[name]
        s, e, ftype = int(row["index_start"]), int(row["index_end"]), row["type"]
        if ftype == "real":
            y = Data[:, s]
            if name in real_columns:
                p = transform_params[name]
                bc = y * torch.as_tensor(p["range"], device=device) + torch.as_tensor(p["min"], device=device)
                x = _inv_boxcox_torch(bc, float(p["lambda"]), eps=float(p.get("eps", eps)))
            else:
                x = y
            out_cols.append(x.view(-1, 1).to(device=device, dtype=torch.float32))

    for name in dtype_schema["name"]:
        row = name_to_row[name]
        s, e, ftype = int(row["index_start"]), int(row["index_end"]), row["type"]
        if ftype in ("cat", "bin"):
            block = Data[:, s:e]
            idx = torch.argmax(block, dim=1).view(-1, 1)
            out_cols.append(idx.to(device=device, dtype=torch.float32))

    return torch.cat(out_cols, dim=1)

# %%
seed_all()

def Execute_C008(data_types=None):
    Replace_Names = [
        "VL [copies/mL]",
        "CD4 [cells/μL]",
        "Gender",
        "Ethnic",
        "Base Drug Combo",
        "Extra PI",
        "Extra pk-En",
    ]
    Replace_Names2 = [
        "VL",
        "CD4",
        "Gender",
        "Ethnic",
        "Base Drug Combo",
        "Extra PI",
        "Extra pk-En",
    ]
    return Replace_Names, Replace_Names2

# %%
seed_all()

sns.set_context("talk")
plt.rcParams.update({"font.size": 35, "legend.loc": "upper right"})

CATEGORY_LABELS = {
    "Gender": ["Male", "Female"],
    "Ethnic": ["Asian", "African", "Caucasian", "Other"],
    "Base Drug Combo": ["FTC + TDF", "3TC + ABC", "FTC + TAF",
                        "DRV + FTC + TDF", "FTC + RTVB + TDF", "Other"],
    "Extra PI": ["DRV", "RTVB", "LPV", "RTV", "ATV", "Not Applied"],
    "Extra pk-En": ["False", "True"],
}
REAL_NAMES = ["VL [copies/mL]", "CD4 [cells/μL]"]

def set_categorical_with_order(df: pd.DataFrame, col: str, ordered_labels):
    ctype = CategoricalDtype(categories=list(ordered_labels), ordered=True)
    df[col] = df[col].astype(str).astype(ctype)

def collect_loader_sequences(loader):
    xs = []
    for x, _ in loader:
        xs.append(x)
    return torch.cat(xs, dim=0)

def sample_and_flatten(seq_tensor: torch.Tensor, seq_len: int, max_rows: int = 10_000):
    n_seqs = seq_tensor.size(0)
    max_seqs = max(1, min(n_seqs, max_rows // seq_len))
    idx = torch.randperm(n_seqs)[:max_seqs]
    seqs = seq_tensor[idx]
    return seqs.reshape(-1, seq_tensor.size(-1))

def to_cpu(x: torch.Tensor):
    return x.detach().cpu()

def make_df(colname: str, real_col: np.ndarray, fake_col: np.ndarray, categorical=False):
    if categorical:
        df = pd.concat([
            pd.DataFrame({colname: fake_col.astype(int), "Type": "Synthetic"}),
            pd.DataFrame({colname: real_col.astype(int), "Type": "Real"}),
        ], ignore_index=True)
        labels = CATEGORY_LABELS.get(colname)
        if labels:
            df[colname] = df[colname].map(dict(enumerate(labels)))
            set_categorical_with_order(df, colname, labels)
        return df
    else:
        return pd.concat([
            pd.DataFrame({colname: fake_col.astype(float), "Type": "Synthetic"}),
            pd.DataFrame({colname: real_col.astype(float), "Type": "Real"}),
        ], ignore_index=True)

# %%
seed_all()

loader60 = only10_60[60]
Real_Seqs = collect_loader_sequences(loader60)
F = int(max(dtype["index_end"]))
Generated_Len = 60

Real_Data = sample_and_flatten(Real_Seqs, seq_len=Generated_Len, max_rows=10_000)
Fake_Data = wgan_gp.generate_data(Generated_Len, num_samples=Real_Seqs.size(0))
Fake_Data = Fake_Data[: Real_Data.size(0) // Generated_Len].reshape(-1, F)

with torch.no_grad():
    Real_Data = Execute_C007(Real_Data, dtype_schema=dtype, transform_params=art_transformation_params)
    Fake_Data = Execute_C007(Fake_Data, dtype_schema=dtype, transform_params=art_transformation_params)

Real_Data = to_cpu(Real_Data)
Fake_Data = to_cpu(Fake_Data)

Replace_Names, _ = Execute_C008(dtype)
n_features = len(Replace_Names)
ncols = 4
nrows = (n_features + ncols - 1) // ncols
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(45, 10 * nrows))
axes = np.atleast_2d(axes)

for k, name in enumerate(Replace_Names):
    i, j = divmod(k, ncols)
    cur_ax = axes[i, j]
    cur_fake = Fake_Data[:, k].numpy()
    cur_real = Real_Data[:, k].numpy()

    if name in REAL_NAMES:
        df_all = make_df(name, cur_real, cur_fake, categorical=False)
        sns.kdeplot(data=df_all, x=name, hue="Type", fill=True, ax=cur_ax, legend=(k == 0), common_norm=False)
        if cur_ax.legend_:
            cur_ax.legend_.set_title(None)
        cur_ax.yaxis.set_visible(False)
        cur_ax.set(xlabel=name)
    else:
        df_all = make_df(name, cur_real, cur_fake, categorical=True)
        sns.histplot(
            data=df_all, x=name, hue="Type", multiple="dodge", stat="probability",
            shrink=0.8, alpha=0.3, linewidth=0, ax=cur_ax, legend=False, discrete=True
        )
        cur_ax.tick_params(axis="x", rotation=-45 if name in CATEGORY_LABELS and len(CATEGORY_LABELS[name]) > 3 else 0)
        cur_ax.yaxis.set_visible(False)
        cur_ax.set(xlabel=name)

for k in range(n_features, nrows * ncols):
    i, j = divmod(k, ncols)
    axes[i, j].axis("off")

plt.tight_layout(pad=1.0)
plt.show()

# %%
torch.save(wgan_gp.G.state_dict(), "YDZ002_G_StateDict_Epoch100")
torch.save(wgan_gp.D.state_dict(), "YDZ002_D_StateDict_Epoch100")

# %%
seed_all()

# Experimental setup
Hyper002_Epochs     = 200

#---
# Continue to train a pre-trained variant
Hyper010_Continue    = True
Hyper011_G_SD        = 'YDZ002_G_StateDict_Epoch100'
Hyper012_D_SD        = 'YDZ002_D_StateDict_Epoch100'
Hyper013_PreEpoch    = 100

# %%
wgan_gp = Execute_D004(
                Hyper001_BatchSize, Hyper002_Epochs,
                Hyper003_G_iter, Hyper004_GP_Lambda, Hyper005_C_Lambda,
                Hyper006_ID, Hyper007_HD,
                Hyper008_LR, Hyper009_Betas,
                dtype,
                correlation_real,
                [Hyper010_Continue,
                 Hyper011_G_SD, Hyper012_D_SD,
                 Hyper013_PreEpoch])

# %%
wgan_gp.train(only10_60)
# Out:
# /tmp/ipython-input-3244134220.py:110: RuntimeWarning: divide by zero encountered in remainder
#   if (np.mod(batch_idx + 1, round(len(Cur_loader) / 5)) == 0) or \
# [Epoch 101] L=10 step 1/1 | D_loss=-3.5153 GP=0.1482 D_real=6.5868 D_fake=2.9234 | G_loss=-2.2039 Corr=0.0586
# [Epoch 101] L=20 step 1/1 | D_loss=-4.4908 GP=0.2254 D_real=9.9477 D_fake=5.2315 | G_loss=-3.9599 Corr=0.0955
# [Epoch 101] L=30 step 1/1 | D_loss=-6.3229 GP=2.9870 D_real=14.1919 D_fake=4.8820 | G_loss=-3.6477 Corr=0.1171
# [Epoch 101] L=40 step 1/1 | D_loss=-8.9802 GP=1.1930 D_real=15.2565 D_fake=5.0834 | G_loss=-3.6982 Corr=0.1247
# [Epoch 101] L=50 step 1/1 | D_loss=-10.2733 GP=2.9019 D_real=18.2277 D_fake=5.0524 | G_loss=-3.9251 Corr=0.1212
# [Epoch 101] L=60 step 1/1 | D_loss=-10.7307 GP=1.9122 D_real=19.1371 D_fake=6.4941 | G_loss=-5.4211 Corr=0.1187
# [Epoch 102] L=10 step 1/1 | D_loss=-2.9021 GP=0.2457 D_real=8.8844 D_fake=5.7366 | G_loss=-4.5915 Corr=0.1049
# [Epoch 102] L=20 step 1/1 | D_loss=-2.5341 GP=1.0053 D_real=10.2681 D_fake=6.7287 | G_loss=-5.5725 Corr=0.1046
# [Epoch 102] L=30 step 1/1 | D_loss=-4.9345 GP=1.4407 D_real=13.8358 D_fake=7.4606 | G_loss=-6.3595 Corr=0.1077
# [Epoch 102] L=40 step 1/1 | D_loss=-7.5253 GP=2.1811 D_real=16.8811 D_fake=7.1748 | G_loss=-5.6252 Corr=0.1211
# [Epoch 102] L=50 step 1/1 | D_loss=-10.3597 GP=2.3240 D_real=19.0015 D_fake=6.3178 | G_loss=-5.0641 Corr=0.1171
# [Epoch 102] L=60 step 1/1 | D_loss=-10.2215 GP=1.8322 D_real=19.8872 D_fake=7.8335 | G_loss=-6.6001 Corr=0.1034
# [Epoch 103] L=10 step 1/1 | D_loss=-2.6845 GP=0.3355 D_real=9.3166 D_fake=6.2967 | G_loss=-5.0607 Corr=0.1052
# [Epoch 103] L=20 step 1/1 | D_loss=-4.0170 GP=0.7372 D_real=11.4528 D_fake=6.6986 | G_loss=-5.3384 Corr=0.1181
# [Epoch 103] L=30 step 1/1 | D_loss=-6.3301 GP=2.7277 D_real=15.6546 D_fake=6.5969 | G_loss=-5.2990 Corr=0.1257
# [Epoch 103] L=40 step 1/1 | D_loss=-8.5074 GP=1.8159 D_real=16.0716 D_fake=5.7484 | G_loss=-4.3919 Corr=0.1212
# [Epoch 103] L=50 step 1/1 | D_loss=-10.3801 GP=2.0002 D_real=17.9708 D_fake=5.5905 | G_loss=-4.4459 Corr=0.1170
# [Epoch 103] L=60 step 1/1 | D_loss=-11.4439 GP=2.6088 D_real=19.5628 D_fake=5.5101 | G_loss=-4.1610 Corr=0.1191
# [Epoch 104] L=10 step 1/1 | D_loss=-3.7927 GP=0.4213 D_real=9.1502 D_fake=4.9363 | G_loss=-3.8682 Corr=0.1198
# [Epoch 104] L=20 step 1/1 | D_loss=-4.5631 GP=0.1128 D_real=10.6142 D_fake=5.9383 | G_loss=-4.7185 Corr=0.1022
# [Epoch 104] L=30 step 1/1 | D_loss=-6.5047 GP=1.2471 D_real=12.6798 D_fake=4.9279 | G_loss=-3.6296 Corr=0.1016
# [Epoch 104] L=40 step 1/1 | D_loss=-6.9147 GP=3.3081 D_real=14.7425 D_fake=4.5197 | G_loss=-3.6119 Corr=0.1027
# [Epoch 104] L=50 step 1/1 | D_loss=-8.1125 GP=0.9206 D_real=14.6965 D_fake=5.6633 | G_loss=-4.6212 Corr=0.1069
# [Epoch 104] L=60 step 1/1 | D_loss=-8.9694 GP=1.9588 D_real=16.8882 D_fake=5.9599 | G_loss=-4.7275 Corr=0.1154
# [Epoch 105] L=10 step 1/1 | D_loss=-3.2739 GP=0.2098 D_real=8.8645 D_fake=5.3808 | G_loss=-4.0801 Corr=0.1295
# [Epoch 105] L=20 step 1/1 | D_loss=-4.5902 GP=0.1463 D_real=10.8628 D_fake=6.1263 | G_loss=-4.8039 Corr=0.1140
# [Epoch 105] L=30 step 1/1 | D_loss=-6.2331 GP=1.4279 D_real=13.0010 D_fake=5.3401 | G_loss=-3.9013 Corr=0.1167
# [Epoch 105] L=40 step 1/1 | D_loss=-7.6888 GP=1.0075 D_real=13.3168 D_fake=4.6204 | G_loss=-3.5559 Corr=0.1095
# [Epoch 105] L=50 step 1/1 | D_loss=-9.0047 GP=2.4393 D_real=16.0173 D_fake=4.5733 | G_loss=-3.4144 Corr=0.1176
# [Epoch 105] L=60 step 1/1 | D_loss=-10.4345 GP=1.7919 D_real=16.7866 D_fake=4.5601 | G_loss=-3.1054 Corr=0.1205
# [Epoch 106] L=10 step 1/1 | D_loss=-3.3034 GP=0.1835 D_real=8.4636 D_fake=4.9767 | G_loss=-3.7635 Corr=0.1089
# [Epoch 106] L=20 step 1/1 | D_loss=-4.9837 GP=0.9674 D_real=10.9940 D_fake=5.0429 | G_loss=-3.8305 Corr=0.1132
# [Epoch 106] L=30 step 1/1 | D_loss=-6.3966 GP=0.8803 D_real=12.5237 D_fake=5.2469 | G_loss=-3.9233 Corr=0.1205
# [Epoch 106] L=40 step 1/1 | D_loss=-7.5897 GP=1.5247 D_real=13.3175 D_fake=4.2031 | G_loss=-2.8851 Corr=0.1155
# [Epoch 106] L=50 step 1/1 | D_loss=-8.9622 GP=2.2631 D_real=15.5043 D_fake=4.2790 | G_loss=-3.1884 Corr=0.1150
# [Epoch 106] L=60 step 1/1 | D_loss=-10.7315 GP=2.1217 D_real=16.1613 D_fake=3.3081 | G_loss=-2.0409 Corr=0.1095
# [Epoch 107] L=10 step 1/1 | D_loss=-3.0698 GP=0.7456 D_real=8.7086 D_fake=4.8933 | G_loss=-3.7752 Corr=0.1036
# [Epoch 107] L=20 step 1/1 | D_loss=-4.7520 GP=0.6638 D_real=10.1739 D_fake=4.7581 | G_loss=-3.7315 Corr=0.0969
# [Epoch 107] L=30 step 1/1 | D_loss=-7.0597 GP=2.3142 D_real=13.1485 D_fake=3.7746 | G_loss=-3.1281 Corr=0.0917
# [Epoch 107] L=40 step 1/1 | D_loss=-8.6849 GP=1.5983 D_real=15.3189 D_fake=5.0356 | G_loss=-4.2604 Corr=0.0911
# [Epoch 107] L=50 step 1/1 | D_loss=-10.1897 GP=2.5602 D_real=17.0175 D_fake=4.2676 | G_loss=-3.3788 Corr=0.0906
# [Epoch 107] L=60 step 1/1 | D_loss=-11.7413 GP=2.6589 D_real=19.1096 D_fake=4.7094 | G_loss=-3.7609 Corr=0.0864
# [Epoch 108] L=10 step 1/1 | D_loss=-3.7029 GP=0.9443 D_real=9.9552 D_fake=5.3080 | G_loss=-4.2612 Corr=0.1101
# [Epoch 108] L=20 step 1/1 | D_loss=-5.7382 GP=0.2999 D_real=11.9363 D_fake=5.8982 | G_loss=-4.9411 Corr=0.0821
# [Epoch 108] L=30 step 1/1 | D_loss=-7.7904 GP=1.8266 D_real=14.3429 D_fake=4.7260 | G_loss=-3.7519 Corr=0.0814
# [Epoch 108] L=40 step 1/1 | D_loss=-9.1713 GP=1.9332 D_real=15.8430 D_fake=4.7386 | G_loss=-4.0236 Corr=0.0806
# [Epoch 108] L=50 step 1/1 | D_loss=-10.5449 GP=3.3089 D_real=18.3209 D_fake=4.4672 | G_loss=-3.7007 Corr=0.0831
# [Epoch 108] L=60 step 1/1 | D_loss=-11.6102 GP=2.2642 D_real=19.6166 D_fake=5.7422 | G_loss=-4.9074 Corr=0.0824
# [Epoch 109] L=10 step 1/1 | D_loss=-3.9945 GP=0.4941 D_real=9.6793 D_fake=5.1908 | G_loss=-4.1140 Corr=0.1036
# [Epoch 109] L=20 step 1/1 | D_loss=-6.0128 GP=0.6293 D_real=12.5010 D_fake=5.8589 | G_loss=-4.9950 Corr=0.0777
# [Epoch 109] L=30 step 1/1 | D_loss=-7.6340 GP=1.7032 D_real=14.7391 D_fake=5.4019 | G_loss=-4.5755 Corr=0.0766
# [Epoch 109] L=40 step 1/1 | D_loss=-9.5219 GP=2.0301 D_real=17.1146 D_fake=5.5626 | G_loss=-4.8797 Corr=0.0749
# [Epoch 109] L=50 step 1/1 | D_loss=-10.5333 GP=2.2360 D_real=18.2105 D_fake=5.4411 | G_loss=-4.6916 Corr=0.0779
# [Epoch 109] L=60 step 1/1 | D_loss=-11.9207 GP=2.7328 D_real=19.8570 D_fake=5.2036 | G_loss=-4.3820 Corr=0.0752
# [Epoch 110] L=10 step 1/1 | D_loss=-3.9372 GP=0.3072 D_real=9.2826 D_fake=5.0382 | G_loss=-4.1962 Corr=0.0835
# [Epoch 110] L=20 step 1/1 | D_loss=-5.7273 GP=0.8248 D_real=12.1514 D_fake=5.5993 | G_loss=-4.7473 Corr=0.0772
# [Epoch 110] L=30 step 1/1 | D_loss=-7.2300 GP=1.0461 D_real=13.8273 D_fake=5.5512 | G_loss=-4.7480 Corr=0.0851
# [Epoch 110] L=40 step 1/1 | D_loss=-8.4599 GP=2.7858 D_real=15.8303 D_fake=4.5846 | G_loss=-3.6619 Corr=0.0846
# [Epoch 110] L=50 step 1/1 | D_loss=-9.8743 GP=1.6031 D_real=15.8593 D_fake=4.3820 | G_loss=-3.7593 Corr=0.0832
# [Epoch 110] L=60 step 1/1 | D_loss=-11.6677 GP=3.6455 D_real=19.7634 D_fake=4.4502 | G_loss=-4.0079 Corr=0.0857
# [Epoch 111] L=10 step 1/1 | D_loss=-3.7349 GP=0.4760 D_real=9.3302 D_fake=5.1193 | G_loss=-4.0939 Corr=0.1020
# [Epoch 111] L=20 step 1/1 | D_loss=-5.9969 GP=0.7853 D_real=12.1642 D_fake=5.3820 | G_loss=-4.2683 Corr=0.0912
# [Epoch 111] L=30 step 1/1 | D_loss=-7.5698 GP=1.2397 D_real=13.1390 D_fake=4.3295 | G_loss=-3.4017 Corr=0.0885
# [Epoch 111] L=40 step 1/1 | D_loss=-9.0189 GP=2.4789 D_real=16.0080 D_fake=4.5102 | G_loss=-3.7963 Corr=0.0789
# [Epoch 111] L=50 step 1/1 | D_loss=-10.5765 GP=1.7980 D_real=17.1851 D_fake=4.8106 | G_loss=-4.1096 Corr=0.0753
# [Epoch 111] L=60 step 1/1 | D_loss=-11.2229 GP=3.2673 D_real=20.5276 D_fake=6.0374 | G_loss=-5.3376 Corr=0.0739
# [Epoch 112] L=10 step 1/1 | D_loss=-3.5724 GP=0.4645 D_real=9.2515 D_fake=5.2146 | G_loss=-4.2812 Corr=0.0862
# [Epoch 112] L=20 step 1/1 | D_loss=-5.8789 GP=1.0738 D_real=12.6088 D_fake=5.6561 | G_loss=-4.7577 Corr=0.0798
# [Epoch 112] L=30 step 1/1 | D_loss=-7.7511 GP=1.2226 D_real=14.5002 D_fake=5.5265 | G_loss=-4.6723 Corr=0.0805
# [Epoch 112] L=40 step 1/1 | D_loss=-9.4467 GP=2.4908 D_real=17.5595 D_fake=5.6220 | G_loss=-5.0875 Corr=0.0788
# [Epoch 112] L=50 step 1/1 | D_loss=-11.1037 GP=2.4307 D_real=19.2375 D_fake=5.7031 | G_loss=-4.8906 Corr=0.0751
# [Epoch 112] L=60 step 1/1 | D_loss=-12.5375 GP=3.5422 D_real=20.9708 D_fake=4.8911 | G_loss=-4.2233 Corr=0.0669
# [Epoch 113] L=10 step 1/1 | D_loss=-3.6682 GP=0.2260 D_real=9.0450 D_fake=5.1508 | G_loss=-4.4170 Corr=0.0781
# [Epoch 113] L=20 step 1/1 | D_loss=-5.9591 GP=1.1625 D_real=12.9088 D_fake=5.7873 | G_loss=-4.9372 Corr=0.0654
# [Epoch 113] L=30 step 1/1 | D_loss=-7.4069 GP=2.3731 D_real=15.2106 D_fake=5.4306 | G_loss=-4.8946 Corr=0.0628
# [Epoch 113] L=40 step 1/1 | D_loss=-9.6375 GP=1.8761 D_real=16.7194 D_fake=5.2058 | G_loss=-4.5951 Corr=0.0607
# [Epoch 113] L=50 step 1/1 | D_loss=-10.8924 GP=2.7499 D_real=18.4006 D_fake=4.7583 | G_loss=-4.2930 Corr=0.0644
# [Epoch 113] L=60 step 1/1 | D_loss=-12.0480 GP=2.6722 D_real=19.2931 D_fake=4.5730 | G_loss=-3.8792 Corr=0.0634
# [Epoch 114] L=10 step 1/1 | D_loss=-3.8701 GP=0.1670 D_real=9.0497 D_fake=5.0125 | G_loss=-4.4039 Corr=0.0667
# [Epoch 114] L=20 step 1/1 | D_loss=-5.8926 GP=0.6499 D_real=11.9055 D_fake=5.3629 | G_loss=-4.5058 Corr=0.0646
# [Epoch 114] L=30 step 1/1 | D_loss=-7.7864 GP=2.0885 D_real=14.3682 D_fake=4.4933 | G_loss=-3.8812 Corr=0.0632
# [Epoch 114] L=40 step 1/1 | D_loss=-9.4933 GP=1.9045 D_real=15.5452 D_fake=4.1474 | G_loss=-3.4541 Corr=0.0602
# [Epoch 114] L=50 step 1/1 | D_loss=-10.5124 GP=2.8476 D_real=17.2927 D_fake=3.9327 | G_loss=-3.3196 Corr=0.0649
# [Epoch 114] L=60 step 1/1 | D_loss=-11.8539 GP=2.8051 D_real=18.6968 D_fake=4.0378 | G_loss=-3.4236 Corr=0.0564
# [Epoch 115] L=10 step 1/1 | D_loss=-3.8962 GP=0.3014 D_real=9.2182 D_fake=5.0205 | G_loss=-4.4840 Corr=0.0575
# [Epoch 115] L=20 step 1/1 | D_loss=-5.9501 GP=0.7813 D_real=12.3006 D_fake=5.5692 | G_loss=-4.8623 Corr=0.0593
# [Epoch 115] L=30 step 1/1 | D_loss=-7.9075 GP=1.7813 D_real=14.7662 D_fake=5.0775 | G_loss=-4.4012 Corr=0.0643
# [Epoch 115] L=40 step 1/1 | D_loss=-9.1564 GP=2.4451 D_real=15.8638 D_fake=4.2623 | G_loss=-3.6792 Corr=0.0620
# [Epoch 115] L=50 step 1/1 | D_loss=-10.5509 GP=2.7217 D_real=17.3244 D_fake=4.0517 | G_loss=-3.3313 Corr=0.0583
# [Epoch 115] L=60 step 1/1 | D_loss=-11.7222 GP=3.0037 D_real=18.8850 D_fake=4.1591 | G_loss=-3.7385 Corr=0.0564
# [Epoch 116] L=10 step 1/1 | D_loss=-4.0201 GP=0.5431 D_real=9.4476 D_fake=4.8844 | G_loss=-4.2494 Corr=0.0561
# [Epoch 116] L=20 step 1/1 | D_loss=-5.9598 GP=0.5884 D_real=12.0031 D_fake=5.4550 | G_loss=-4.8521 Corr=0.0553
# [Epoch 116] L=30 step 1/1 | D_loss=-8.0256 GP=1.5530 D_real=14.8289 D_fake=5.2503 | G_loss=-4.6817 Corr=0.0549
# [Epoch 116] L=40 step 1/1 | D_loss=-9.1062 GP=1.8350 D_real=15.5642 D_fake=4.6230 | G_loss=-4.1680 Corr=0.0593
# [Epoch 116] L=50 step 1/1 | D_loss=-10.5908 GP=2.5298 D_real=17.6701 D_fake=4.5495 | G_loss=-4.2580 Corr=0.0508
# [Epoch 116] L=60 step 1/1 | D_loss=-12.4290 GP=2.8603 D_real=19.9283 D_fake=4.6389 | G_loss=-4.0470 Corr=0.0525
# [Epoch 117] L=10 step 1/1 | D_loss=-3.8019 GP=0.3862 D_real=8.8361 D_fake=4.6480 | G_loss=-3.9954 Corr=0.0617
# [Epoch 117] L=20 step 1/1 | D_loss=-6.1923 GP=0.8718 D_real=11.7074 D_fake=4.6433 | G_loss=-4.0399 Corr=0.0537
# [Epoch 117] L=30 step 1/1 | D_loss=-8.0060 GP=1.8447 D_real=14.6314 D_fake=4.7807 | G_loss=-4.3604 Corr=0.0498
# [Epoch 117] L=40 step 1/1 | D_loss=-9.1599 GP=2.0230 D_real=15.6553 D_fake=4.4724 | G_loss=-4.2138 Corr=0.0476
# [Epoch 117] L=50 step 1/1 | D_loss=-10.3308 GP=3.0311 D_real=17.5599 D_fake=4.1980 | G_loss=-3.6867 Corr=0.0511
# [Epoch 117] L=60 step 1/1 | D_loss=-11.6956 GP=2.3508 D_real=19.2755 D_fake=5.2291 | G_loss=-4.3037 Corr=0.0529
# [Epoch 118] L=10 step 1/1 | D_loss=-3.8233 GP=0.2005 D_real=8.8796 D_fake=4.8559 | G_loss=-4.2498 Corr=0.0552
# [Epoch 118] L=20 step 1/1 | D_loss=-6.0951 GP=0.8526 D_real=11.7756 D_fake=4.8279 | G_loss=-4.2471 Corr=0.0558
# [Epoch 118] L=30 step 1/1 | D_loss=-7.6693 GP=1.0611 D_real=13.5612 D_fake=4.8308 | G_loss=-4.2950 Corr=0.0590
# [Epoch 118] L=40 step 1/1 | D_loss=-9.3140 GP=2.1084 D_real=15.7117 D_fake=4.2894 | G_loss=-3.6615 Corr=0.0595
# [Epoch 118] L=50 step 1/1 | D_loss=-10.5407 GP=2.4309 D_real=16.9709 D_fake=3.9993 | G_loss=-3.6787 Corr=0.0560
# [Epoch 118] L=60 step 1/1 | D_loss=-12.1788 GP=3.0724 D_real=19.5538 D_fake=4.3025 | G_loss=-3.9265 Corr=0.0564
# [Epoch 119] L=10 step 1/1 | D_loss=-3.7721 GP=0.5408 D_real=9.5357 D_fake=5.2228 | G_loss=-4.6819 Corr=0.0554
# [Epoch 119] L=20 step 1/1 | D_loss=-6.1109 GP=0.8728 D_real=12.7841 D_fake=5.8004 | G_loss=-5.2289 Corr=0.0463
# [Epoch 119] L=30 step 1/1 | D_loss=-7.8544 GP=1.4132 D_real=14.3045 D_fake=5.0370 | G_loss=-4.5630 Corr=0.0451
# [Epoch 119] L=40 step 1/1 | D_loss=-9.1324 GP=2.5986 D_real=17.1002 D_fake=5.3692 | G_loss=-5.1674 Corr=0.0453
# [Epoch 119] L=50 step 1/1 | D_loss=-10.5550 GP=2.2664 D_real=18.4669 D_fake=5.6455 | G_loss=-5.0650 Corr=0.0450
# [Epoch 119] L=60 step 1/1 | D_loss=-11.9318 GP=3.1854 D_real=20.0471 D_fake=4.9299 | G_loss=-4.6563 Corr=0.0430
# [Epoch 120] L=10 step 1/1 | D_loss=-3.7155 GP=0.2355 D_real=9.2591 D_fake=5.3080 | G_loss=-4.8262 Corr=0.0484
# [Epoch 120] L=20 step 1/1 | D_loss=-6.0617 GP=0.9340 D_real=12.6659 D_fake=5.6702 | G_loss=-5.0448 Corr=0.0476
# [Epoch 120] L=30 step 1/1 | D_loss=-7.7249 GP=1.7136 D_real=14.8946 D_fake=5.4560 | G_loss=-5.0063 Corr=0.0501
# [Epoch 120] L=40 step 1/1 | D_loss=-9.2173 GP=2.1196 D_real=16.5736 D_fake=5.2367 | G_loss=-4.6558 Corr=0.0514
# [Epoch 120] L=50 step 1/1 | D_loss=-10.3110 GP=2.4626 D_real=18.0306 D_fake=5.2570 | G_loss=-4.8324 Corr=0.0427
# [Epoch 120] L=60 step 1/1 | D_loss=-11.8060 GP=3.2419 D_real=19.5499 D_fake=4.5021 | G_loss=-4.1924 Corr=0.0424
# [Epoch 121] L=10 step 1/1 | D_loss=-3.4622 GP=0.3403 D_real=9.2689 D_fake=5.4665 | G_loss=-4.9974 Corr=0.0449
# [Epoch 121] L=20 step 1/1 | D_loss=-6.0569 GP=1.1317 D_real=12.8760 D_fake=5.6875 | G_loss=-5.1009 Corr=0.0391
# [Epoch 121] L=30 step 1/1 | D_loss=-7.7828 GP=1.7144 D_real=14.6620 D_fake=5.1649 | G_loss=-4.6929 Corr=0.0451
# [Epoch 121] L=40 step 1/1 | D_loss=-9.3714 GP=2.4281 D_real=16.1418 D_fake=4.3423 | G_loss=-3.9899 Corr=0.0455
# [Epoch 121] L=50 step 1/1 | D_loss=-10.7276 GP=2.8653 D_real=18.2369 D_fake=4.6440 | G_loss=-4.1822 Corr=0.0434
# [Epoch 121] L=60 step 1/1 | D_loss=-12.4574 GP=3.0486 D_real=19.8995 D_fake=4.3935 | G_loss=-4.2943 Corr=0.0446
# [Epoch 122] L=10 step 1/1 | D_loss=-3.6166 GP=0.1720 D_real=8.7627 D_fake=4.9741 | G_loss=-4.5043 Corr=0.0448
# [Epoch 122] L=20 step 1/1 | D_loss=-6.0988 GP=1.0019 D_real=11.8271 D_fake=4.7265 | G_loss=-4.0484 Corr=0.0443
# [Epoch 122] L=30 step 1/1 | D_loss=-7.6492 GP=1.9711 D_real=13.8051 D_fake=4.1848 | G_loss=-3.8148 Corr=0.0405
# [Epoch 122] L=40 step 1/1 | D_loss=-9.2077 GP=2.5599 D_real=15.2728 D_fake=3.5052 | G_loss=-3.0544 Corr=0.0391
# [Epoch 122] L=50 step 1/1 | D_loss=-10.9173 GP=2.0747 D_real=17.3978 D_fake=4.4058 | G_loss=-4.0988 Corr=0.0417
# [Epoch 122] L=60 step 1/1 | D_loss=-12.3354 GP=3.3377 D_real=19.6851 D_fake=4.0120 | G_loss=-3.5802 Corr=0.0415
# [Epoch 123] L=10 step 1/1 | D_loss=-3.7785 GP=0.2317 D_real=8.7666 D_fake=4.7564 | G_loss=-4.4040 Corr=0.0408
# [Epoch 123] L=20 step 1/1 | D_loss=-5.8723 GP=0.6565 D_real=11.7599 D_fake=5.2311 | G_loss=-4.7829 Corr=0.0365
# [Epoch 123] L=30 step 1/1 | D_loss=-7.6107 GP=2.2474 D_real=14.5873 D_fake=4.7293 | G_loss=-4.3116 Corr=0.0388
# [Epoch 123] L=40 step 1/1 | D_loss=-9.4757 GP=1.9433 D_real=15.8483 D_fake=4.4293 | G_loss=-4.0366 Corr=0.0362
# [Epoch 123] L=50 step 1/1 | D_loss=-11.0250 GP=2.7797 D_real=18.2749 D_fake=4.4703 | G_loss=-4.3304 Corr=0.0353
# [Epoch 123] L=60 step 1/1 | D_loss=-12.1572 GP=2.8379 D_real=19.4988 D_fake=4.5037 | G_loss=-4.1486 Corr=0.0365
# [Epoch 124] L=10 step 1/1 | D_loss=-3.9160 GP=0.2033 D_real=8.9986 D_fake=4.8793 | G_loss=-4.4550 Corr=0.0408
# [Epoch 124] L=20 step 1/1 | D_loss=-6.0911 GP=0.8272 D_real=11.8056 D_fake=4.8873 | G_loss=-4.4396 Corr=0.0355
# [Epoch 124] L=30 step 1/1 | D_loss=-8.0355 GP=1.9247 D_real=14.4951 D_fake=4.5349 | G_loss=-4.2153 Corr=0.0352
# [Epoch 124] L=40 step 1/1 | D_loss=-9.7949 GP=2.1491 D_real=16.6653 D_fake=4.7213 | G_loss=-4.4139 Corr=0.0357
# [Epoch 124] L=50 step 1/1 | D_loss=-11.0882 GP=2.7313 D_real=18.7071 D_fake=4.8876 | G_loss=-4.5686 Corr=0.0326
# [Epoch 124] L=60 step 1/1 | D_loss=-12.5418 GP=3.5503 D_real=19.9112 D_fake=3.8191 | G_loss=-3.4197 Corr=0.0337
# [Epoch 125] L=10 step 1/1 | D_loss=-3.9869 GP=0.1971 D_real=8.8318 D_fake=4.6479 | G_loss=-4.2640 Corr=0.0399
# [Epoch 125] L=20 step 1/1 | D_loss=-6.2524 GP=0.8397 D_real=11.6355 D_fake=4.5435 | G_loss=-4.0435 Corr=0.0333
# [Epoch 125] L=30 step 1/1 | D_loss=-8.1942 GP=1.7317 D_real=14.2796 D_fake=4.3538 | G_loss=-4.1661 Corr=0.0315
# [Epoch 125] L=40 step 1/1 | D_loss=-9.8529 GP=2.5272 D_real=16.3231 D_fake=3.9430 | G_loss=-3.7828 Corr=0.0311
# [Epoch 125] L=50 step 1/1 | D_loss=-11.6349 GP=3.1900 D_real=19.0061 D_fake=4.1811 | G_loss=-3.7401 Corr=0.0312
# [Epoch 125] L=60 step 1/1 | D_loss=-12.4808 GP=2.6929 D_real=19.3485 D_fake=4.1748 | G_loss=-4.0748 Corr=0.0311
# [Epoch 126] L=10 step 1/1 | D_loss=-4.1178 GP=0.4012 D_real=9.7687 D_fake=5.2497 | G_loss=-4.9131 Corr=0.0354
# [Epoch 126] L=20 step 1/1 | D_loss=-6.2348 GP=0.5965 D_real=12.3316 D_fake=5.5004 | G_loss=-5.0348 Corr=0.0342
# [Epoch 126] L=30 step 1/1 | D_loss=-8.1695 GP=1.6964 D_real=14.5213 D_fake=4.6554 | G_loss=-4.2654 Corr=0.0335
# [Epoch 126] L=40 step 1/1 | D_loss=-9.1890 GP=2.2722 D_real=16.0556 D_fake=4.5944 | G_loss=-4.2850 Corr=0.0311
# [Epoch 126] L=50 step 1/1 | D_loss=-11.1843 GP=3.1695 D_real=18.2961 D_fake=3.9423 | G_loss=-3.7550 Corr=0.0285
# [Epoch 126] L=60 step 1/1 | D_loss=-12.6945 GP=2.7799 D_real=20.0989 D_fake=4.6245 | G_loss=-4.3374 Corr=0.0276
# [Epoch 127] L=10 step 1/1 | D_loss=-4.2053 GP=0.5235 D_real=9.6701 D_fake=4.9413 | G_loss=-4.5454 Corr=0.0310
# [Epoch 127] L=20 step 1/1 | D_loss=-6.3003 GP=0.5717 D_real=11.4054 D_fake=4.5335 | G_loss=-4.1115 Corr=0.0306
# [Epoch 127] L=30 step 1/1 | D_loss=-7.9311 GP=1.7938 D_real=13.7582 D_fake=4.0332 | G_loss=-3.8180 Corr=0.0318
# [Epoch 127] L=40 step 1/1 | D_loss=-9.6394 GP=2.0888 D_real=15.8225 D_fake=4.0943 | G_loss=-3.8259 Corr=0.0305
# [Epoch 127] L=50 step 1/1 | D_loss=-10.8190 GP=2.5881 D_real=17.3976 D_fake=3.9905 | G_loss=-3.7283 Corr=0.0288
# [Epoch 127] L=60 step 1/1 | D_loss=-12.5310 GP=3.1711 D_real=20.2893 D_fake=4.5873 | G_loss=-4.6095 Corr=0.0256
# [Epoch 128] L=10 step 1/1 | D_loss=-3.9889 GP=0.4050 D_real=9.6076 D_fake=5.2137 | G_loss=-4.8680 Corr=0.0319
# [Epoch 128] L=20 step 1/1 | D_loss=-5.9496 GP=0.9076 D_real=12.1869 D_fake=5.3297 | G_loss=-4.8254 Corr=0.0336
# [Epoch 128] L=30 step 1/1 | D_loss=-7.8885 GP=1.4862 D_real=14.6336 D_fake=5.2589 | G_loss=-5.1652 Corr=0.0301
# [Epoch 128] L=40 step 1/1 | D_loss=-9.4879 GP=2.2007 D_real=17.0609 D_fake=5.3723 | G_loss=-5.1006 Corr=0.0326
# [Epoch 128] L=50 step 1/1 | D_loss=-10.9219 GP=2.7005 D_real=18.2182 D_fake=4.5958 | G_loss=-4.1946 Corr=0.0320
# [Epoch 128] L=60 step 1/1 | D_loss=-12.4499 GP=3.6436 D_real=20.2507 D_fake=4.1571 | G_loss=-4.0027 Corr=0.0336
# [Epoch 129] L=10 step 1/1 | D_loss=-3.8066 GP=0.2680 D_real=9.4417 D_fake=5.3670 | G_loss=-4.9733 Corr=0.0358
# [Epoch 129] L=20 step 1/1 | D_loss=-6.0263 GP=1.0857 D_real=12.1190 D_fake=5.0070 | G_loss=-4.5120 Corr=0.0341
# [Epoch 129] L=30 step 1/1 | D_loss=-7.6879 GP=1.0893 D_real=13.5102 D_fake=4.7331 | G_loss=-4.4061 Corr=0.0320
# [Epoch 129] L=40 step 1/1 | D_loss=-9.3179 GP=2.5591 D_real=16.4746 D_fake=4.5977 | G_loss=-4.3763 Corr=0.0307
# [Epoch 129] L=50 step 1/1 | D_loss=-11.0042 GP=2.2851 D_real=17.7863 D_fake=4.4970 | G_loss=-4.1124 Corr=0.0302
# [Epoch 129] L=60 step 1/1 | D_loss=-12.2967 GP=3.1422 D_real=20.0134 D_fake=4.5745 | G_loss=-4.3210 Corr=0.0316
# [Epoch 130] L=10 step 1/1 | D_loss=-3.7689 GP=0.2250 D_real=8.8274 D_fake=4.8334 | G_loss=-4.3890 Corr=0.0381
# [Epoch 130] L=20 step 1/1 | D_loss=-6.1068 GP=0.9528 D_real=11.6863 D_fake=4.6268 | G_loss=-4.2020 Corr=0.0313
# [Epoch 130] L=30 step 1/1 | D_loss=-7.7823 GP=1.3459 D_real=13.5393 D_fake=4.4111 | G_loss=-4.0564 Corr=0.0366
# [Epoch 130] L=40 step 1/1 | D_loss=-9.0555 GP=2.3866 D_real=15.4933 D_fake=4.0512 | G_loss=-3.6153 Corr=0.0378
# [Epoch 130] L=50 step 1/1 | D_loss=-10.8635 GP=2.1411 D_real=17.2916 D_fake=4.2871 | G_loss=-4.0558 Corr=0.0328
# [Epoch 130] L=60 step 1/1 | D_loss=-12.2434 GP=3.4736 D_real=19.2537 D_fake=3.5367 | G_loss=-3.3608 Corr=0.0338
# [Epoch 131] L=10 step 1/1 | D_loss=-3.8906 GP=0.4321 D_real=9.2319 D_fake=4.9091 | G_loss=-4.5656 Corr=0.0344
# [Epoch 131] L=20 step 1/1 | D_loss=-6.0383 GP=0.8849 D_real=11.9169 D_fake=4.9937 | G_loss=-4.5377 Corr=0.0347
# [Epoch 131] L=30 step 1/1 | D_loss=-7.5125 GP=1.5995 D_real=13.1525 D_fake=4.0405 | G_loss=-3.6699 Corr=0.0374
# [Epoch 131] L=40 step 1/1 | D_loss=-8.9844 GP=2.0959 D_real=14.6805 D_fake=3.6001 | G_loss=-3.3297 Corr=0.0344
# [Epoch 131] L=50 step 1/1 | D_loss=-10.7925 GP=2.3033 D_real=16.8061 D_fake=3.7103 | G_loss=-3.3875 Corr=0.0333
# [Epoch 131] L=60 step 1/1 | D_loss=-11.6617 GP=3.6429 D_real=19.0645 D_fake=3.7599 | G_loss=-3.4876 Corr=0.0336
# [Epoch 132] L=10 step 1/1 | D_loss=-3.8839 GP=0.1716 D_real=9.0574 D_fake=5.0019 | G_loss=-4.6742 Corr=0.0345
# [Epoch 132] L=20 step 1/1 | D_loss=-6.1916 GP=0.9705 D_real=12.2037 D_fake=5.0415 | G_loss=-4.5418 Corr=0.0317
# [Epoch 132] L=30 step 1/1 | D_loss=-7.8212 GP=1.5731 D_real=13.6432 D_fake=4.2489 | G_loss=-3.8286 Corr=0.0340
# [Epoch 132] L=40 step 1/1 | D_loss=-9.1416 GP=2.2129 D_real=15.3753 D_fake=4.0207 | G_loss=-3.7153 Corr=0.0364
# [Epoch 132] L=50 step 1/1 | D_loss=-10.7816 GP=2.6094 D_real=17.4478 D_fake=4.0569 | G_loss=-3.7586 Corr=0.0393
# [Epoch 132] L=60 step 1/1 | D_loss=-12.3740 GP=3.1974 D_real=20.1458 D_fake=4.5744 | G_loss=-4.0886 Corr=0.0358
# [Epoch 133] L=10 step 1/1 | D_loss=-3.8756 GP=0.2149 D_real=8.8990 D_fake=4.8085 | G_loss=-4.3447 Corr=0.0412
# [Epoch 133] L=20 step 1/1 | D_loss=-6.2510 GP=0.8048 D_real=11.5828 D_fake=4.5269 | G_loss=-4.0454 Corr=0.0395
# [Epoch 133] L=30 step 1/1 | D_loss=-7.8610 GP=1.7737 D_real=13.5109 D_fake=3.8763 | G_loss=-3.3815 Corr=0.0359
# [Epoch 133] L=40 step 1/1 | D_loss=-9.6198 GP=1.9142 D_real=15.0639 D_fake=3.5298 | G_loss=-3.3059 Corr=0.0359
# [Epoch 133] L=50 step 1/1 | D_loss=-10.8666 GP=2.9297 D_real=17.2860 D_fake=3.4896 | G_loss=-3.2367 Corr=0.0348
# [Epoch 133] L=60 step 1/1 | D_loss=-12.0888 GP=2.5365 D_real=18.7409 D_fake=4.1156 | G_loss=-3.7002 Corr=0.0361
# [Epoch 134] L=10 step 1/1 | D_loss=-4.0804 GP=0.7908 D_real=9.9378 D_fake=5.0666 | G_loss=-4.7174 Corr=0.0377
# [Epoch 134] L=20 step 1/1 | D_loss=-5.7424 GP=0.3085 D_real=11.2600 D_fake=5.2090 | G_loss=-4.7111 Corr=0.0345
# [Epoch 134] L=30 step 1/1 | D_loss=-7.8946 GP=1.3782 D_real=13.6475 D_fake=4.3746 | G_loss=-4.1114 Corr=0.0325
# [Epoch 134] L=40 step 1/1 | D_loss=-9.3761 GP=2.3905 D_real=16.2365 D_fake=4.4699 | G_loss=-4.0875 Corr=0.0355
# [Epoch 134] L=50 step 1/1 | D_loss=-10.8814 GP=2.2386 D_real=16.8733 D_fake=3.7532 | G_loss=-3.3913 Corr=0.0334
# [Epoch 134] L=60 step 1/1 | D_loss=-11.7603 GP=3.8889 D_real=19.6726 D_fake=4.0233 | G_loss=-3.7708 Corr=0.0361
# [Epoch 135] L=10 step 1/1 | D_loss=-4.0097 GP=0.3558 D_real=9.2281 D_fake=4.8625 | G_loss=-4.3338 Corr=0.0445
# [Epoch 135] L=20 step 1/1 | D_loss=-6.2432 GP=0.7711 D_real=11.4010 D_fake=4.3867 | G_loss=-3.8508 Corr=0.0407
# [Epoch 135] L=30 step 1/1 | D_loss=-8.2187 GP=1.3868 D_real=13.6807 D_fake=4.0753 | G_loss=-3.7873 Corr=0.0384
# [Epoch 135] L=40 step 1/1 | D_loss=-9.5649 GP=2.2838 D_real=15.7554 D_fake=3.9068 | G_loss=-3.6328 Corr=0.0375
# [Epoch 135] L=50 step 1/1 | D_loss=-10.6783 GP=2.2865 D_real=16.9829 D_fake=4.0181 | G_loss=-3.8063 Corr=0.0361
# [Epoch 135] L=60 step 1/1 | D_loss=-11.9820 GP=3.4554 D_real=19.2581 D_fake=3.8207 | G_loss=-3.4102 Corr=0.0349
# [Epoch 136] L=10 step 1/1 | D_loss=-3.4972 GP=0.5362 D_real=9.2513 D_fake=5.2179 | G_loss=-4.8301 Corr=0.0359
# [Epoch 136] L=20 step 1/1 | D_loss=-5.7086 GP=1.1311 D_real=11.9450 D_fake=5.1052 | G_loss=-4.7377 Corr=0.0324
# [Epoch 136] L=30 step 1/1 | D_loss=-7.7012 GP=1.7250 D_real=13.8063 D_fake=4.3801 | G_loss=-3.8335 Corr=0.0386
# [Epoch 136] L=40 step 1/1 | D_loss=-9.0807 GP=2.1106 D_real=14.8879 D_fake=3.6966 | G_loss=-3.3014 Corr=0.0370
# [Epoch 136] L=50 step 1/1 | D_loss=-10.7136 GP=2.8045 D_real=17.3096 D_fake=3.7915 | G_loss=-3.6141 Corr=0.0378
# [Epoch 136] L=60 step 1/1 | D_loss=-12.1230 GP=2.5836 D_real=18.5537 D_fake=3.8471 | G_loss=-3.5677 Corr=0.0346
# [Epoch 137] L=10 step 1/1 | D_loss=-3.7012 GP=0.3729 D_real=9.3319 D_fake=5.2579 | G_loss=-4.8954 Corr=0.0336
# [Epoch 137] L=20 step 1/1 | D_loss=-5.7180 GP=0.5733 D_real=11.6225 D_fake=5.3313 | G_loss=-4.8253 Corr=0.0340
# [Epoch 137] L=30 step 1/1 | D_loss=-7.6421 GP=2.0284 D_real=14.4341 D_fake=4.7637 | G_loss=-4.3208 Corr=0.0401
# [Epoch 137] L=40 step 1/1 | D_loss=-9.2517 GP=2.2498 D_real=15.5736 D_fake=4.0721 | G_loss=-3.6505 Corr=0.0309
# [Epoch 137] L=50 step 1/1 | D_loss=-11.0914 GP=2.4961 D_real=17.5129 D_fake=3.9254 | G_loss=-3.7324 Corr=0.0338
# [Epoch 137] L=60 step 1/1 | D_loss=-12.2730 GP=3.0016 D_real=19.0531 D_fake=3.7785 | G_loss=-3.4193 Corr=0.0341
# [Epoch 138] L=10 step 1/1 | D_loss=-3.8804 GP=0.2257 D_real=8.8189 D_fake=4.7128 | G_loss=-4.2607 Corr=0.0432
# [Epoch 138] L=20 step 1/1 | D_loss=-6.1079 GP=0.6485 D_real=11.5054 D_fake=4.7490 | G_loss=-4.2297 Corr=0.0461
# [Epoch 138] L=30 step 1/1 | D_loss=-7.7708 GP=1.6605 D_real=13.8610 D_fake=4.4297 | G_loss=-4.1053 Corr=0.0411
# [Epoch 138] L=40 step 1/1 | D_loss=-9.5790 GP=2.2232 D_real=16.2389 D_fake=4.4366 | G_loss=-3.8923 Corr=0.0376
# [Epoch 138] L=50 step 1/1 | D_loss=-11.2093 GP=2.3218 D_real=17.7499 D_fake=4.2188 | G_loss=-3.8925 Corr=0.0358
# [Epoch 138] L=60 step 1/1 | D_loss=-12.1386 GP=3.1154 D_real=18.6698 D_fake=3.4157 | G_loss=-3.0558 Corr=0.0394
# [Epoch 139] L=10 step 1/1 | D_loss=-4.0276 GP=0.4533 D_real=9.3530 D_fake=4.8721 | G_loss=-4.5246 Corr=0.0387
# [Epoch 139] L=20 step 1/1 | D_loss=-5.9381 GP=0.7854 D_real=12.1277 D_fake=5.4041 | G_loss=-4.9800 Corr=0.0321
# [Epoch 139] L=30 step 1/1 | D_loss=-7.7064 GP=1.9214 D_real=14.7520 D_fake=5.1241 | G_loss=-4.7992 Corr=0.0354
# [Epoch 139] L=40 step 1/1 | D_loss=-9.2987 GP=2.2780 D_real=16.4048 D_fake=4.8281 | G_loss=-4.3339 Corr=0.0392
# [Epoch 139] L=50 step 1/1 | D_loss=-11.1665 GP=2.6210 D_real=17.7866 D_fake=3.9992 | G_loss=-3.8589 Corr=0.0364
# [Epoch 139] L=60 step 1/1 | D_loss=-11.9811 GP=3.2192 D_real=19.1918 D_fake=3.9915 | G_loss=-3.6271 Corr=0.0347
# [Epoch 140] L=10 step 1/1 | D_loss=-3.9800 GP=0.1910 D_real=9.4304 D_fake=5.2594 | G_loss=-4.8976 Corr=0.0388
# [Epoch 140] L=20 step 1/1 | D_loss=-6.2324 GP=0.7240 D_real=12.3438 D_fake=5.3874 | G_loss=-5.0250 Corr=0.0324
# [Epoch 140] L=30 step 1/1 | D_loss=-7.8228 GP=1.7040 D_real=14.7225 D_fake=5.1957 | G_loss=-4.8124 Corr=0.0305
# [Epoch 140] L=40 step 1/1 | D_loss=-9.4615 GP=1.7062 D_real=15.4844 D_fake=4.3167 | G_loss=-3.9672 Corr=0.0322
# [Epoch 140] L=50 step 1/1 | D_loss=-10.9785 GP=2.7868 D_real=18.2813 D_fake=4.5161 | G_loss=-4.2581 Corr=0.0316
# [Epoch 140] L=60 step 1/1 | D_loss=-12.3429 GP=3.0441 D_real=19.5326 D_fake=4.1456 | G_loss=-3.9600 Corr=0.0303
# [Epoch 141] L=10 step 1/1 | D_loss=-4.1266 GP=0.3792 D_real=9.4406 D_fake=4.9348 | G_loss=-4.6442 Corr=0.0322
# [Epoch 141] L=20 step 1/1 | D_loss=-6.0887 GP=0.7350 D_real=11.9204 D_fake=5.0967 | G_loss=-4.6552 Corr=0.0312
# [Epoch 141] L=30 step 1/1 | D_loss=-8.1356 GP=2.0664 D_real=14.6228 D_fake=4.4208 | G_loss=-4.1733 Corr=0.0300
# [Epoch 141] L=40 step 1/1 | D_loss=-9.6506 GP=2.3092 D_real=16.3027 D_fake=4.3429 | G_loss=-3.9836 Corr=0.0292
# [Epoch 141] L=50 step 1/1 | D_loss=-11.0802 GP=2.4082 D_real=17.4575 D_fake=3.9691 | G_loss=-3.7285 Corr=0.0286
# [Epoch 141] L=60 step 1/1 | D_loss=-12.1534 GP=3.9254 D_real=19.5697 D_fake=3.4909 | G_loss=-3.4223 Corr=0.0264
# [Epoch 142] L=10 step 1/1 | D_loss=-3.9338 GP=0.2019 D_real=9.3233 D_fake=5.1876 | G_loss=-4.9163 Corr=0.0308
# [Epoch 142] L=20 step 1/1 | D_loss=-6.0830 GP=0.8582 D_real=12.3577 D_fake=5.4164 | G_loss=-5.0533 Corr=0.0265
# [Epoch 142] L=30 step 1/1 | D_loss=-8.1320 GP=1.8910 D_real=15.0390 D_fake=5.0159 | G_loss=-4.7272 Corr=0.0289
# [Epoch 142] L=40 step 1/1 | D_loss=-9.4407 GP=2.2516 D_real=16.1597 D_fake=4.4674 | G_loss=-4.1763 Corr=0.0308
# [Epoch 142] L=50 step 1/1 | D_loss=-10.9429 GP=2.8787 D_real=18.1807 D_fake=4.3592 | G_loss=-4.0472 Corr=0.0260
# [Epoch 142] L=60 step 1/1 | D_loss=-12.4825 GP=3.1657 D_real=19.7981 D_fake=4.1499 | G_loss=-3.9768 Corr=0.0268
# [Epoch 143] L=10 step 1/1 | D_loss=-4.0352 GP=0.3561 D_real=9.2906 D_fake=4.8993 | G_loss=-4.6099 Corr=0.0302
# [Epoch 143] L=20 step 1/1 | D_loss=-6.2005 GP=0.8196 D_real=11.9367 D_fake=4.9166 | G_loss=-4.5486 Corr=0.0281
# [Epoch 143] L=30 step 1/1 | D_loss=-7.9971 GP=1.8005 D_real=14.2304 D_fake=4.4328 | G_loss=-4.1567 Corr=0.0263
# [Epoch 143] L=40 step 1/1 | D_loss=-9.6162 GP=2.0182 D_real=15.8973 D_fake=4.2629 | G_loss=-4.0363 Corr=0.0295
# [Epoch 143] L=50 step 1/1 | D_loss=-11.1894 GP=2.8783 D_real=18.0134 D_fake=3.9457 | G_loss=-3.6804 Corr=0.0247
# [Epoch 143] L=60 step 1/1 | D_loss=-12.2671 GP=2.8068 D_real=18.9847 D_fake=3.9107 | G_loss=-3.7140 Corr=0.0244
# [Epoch 144] L=10 step 1/1 | D_loss=-3.9313 GP=0.2295 D_real=9.1153 D_fake=4.9546 | G_loss=-4.5953 Corr=0.0311
# [Epoch 144] L=20 step 1/1 | D_loss=-6.1041 GP=0.8790 D_real=11.6380 D_fake=4.6549 | G_loss=-4.3487 Corr=0.0281
# [Epoch 144] L=30 step 1/1 | D_loss=-7.8976 GP=1.4516 D_real=13.5485 D_fake=4.1994 | G_loss=-3.9026 Corr=0.0288
# [Epoch 144] L=40 step 1/1 | D_loss=-9.2619 GP=2.0679 D_real=15.5391 D_fake=4.2093 | G_loss=-3.9120 Corr=0.0250
# [Epoch 144] L=50 step 1/1 | D_loss=-11.2598 GP=2.8656 D_real=18.1413 D_fake=4.0158 | G_loss=-3.8303 Corr=0.0235
# [Epoch 144] L=60 step 1/1 | D_loss=-12.1804 GP=2.7132 D_real=18.6900 D_fake=3.7964 | G_loss=-3.5919 Corr=0.0266
# [Epoch 145] L=10 step 1/1 | D_loss=-4.0301 GP=0.5738 D_real=9.4312 D_fake=4.8272 | G_loss=-4.5615 Corr=0.0270
# [Epoch 145] L=20 step 1/1 | D_loss=-6.0078 GP=0.3855 D_real=11.0697 D_fake=4.6763 | G_loss=-4.2612 Corr=0.0305
# [Epoch 145] L=30 step 1/1 | D_loss=-8.1998 GP=1.9263 D_real=13.8873 D_fake=3.7611 | G_loss=-3.3655 Corr=0.0332
# [Epoch 145] L=40 step 1/1 | D_loss=-9.6597 GP=2.0656 D_real=15.1839 D_fake=3.4586 | G_loss=-3.1991 Corr=0.0295
# [Epoch 145] L=50 step 1/1 | D_loss=-11.2115 GP=2.5159 D_real=17.4697 D_fake=3.7422 | G_loss=-3.5291 Corr=0.0263
# [Epoch 145] L=60 step 1/1 | D_loss=-12.3510 GP=2.7081 D_real=18.8350 D_fake=3.7760 | G_loss=-3.6823 Corr=0.0258
# [Epoch 146] L=10 step 1/1 | D_loss=-3.9547 GP=0.6497 D_real=9.6903 D_fake=5.0859 | G_loss=-4.7419 Corr=0.0309
# [Epoch 146] L=20 step 1/1 | D_loss=-5.8645 GP=0.5039 D_real=11.5184 D_fake=5.1501 | G_loss=-4.7629 Corr=0.0315
# [Epoch 146] L=30 step 1/1 | D_loss=-7.5965 GP=1.8068 D_real=13.8814 D_fake=4.4781 | G_loss=-4.2155 Corr=0.0356
# [Epoch 146] L=40 step 1/1 | D_loss=-9.4385 GP=1.9652 D_real=16.3146 D_fake=4.9109 | G_loss=-4.5618 Corr=0.0301
# [Epoch 146] L=50 step 1/1 | D_loss=-10.5798 GP=2.3792 D_real=16.8440 D_fake=3.8850 | G_loss=-3.5068 Corr=0.0299
# [Epoch 146] L=60 step 1/1 | D_loss=-12.6408 GP=3.3564 D_real=20.2906 D_fake=4.2934 | G_loss=-4.5517 Corr=0.0282
# [Epoch 147] L=10 step 1/1 | D_loss=-3.6359 GP=0.1724 D_real=9.1897 D_fake=5.3815 | G_loss=-5.0122 Corr=0.0337
# [Epoch 147] L=20 step 1/1 | D_loss=-5.7396 GP=1.3887 D_real=12.5392 D_fake=5.4109 | G_loss=-4.9056 Corr=0.0267
# [Epoch 147] L=30 step 1/1 | D_loss=-7.5312 GP=1.0336 D_real=13.4058 D_fake=4.8409 | G_loss=-4.5280 Corr=0.0287
# [Epoch 147] L=40 step 1/1 | D_loss=-9.0955 GP=2.2986 D_real=15.7782 D_fake=4.3842 | G_loss=-4.2058 Corr=0.0270
# [Epoch 147] L=50 step 1/1 | D_loss=-10.7992 GP=2.6182 D_real=17.9352 D_fake=4.5179 | G_loss=-4.2546 Corr=0.0272
# [Epoch 147] L=60 step 1/1 | D_loss=-12.1946 GP=2.9538 D_real=18.5801 D_fake=3.4317 | G_loss=-3.0898 Corr=0.0301
# [Epoch 148] L=10 step 1/1 | D_loss=-3.6136 GP=0.3417 D_real=8.7210 D_fake=4.7658 | G_loss=-4.3704 Corr=0.0379
# [Epoch 148] L=20 step 1/1 | D_loss=-5.9287 GP=1.1339 D_real=11.4265 D_fake=4.3639 | G_loss=-3.8982 Corr=0.0341
# [Epoch 148] L=30 step 1/1 | D_loss=-7.8098 GP=1.1223 D_real=12.6124 D_fake=3.6803 | G_loss=-3.3677 Corr=0.0295
# [Epoch 148] L=40 step 1/1 | D_loss=-9.1757 GP=2.2796 D_real=14.9736 D_fake=3.5183 | G_loss=-3.2624 Corr=0.0318
# [Epoch 148] L=50 step 1/1 | D_loss=-10.8839 GP=2.2556 D_real=16.8064 D_fake=3.6669 | G_loss=-3.3519 Corr=0.0329
# [Epoch 148] L=60 step 1/1 | D_loss=-11.7050 GP=3.4475 D_real=18.3770 D_fake=3.2244 | G_loss=-2.9544 Corr=0.0338
# [Epoch 149] L=10 step 1/1 | D_loss=-3.7905 GP=0.4877 D_real=9.2109 D_fake=4.9327 | G_loss=-4.5485 Corr=0.0363
# [Epoch 149] L=20 step 1/1 | D_loss=-6.0081 GP=0.7610 D_real=11.5929 D_fake=4.8238 | G_loss=-4.3762 Corr=0.0366
# [Epoch 149] L=30 step 1/1 | D_loss=-7.9104 GP=1.7056 D_real=14.0484 D_fake=4.4323 | G_loss=-4.0032 Corr=0.0406
# [Epoch 149] L=40 step 1/1 | D_loss=-9.5872 GP=2.3311 D_real=15.2683 D_fake=3.3501 | G_loss=-2.9628 Corr=0.0411
# [Epoch 149] L=50 step 1/1 | D_loss=-11.3347 GP=2.4772 D_real=17.2925 D_fake=3.4805 | G_loss=-3.2849 Corr=0.0404
# [Epoch 149] L=60 step 1/1 | D_loss=-11.8877 GP=3.3690 D_real=20.3789 D_fake=5.1221 | G_loss=-4.8510 Corr=0.0375
# [Epoch 150] L=10 step 1/1 | D_loss=-3.9050 GP=0.2297 D_real=9.5977 D_fake=5.4630 | G_loss=-5.0479 Corr=0.0373
# [Epoch 150] L=20 step 1/1 | D_loss=-5.9410 GP=0.9764 D_real=12.5525 D_fake=5.6351 | G_loss=-5.1484 Corr=0.0422
# [Epoch 150] L=30 step 1/1 | D_loss=-7.9630 GP=1.5661 D_real=14.7731 D_fake=5.2440 | G_loss=-4.7003 Corr=0.0399
# [Epoch 150] L=40 step 1/1 | D_loss=-9.3065 GP=2.6865 D_real=16.7755 D_fake=4.7825 | G_loss=-4.3099 Corr=0.0424
# [Epoch 150] L=50 step 1/1 | D_loss=-10.7672 GP=2.3821 D_real=17.2685 D_fake=4.1192 | G_loss=-3.6340 Corr=0.0525
# [Epoch 150] L=60 step 1/1 | D_loss=-11.9908 GP=2.9050 D_real=19.4454 D_fake=4.5496 | G_loss=-4.1215 Corr=0.0457
# [Epoch 151] L=10 step 1/1 | D_loss=-3.8488 GP=0.1839 D_real=8.8770 D_fake=4.8443 | G_loss=-4.3708 Corr=0.0440
# [Epoch 151] L=20 step 1/1 | D_loss=-6.0742 GP=1.2087 D_real=11.9970 D_fake=4.7141 | G_loss=-4.2055 Corr=0.0381
# [Epoch 151] L=30 step 1/1 | D_loss=-7.6687 GP=1.1923 D_real=12.8520 D_fake=3.9910 | G_loss=-3.5735 Corr=0.0365
# [Epoch 151] L=40 step 1/1 | D_loss=-9.4249 GP=2.4250 D_real=15.8884 D_fake=4.0385 | G_loss=-3.6823 Corr=0.0388
# [Epoch 151] L=50 step 1/1 | D_loss=-10.9175 GP=2.2625 D_real=16.9891 D_fake=3.8091 | G_loss=-3.4746 Corr=0.0371
# [Epoch 151] L=60 step 1/1 | D_loss=-12.4713 GP=3.1566 D_real=19.4768 D_fake=3.8488 | G_loss=-3.6428 Corr=0.0356
# [Epoch 152] L=10 step 1/1 | D_loss=-3.9253 GP=0.2565 D_real=9.2436 D_fake=5.0619 | G_loss=-4.6677 Corr=0.0407
# [Epoch 152] L=20 step 1/1 | D_loss=-5.9746 GP=0.6680 D_real=11.9511 D_fake=5.3084 | G_loss=-4.7789 Corr=0.0402
# [Epoch 152] L=30 step 1/1 | D_loss=-7.8343 GP=1.5918 D_real=14.3721 D_fake=4.9460 | G_loss=-4.6346 Corr=0.0430
# [Epoch 152] L=40 step 1/1 | D_loss=-9.1058 GP=1.8588 D_real=15.7669 D_fake=4.8022 | G_loss=-4.1658 Corr=0.0455
# [Epoch 152] L=50 step 1/1 | D_loss=-10.7669 GP=2.1987 D_real=17.7271 D_fake=4.7615 | G_loss=-4.6190 Corr=0.0384
# [Epoch 152] L=60 step 1/1 | D_loss=-11.8191 GP=2.9687 D_real=19.5529 D_fake=4.7651 | G_loss=-4.4085 Corr=0.0423
# [Epoch 153] L=10 step 1/1 | D_loss=-3.8948 GP=0.5289 D_real=9.5831 D_fake=5.1595 | G_loss=-4.6322 Corr=0.0471
# [Epoch 153] L=20 step 1/1 | D_loss=-6.0388 GP=0.6268 D_real=11.6227 D_fake=4.9572 | G_loss=-4.4401 Corr=0.0375
# [Epoch 153] L=30 step 1/1 | D_loss=-7.7178 GP=1.4176 D_real=13.2476 D_fake=4.1123 | G_loss=-3.6280 Corr=0.0355
# [Epoch 153] L=40 step 1/1 | D_loss=-9.2182 GP=2.2000 D_real=14.9691 D_fake=3.5509 | G_loss=-3.2119 Corr=0.0332
# [Epoch 153] L=50 step 1/1 | D_loss=-10.6823 GP=2.5400 D_real=16.8927 D_fake=3.6704 | G_loss=-3.3847 Corr=0.0372
# [Epoch 153] L=60 step 1/1 | D_loss=-12.0409 GP=3.4485 D_real=19.2713 D_fake=3.7820 | G_loss=-3.4958 Corr=0.0324
# [Epoch 154] L=10 step 1/1 | D_loss=-3.7427 GP=0.2862 D_real=8.9592 D_fake=4.9303 | G_loss=-4.5352 Corr=0.0386
# [Epoch 154] L=20 step 1/1 | D_loss=-6.1277 GP=0.8640 D_real=11.8600 D_fake=4.8682 | G_loss=-4.4105 Corr=0.0390
# [Epoch 154] L=30 step 1/1 | D_loss=-7.9184 GP=1.4069 D_real=13.7425 D_fake=4.4171 | G_loss=-3.9261 Corr=0.0389
# [Epoch 154] L=40 step 1/1 | D_loss=-9.4249 GP=2.2689 D_real=15.3608 D_fake=3.6670 | G_loss=-3.3331 Corr=0.0356
# [Epoch 154] L=50 step 1/1 | D_loss=-10.6668 GP=2.6237 D_real=16.9951 D_fake=3.7046 | G_loss=-3.3444 Corr=0.0329
# [Epoch 154] L=60 step 1/1 | D_loss=-12.1139 GP=3.2872 D_real=18.4244 D_fake=3.0234 | G_loss=-2.6780 Corr=0.0327
# [Epoch 155] L=10 step 1/1 | D_loss=-3.9408 GP=0.2119 D_real=8.5270 D_fake=4.3742 | G_loss=-4.0235 Corr=0.0367
# [Epoch 155] L=20 step 1/1 | D_loss=-6.1973 GP=1.0349 D_real=11.3727 D_fake=4.1404 | G_loss=-3.7550 Corr=0.0326
# [Epoch 155] L=30 step 1/1 | D_loss=-7.7282 GP=1.1597 D_real=12.6831 D_fake=3.7952 | G_loss=-3.5659 Corr=0.0277
# [Epoch 155] L=40 step 1/1 | D_loss=-9.1611 GP=2.3626 D_real=15.4387 D_fake=3.9149 | G_loss=-3.6877 Corr=0.0306
# [Epoch 155] L=50 step 1/1 | D_loss=-10.9229 GP=2.1628 D_real=17.0700 D_fake=3.9844 | G_loss=-3.6420 Corr=0.0352
# [Epoch 155] L=60 step 1/1 | D_loss=-11.8784 GP=3.2838 D_real=18.8873 D_fake=3.7251 | G_loss=-3.3524 Corr=0.0338
# [Epoch 156] L=10 step 1/1 | D_loss=-3.7862 GP=0.2189 D_real=8.4435 D_fake=4.4384 | G_loss=-4.0326 Corr=0.0371
# [Epoch 156] L=20 step 1/1 | D_loss=-5.8843 GP=1.0869 D_real=11.1719 D_fake=4.2007 | G_loss=-3.8085 Corr=0.0313
# [Epoch 156] L=30 step 1/1 | D_loss=-7.7681 GP=1.5681 D_real=13.4272 D_fake=4.0910 | G_loss=-3.7798 Corr=0.0336
# [Epoch 156] L=40 step 1/1 | D_loss=-9.2416 GP=1.9135 D_real=14.8776 D_fake=3.7225 | G_loss=-3.2710 Corr=0.0359
# [Epoch 156] L=50 step 1/1 | D_loss=-10.9033 GP=2.9382 D_real=17.3000 D_fake=3.4585 | G_loss=-3.2528 Corr=0.0359
# [Epoch 156] L=60 step 1/1 | D_loss=-11.8731 GP=2.6137 D_real=18.3254 D_fake=3.8385 | G_loss=-3.5563 Corr=0.0352
# [Epoch 157] L=10 step 1/1 | D_loss=-3.2906 GP=0.1925 D_real=8.9104 D_fake=5.4273 | G_loss=-5.0391 Corr=0.0401
# [Epoch 157] L=20 step 1/1 | D_loss=-5.2985 GP=1.3974 D_real=12.9234 D_fake=6.2276 | G_loss=-5.6323 Corr=0.0418
# [Epoch 157] L=30 step 1/1 | D_loss=-6.8637 GP=1.1660 D_real=13.9639 D_fake=5.9342 | G_loss=-5.1064 Corr=0.0601
# [Epoch 157] L=40 step 1/1 | D_loss=-8.8297 GP=2.4063 D_real=16.0973 D_fake=4.8612 | G_loss=-4.2419 Corr=0.0859
# [Epoch 157] L=50 step 1/1 | D_loss=-10.5009 GP=2.7410 D_real=19.9597 D_fake=6.7177 | G_loss=-6.1681 Corr=0.0771
# [Epoch 157] L=60 step 1/1 | D_loss=-11.1187 GP=2.1927 D_real=21.4611 D_fake=8.1498 | G_loss=-7.0919 Corr=0.0726
# [Epoch 158] L=10 step 1/1 | D_loss=-1.5838 GP=1.1071 D_real=9.7528 D_fake=7.0619 | G_loss=-6.3659 Corr=0.0478
# [Epoch 158] L=20 step 1/1 | D_loss=-4.4738 GP=1.0302 D_real=12.6755 D_fake=7.1715 | G_loss=-6.4484 Corr=0.0574
# [Epoch 158] L=30 step 1/1 | D_loss=-6.8006 GP=1.5034 D_real=14.9908 D_fake=6.6868 | G_loss=-6.0355 Corr=0.0635
# [Epoch 158] L=40 step 1/1 | D_loss=-9.0923 GP=2.2082 D_real=17.9103 D_fake=6.6098 | G_loss=-5.7268 Corr=0.0720
# [Epoch 158] L=50 step 1/1 | D_loss=-11.0036 GP=2.8919 D_real=19.7045 D_fake=5.8090 | G_loss=-5.0715 Corr=0.0790
# [Epoch 158] L=60 step 1/1 | D_loss=-12.5755 GP=2.7188 D_real=21.2804 D_fake=5.9861 | G_loss=-5.2813 Corr=0.0786
# [Epoch 159] L=10 step 1/1 | D_loss=-3.7757 GP=0.4159 D_real=10.3820 D_fake=6.1904 | G_loss=-5.3255 Corr=0.0887
# [Epoch 159] L=20 step 1/1 | D_loss=-5.4966 GP=0.1312 D_real=12.0968 D_fake=6.4690 | G_loss=-5.3938 Corr=0.0815
# [Epoch 159] L=30 step 1/1 | D_loss=-8.0703 GP=2.7331 D_real=15.8868 D_fake=5.0835 | G_loss=-4.1725 Corr=0.0719
# [Epoch 159] L=40 step 1/1 | D_loss=-9.6335 GP=2.9328 D_real=17.6439 D_fake=5.0776 | G_loss=-4.4582 Corr=0.0733
# [Epoch 159] L=50 step 1/1 | D_loss=-11.1449 GP=2.4644 D_real=18.5438 D_fake=4.9344 | G_loss=-4.1169 Corr=0.0707
# [Epoch 159] L=60 step 1/1 | D_loss=-12.0894 GP=3.7621 D_real=20.6755 D_fake=4.8240 | G_loss=-4.1607 Corr=0.0726
# [Epoch 160] L=10 step 1/1 | D_loss=-4.0381 GP=0.4029 D_real=9.8809 D_fake=5.4398 | G_loss=-4.7808 Corr=0.0681
# [Epoch 160] L=20 step 1/1 | D_loss=-5.5437 GP=0.1466 D_real=11.0682 D_fake=5.3780 | G_loss=-4.4906 Corr=0.0712
# [Epoch 160] L=30 step 1/1 | D_loss=-7.6813 GP=1.8379 D_real=13.9730 D_fake=4.4538 | G_loss=-3.7125 Corr=0.0663
# [Epoch 160] L=40 step 1/1 | D_loss=-9.6712 GP=2.6703 D_real=16.9230 D_fake=4.5815 | G_loss=-4.1180 Corr=0.0650
# [Epoch 160] L=50 step 1/1 | D_loss=-11.5220 GP=2.8244 D_real=19.3157 D_fake=4.9693 | G_loss=-4.2876 Corr=0.0639
# [Epoch 160] L=60 step 1/1 | D_loss=-13.1711 GP=3.8698 D_real=21.7745 D_fake=4.7336 | G_loss=-4.1388 Corr=0.0655
# [Epoch 161] L=10 step 1/1 | D_loss=-4.0660 GP=0.5412 D_real=10.0983 D_fake=5.4912 | G_loss=-4.8690 Corr=0.0657
# [Epoch 161] L=20 step 1/1 | D_loss=-5.8634 GP=0.4625 D_real=12.6511 D_fake=6.3253 | G_loss=-5.7366 Corr=0.0619
# [Epoch 161] L=30 step 1/1 | D_loss=-7.6463 GP=1.1493 D_real=15.6134 D_fake=6.8178 | G_loss=-6.0570 Corr=0.0629
# [Epoch 161] L=40 step 1/1 | D_loss=-9.0284 GP=2.2765 D_real=17.6676 D_fake=6.3627 | G_loss=-5.3756 Corr=0.0694
# [Epoch 161] L=50 step 1/1 | D_loss=-10.4400 GP=2.4220 D_real=18.5137 D_fake=5.6517 | G_loss=-4.7541 Corr=0.0683
# [Epoch 161] L=60 step 1/1 | D_loss=-11.7622 GP=3.2562 D_real=19.5263 D_fake=4.5079 | G_loss=-3.5261 Corr=0.0765
# [Epoch 162] L=10 step 1/1 | D_loss=-3.8544 GP=0.4104 D_real=9.6664 D_fake=5.4016 | G_loss=-4.5083 Corr=0.0821
# [Epoch 162] L=20 step 1/1 | D_loss=-5.9786 GP=0.5847 D_real=11.8147 D_fake=5.2514 | G_loss=-4.4634 Corr=0.0769
# [Epoch 162] L=30 step 1/1 | D_loss=-7.4661 GP=0.8721 D_real=13.7286 D_fake=5.3904 | G_loss=-4.5606 Corr=0.0772
# [Epoch 162] L=40 step 1/1 | D_loss=-8.8767 GP=1.8060 D_real=15.3848 D_fake=4.7021 | G_loss=-3.6960 Corr=0.0792
# [Epoch 162] L=50 step 1/1 | D_loss=-10.6481 GP=3.5059 D_real=17.8253 D_fake=3.6712 | G_loss=-2.7486 Corr=0.0812
# [Epoch 162] L=60 step 1/1 | D_loss=-12.2125 GP=2.5392 D_real=18.4637 D_fake=3.7120 | G_loss=-3.0674 Corr=0.0815
# [Epoch 163] L=10 step 1/1 | D_loss=-4.0281 GP=0.5954 D_real=9.8638 D_fake=5.2403 | G_loss=-4.4801 Corr=0.0763
# [Epoch 163] L=20 step 1/1 | D_loss=-6.2671 GP=1.0818 D_real=12.5005 D_fake=5.1515 | G_loss=-4.2801 Corr=0.0819
# [Epoch 163] L=30 step 1/1 | D_loss=-8.0710 GP=1.1112 D_real=13.6098 D_fake=4.4276 | G_loss=-3.5532 Corr=0.0803
# [Epoch 163] L=40 step 1/1 | D_loss=-9.7783 GP=2.3338 D_real=16.0575 D_fake=3.9455 | G_loss=-3.1531 Corr=0.0770
# [Epoch 163] L=50 step 1/1 | D_loss=-10.9663 GP=2.8016 D_real=17.7756 D_fake=4.0077 | G_loss=-3.3329 Corr=0.0786
# [Epoch 163] L=60 step 1/1 | D_loss=-12.3138 GP=2.9229 D_real=19.4478 D_fake=4.2111 | G_loss=-3.4411 Corr=0.0731
# [Epoch 164] L=10 step 1/1 | D_loss=-4.2471 GP=0.6162 D_real=10.2404 D_fake=5.3771 | G_loss=-4.6477 Corr=0.0740
# [Epoch 164] L=20 step 1/1 | D_loss=-6.2024 GP=0.5551 D_real=12.3331 D_fake=5.5756 | G_loss=-4.7672 Corr=0.0720
# [Epoch 164] L=30 step 1/1 | D_loss=-8.0953 GP=1.1515 D_real=13.9248 D_fake=4.6779 | G_loss=-3.8528 Corr=0.0679
# [Epoch 164] L=40 step 1/1 | D_loss=-9.6041 GP=2.3708 D_real=16.3233 D_fake=4.3483 | G_loss=-3.7358 Corr=0.0667
# [Epoch 164] L=50 step 1/1 | D_loss=-10.7097 GP=2.9388 D_real=17.9947 D_fake=4.3463 | G_loss=-3.7993 Corr=0.0646
# [Epoch 164] L=60 step 1/1 | D_loss=-12.2557 GP=2.4845 D_real=19.3522 D_fake=4.6121 | G_loss=-3.9963 Corr=0.0635
# [Epoch 165] L=10 step 1/1 | D_loss=-3.7895 GP=0.6503 D_real=10.0434 D_fake=5.6035 | G_loss=-4.9191 Corr=0.0675
# [Epoch 165] L=20 step 1/1 | D_loss=-5.5853 GP=0.7513 D_real=12.3268 D_fake=5.9902 | G_loss=-5.3104 Corr=0.0620
# [Epoch 165] L=30 step 1/1 | D_loss=-7.2935 GP=1.1218 D_real=14.3769 D_fake=5.9616 | G_loss=-5.3239 Corr=0.0703
# [Epoch 165] L=40 step 1/1 | D_loss=-9.1373 GP=2.3871 D_real=17.7565 D_fake=6.2321 | G_loss=-5.5609 Corr=0.0716
# [Epoch 165] L=50 step 1/1 | D_loss=-10.5036 GP=2.1389 D_real=18.9455 D_fake=6.3030 | G_loss=-5.3356 Corr=0.0715
# [Epoch 165] L=60 step 1/1 | D_loss=-11.7939 GP=3.1426 D_real=19.9441 D_fake=5.0076 | G_loss=-4.1401 Corr=0.0691
# [Epoch 166] L=10 step 1/1 | D_loss=-3.6879 GP=0.5450 D_real=9.9629 D_fake=5.7300 | G_loss=-4.9455 Corr=0.0693
# [Epoch 166] L=20 step 1/1 | D_loss=-5.9658 GP=0.7669 D_real=12.3819 D_fake=5.6492 | G_loss=-4.9260 Corr=0.0702
# [Epoch 166] L=30 step 1/1 | D_loss=-7.5721 GP=1.4047 D_real=14.1989 D_fake=5.2222 | G_loss=-4.2783 Corr=0.0739
# [Epoch 166] L=40 step 1/1 | D_loss=-9.5934 GP=2.2774 D_real=16.2281 D_fake=4.3574 | G_loss=-3.6504 Corr=0.0758
# [Epoch 166] L=50 step 1/1 | D_loss=-11.0661 GP=2.7254 D_real=18.5627 D_fake=4.7712 | G_loss=-4.0392 Corr=0.0784
# [Epoch 166] L=60 step 1/1 | D_loss=-12.9271 GP=2.7844 D_real=20.7449 D_fake=5.0334 | G_loss=-4.3790 Corr=0.0735
# [Epoch 167] L=10 step 1/1 | D_loss=-3.9014 GP=0.6276 D_real=10.2366 D_fake=5.7076 | G_loss=-4.9730 Corr=0.0697
# [Epoch 167] L=20 step 1/1 | D_loss=-6.2444 GP=0.7305 D_real=12.5186 D_fake=5.5437 | G_loss=-4.7620 Corr=0.0659
# [Epoch 167] L=30 step 1/1 | D_loss=-8.0034 GP=1.2421 D_real=13.9876 D_fake=4.7420 | G_loss=-3.9487 Corr=0.0661
# [Epoch 167] L=40 step 1/1 | D_loss=-9.6083 GP=2.3711 D_real=16.2935 D_fake=4.3141 | G_loss=-3.5831 Corr=0.0676
# [Epoch 167] L=50 step 1/1 | D_loss=-11.3157 GP=2.4127 D_real=17.9616 D_fake=4.2332 | G_loss=-3.5523 Corr=0.0655
# [Epoch 167] L=60 step 1/1 | D_loss=-12.5487 GP=3.3671 D_real=20.0147 D_fake=4.0989 | G_loss=-3.5147 Corr=0.0636
# [Epoch 168] L=10 step 1/1 | D_loss=-4.0190 GP=0.5508 D_real=9.8749 D_fake=5.3051 | G_loss=-4.7037 Corr=0.0606
# [Epoch 168] L=20 step 1/1 | D_loss=-6.1161 GP=0.6794 D_real=12.0701 D_fake=5.2745 | G_loss=-4.5767 Corr=0.0595
# [Epoch 168] L=30 step 1/1 | D_loss=-7.9124 GP=1.4346 D_real=14.1000 D_fake=4.7529 | G_loss=-4.0393 Corr=0.0646
# [Epoch 168] L=40 step 1/1 | D_loss=-9.4119 GP=2.0371 D_real=16.2048 D_fake=4.7559 | G_loss=-4.2306 Corr=0.0667
# [Epoch 168] L=50 step 1/1 | D_loss=-10.9192 GP=2.5551 D_real=17.8945 D_fake=4.4203 | G_loss=-3.7531 Corr=0.0649
# [Epoch 168] L=60 step 1/1 | D_loss=-12.3960 GP=3.0744 D_real=19.8577 D_fake=4.3873 | G_loss=-3.8900 Corr=0.0658
# [Epoch 169] L=10 step 1/1 | D_loss=-4.0456 GP=0.5002 D_real=9.7599 D_fake=5.2141 | G_loss=-4.6383 Corr=0.0570
# [Epoch 169] L=20 step 1/1 | D_loss=-6.0739 GP=0.6116 D_real=12.0361 D_fake=5.3506 | G_loss=-4.6509 Corr=0.0560
# [Epoch 169] L=30 step 1/1 | D_loss=-8.1756 GP=1.4987 D_real=14.5793 D_fake=4.9049 | G_loss=-4.2520 Corr=0.0596
# [Epoch 169] L=40 step 1/1 | D_loss=-9.3762 GP=2.5560 D_real=16.8054 D_fake=4.8731 | G_loss=-4.3043 Corr=0.0617
# [Epoch 169] L=50 step 1/1 | D_loss=-10.9609 GP=2.0026 D_real=17.9588 D_fake=4.9954 | G_loss=-4.3453 Corr=0.0598
# [Epoch 169] L=60 step 1/1 | D_loss=-12.0329 GP=2.7891 D_real=19.1182 D_fake=4.2963 | G_loss=-3.6262 Corr=0.0568
# [Epoch 170] L=10 step 1/1 | D_loss=-3.8525 GP=0.4138 D_real=9.3064 D_fake=5.0401 | G_loss=-4.4446 Corr=0.0557
# [Epoch 170] L=20 step 1/1 | D_loss=-6.0801 GP=0.8697 D_real=11.8772 D_fake=4.9275 | G_loss=-4.3853 Corr=0.0519
# [Epoch 170] L=30 step 1/1 | D_loss=-7.7626 GP=1.5641 D_real=13.8410 D_fake=4.5143 | G_loss=-3.9257 Corr=0.0486
# [Epoch 170] L=40 step 1/1 | D_loss=-9.4476 GP=2.1097 D_real=15.2843 D_fake=3.7270 | G_loss=-3.1770 Corr=0.0475
# [Epoch 170] L=50 step 1/1 | D_loss=-10.9084 GP=2.5443 D_real=16.9355 D_fake=3.4828 | G_loss=-3.1541 Corr=0.0461
# [Epoch 170] L=60 step 1/1 | D_loss=-11.9167 GP=2.8196 D_real=18.5927 D_fake=3.8564 | G_loss=-3.3957 Corr=0.0492
# [Epoch 171] L=10 step 1/1 | D_loss=-3.9618 GP=0.5195 D_real=9.7240 D_fake=5.2427 | G_loss=-4.6831 Corr=0.0532
# [Epoch 171] L=20 step 1/1 | D_loss=-6.1939 GP=0.6434 D_real=12.0622 D_fake=5.2249 | G_loss=-4.7432 Corr=0.0456
# [Epoch 171] L=30 step 1/1 | D_loss=-7.8971 GP=1.6727 D_real=14.1892 D_fake=4.6194 | G_loss=-4.0692 Corr=0.0425
# [Epoch 171] L=40 step 1/1 | D_loss=-9.5308 GP=1.9165 D_real=15.3651 D_fake=3.9178 | G_loss=-3.5205 Corr=0.0388
# [Epoch 171] L=50 step 1/1 | D_loss=-10.6974 GP=3.1872 D_real=17.2534 D_fake=3.3689 | G_loss=-3.0038 Corr=0.0395
# [Epoch 171] L=60 step 1/1 | D_loss=-12.1779 GP=2.4589 D_real=18.5704 D_fake=3.9336 | G_loss=-3.5065 Corr=0.0379
# [Epoch 172] L=10 step 1/1 | D_loss=-4.3205 GP=0.6834 D_real=10.2399 D_fake=5.2360 | G_loss=-4.8301 Corr=0.0379
# [Epoch 172] L=20 step 1/1 | D_loss=-6.3159 GP=0.5566 D_real=11.9884 D_fake=5.1160 | G_loss=-4.7076 Corr=0.0350
# [Epoch 172] L=30 step 1/1 | D_loss=-8.0960 GP=1.9804 D_real=14.5669 D_fake=4.4905 | G_loss=-4.0623 Corr=0.0381
# [Epoch 172] L=40 step 1/1 | D_loss=-9.5401 GP=1.4152 D_real=15.6239 D_fake=4.6686 | G_loss=-4.3211 Corr=0.0371
# ...
# [Epoch 177] L=20 step 1/1 | D_loss=-5.8859 GP=0.9780 D_real=11.9442 D_fake=5.0803 | G_loss=-4.6810 Corr=0.0269
# [Epoch 177] L=30 step 1/1 | D_loss=-7.8471 GP=1.2315 D_real=13.5745 D_fake=4.4959 | G_loss=-4.1845 Corr=0.0246
# [Epoch 177] L=40 step 1/1 | D_loss=-9.5876 GP=2.4229 D_real=15.9644 D_fake=3.9539 | G_loss=-3.7322 Corr=0.0235
# [Epoch 177] L=50 step 1/1 | D_loss=-10.6693 GP=2.3366 D_real=16.8751 D_fake=3.8691 | G_loss=-3.6175 Corr=0.0227
# [Epoch 177] L=60 step 1/1 | D_loss=-11.7552 GP=2.4977 D_real=17.9219 D_fake=3.6689 | G_loss=-3.2693 Corr=0.0307
# [Epoch 178] L=10 step 1/1 | D_loss=-3.8849 GP=0.4460 D_real=9.3665 D_fake=5.0356 | G_loss=-4.7692 Corr=0.0321
# [Epoch 178] L=20 step 1/1 | D_loss=-5.7351 GP=0.7000 D_real=11.6749 D_fake=5.2398 | G_loss=-4.9417 Corr=0.0272
# [Epoch 178] L=30 step 1/1 | D_loss=-7.7223 GP=1.6808 D_real=14.3830 D_fake=4.9799 | G_loss=-4.6150 Corr=0.0320
# [Epoch 178] L=40 step 1/1 | D_loss=-9.4630 GP=1.9894 D_real=16.0769 D_fake=4.6244 | G_loss=-4.2052 Corr=0.0328
# [Epoch 178] L=50 step 1/1 | D_loss=-11.0788 GP=3.3501 D_real=18.2865 D_fake=3.8576 | G_loss=-3.5882 Corr=0.0332
# [Epoch 178] L=60 step 1/1 | D_loss=-12.4159 GP=3.1440 D_real=19.3985 D_fake=3.8387 | G_loss=-3.5152 Corr=0.0314
# [Epoch 179] L=10 step 1/1 | D_loss=-3.8694 GP=0.1720 D_real=9.2914 D_fake=5.2500 | G_loss=-4.8825 Corr=0.0348
# [Epoch 179] L=20 step 1/1 | D_loss=-6.1406 GP=1.2970 D_real=12.6842 D_fake=5.2466 | G_loss=-4.8281 Corr=0.0320
# [Epoch 179] L=30 step 1/1 | D_loss=-8.0760 GP=1.3382 D_real=14.2520 D_fake=4.8377 | G_loss=-4.4120 Corr=0.0359
# [Epoch 179] L=40 step 1/1 | D_loss=-9.3419 GP=1.9614 D_real=16.0817 D_fake=4.7784 | G_loss=-4.5296 Corr=0.0335
# [Epoch 179] L=50 step 1/1 | D_loss=-10.6929 GP=2.4556 D_real=18.4779 D_fake=5.3294 | G_loss=-4.9799 Corr=0.0386
# [Epoch 179] L=60 step 1/1 | D_loss=-12.6642 GP=3.9345 D_real=21.2362 D_fake=4.6376 | G_loss=-4.0505 Corr=0.0382
# [Epoch 180] L=10 step 1/1 | D_loss=-3.7159 GP=0.1583 D_real=8.5923 D_fake=4.7180 | G_loss=-4.0973 Corr=0.0465
# [Epoch 180] L=20 step 1/1 | D_loss=-6.1486 GP=0.5267 D_real=11.2727 D_fake=4.5974 | G_loss=-4.1069 Corr=0.0468
# [Epoch 180] L=30 step 1/1 | D_loss=-7.6865 GP=2.1158 D_real=14.2108 D_fake=4.4085 | G_loss=-3.9995 Corr=0.0442
# [Epoch 180] L=40 step 1/1 | D_loss=-9.4698 GP=1.7522 D_real=15.7227 D_fake=4.5007 | G_loss=-4.2202 Corr=0.0392
# [Epoch 180] L=50 step 1/1 | D_loss=-10.7962 GP=2.8877 D_real=18.4636 D_fake=4.7796 | G_loss=-4.4626 Corr=0.0307
# [Epoch 180] L=60 step 1/1 | D_loss=-11.8260 GP=2.9361 D_real=19.1371 D_fake=4.3750 | G_loss=-3.9678 Corr=0.0325
# [Epoch 181] L=10 step 1/1 | D_loss=-3.5138 GP=0.2700 D_real=8.5630 D_fake=4.7792 | G_loss=-4.3248 Corr=0.0376
# [Epoch 181] L=20 step 1/1 | D_loss=-5.7482 GP=0.5324 D_real=10.8575 D_fake=4.5770 | G_loss=-4.1922 Corr=0.0284
# [Epoch 181] L=30 step 1/1 | D_loss=-7.5877 GP=1.4601 D_real=13.1182 D_fake=4.0704 | G_loss=-3.7516 Corr=0.0342
# [Epoch 181] L=40 step 1/1 | D_loss=-9.3552 GP=2.2332 D_real=15.6926 D_fake=4.1041 | G_loss=-3.7088 Corr=0.0335
# [Epoch 181] L=50 step 1/1 | D_loss=-10.7837 GP=2.9310 D_real=17.6215 D_fake=3.9068 | G_loss=-3.5282 Corr=0.0335
# [Epoch 181] L=60 step 1/1 | D_loss=-12.2204 GP=2.7788 D_real=19.2327 D_fake=4.2335 | G_loss=-3.9601 Corr=0.0315
# [Epoch 182] L=10 step 1/1 | D_loss=-4.1377 GP=0.4259 D_real=9.3386 D_fake=4.7750 | G_loss=-4.3724 Corr=0.0395
# [Epoch 182] L=20 step 1/1 | D_loss=-5.9535 GP=0.6538 D_real=11.3288 D_fake=4.7215 | G_loss=-4.2435 Corr=0.0346
# [Epoch 182] L=30 step 1/1 | D_loss=-8.1107 GP=1.4630 D_real=13.3749 D_fake=3.8011 | G_loss=-3.3150 Corr=0.0395
# [Epoch 182] L=40 step 1/1 | D_loss=-9.5615 GP=1.7742 D_real=14.9673 D_fake=3.6317 | G_loss=-3.2626 Corr=0.0451
# [Epoch 182] L=50 step 1/1 | D_loss=-11.0225 GP=2.9219 D_real=17.6836 D_fake=3.7393 | G_loss=-3.4242 Corr=0.0407
# [Epoch 182] L=60 step 1/1 | D_loss=-12.1551 GP=3.1022 D_real=18.9822 D_fake=3.7249 | G_loss=-3.2286 Corr=0.0443
# [Epoch 183] L=10 step 1/1 | D_loss=-3.9586 GP=0.5537 D_real=9.2427 D_fake=4.7304 | G_loss=-4.2992 Corr=0.0363
# [Epoch 183] L=20 step 1/1 | D_loss=-6.0747 GP=0.8928 D_real=11.5292 D_fake=4.5617 | G_loss=-4.1133 Corr=0.0444
# [Epoch 183] L=30 step 1/1 | D_loss=-7.5834 GP=1.0022 D_real=12.7454 D_fake=4.1597 | G_loss=-3.6200 Corr=0.0447
# [Epoch 183] L=40 step 1/1 | D_loss=-9.2579 GP=2.4366 D_real=15.4402 D_fake=3.7457 | G_loss=-3.2473 Corr=0.0472
# [Epoch 183] L=50 step 1/1 | D_loss=-10.8772 GP=2.8218 D_real=17.6099 D_fake=3.9109 | G_loss=-3.5161 Corr=0.0470
# [Epoch 183] L=60 step 1/1 | D_loss=-11.9905 GP=3.0653 D_real=19.1195 D_fake=4.0637 | G_loss=-3.5589 Corr=0.0505
# [Epoch 184] L=10 step 1/1 | D_loss=-3.9115 GP=0.5062 D_real=9.1157 D_fake=4.6981 | G_loss=-4.1423 Corr=0.0532
# [Epoch 184] L=20 step 1/1 | D_loss=-5.9114 GP=0.5935 D_real=10.9767 D_fake=4.4718 | G_loss=-3.9350 Corr=0.0497
# [Epoch 184] L=30 step 1/1 | D_loss=-7.9481 GP=1.5822 D_real=13.6283 D_fake=4.0980 | G_loss=-3.4670 Corr=0.0586
# [Epoch 184] L=40 step 1/1 | D_loss=-8.8936 GP=2.0576 D_real=14.9328 D_fake=3.9816 | G_loss=-3.4006 Corr=0.0685
# [Epoch 184] L=50 step 1/1 | D_loss=-10.1828 GP=2.4393 D_real=16.7752 D_fake=4.1531 | G_loss=-3.7705 Corr=0.0488
# [Epoch 184] L=60 step 1/1 | D_loss=-11.8137 GP=2.9554 D_real=18.6348 D_fake=3.8656 | G_loss=-3.3744 Corr=0.0498
# [Epoch 185] L=10 step 1/1 | D_loss=-3.8919 GP=0.4796 D_real=9.2705 D_fake=4.8990 | G_loss=-4.4909 Corr=0.0408
# [Epoch 185] L=20 step 1/1 | D_loss=-5.8029 GP=0.7244 D_real=11.3691 D_fake=4.8418 | G_loss=-4.3542 Corr=0.0377
# [Epoch 185] L=30 step 1/1 | D_loss=-7.3369 GP=0.9401 D_real=12.4320 D_fake=4.1550 | G_loss=-3.7697 Corr=0.0363
# [Epoch 185] L=40 step 1/1 | D_loss=-8.5816 GP=1.9497 D_real=14.8717 D_fake=4.3404 | G_loss=-3.7369 Corr=0.0517
# [Epoch 185] L=50 step 1/1 | D_loss=-10.5230 GP=2.9695 D_real=17.5595 D_fake=4.0670 | G_loss=-3.5764 Corr=0.0523
# [Epoch 185] L=60 step 1/1 | D_loss=-12.6554 GP=3.7883 D_real=19.8475 D_fake=3.4038 | G_loss=-2.8358 Corr=0.0554
# [Epoch 186] L=10 step 1/1 | D_loss=-3.9076 GP=0.4157 D_real=9.3991 D_fake=5.0758 | G_loss=-4.5306 Corr=0.0601
# [Epoch 186] L=20 step 1/1 | D_loss=-6.0584 GP=0.9538 D_real=12.2726 D_fake=5.2604 | G_loss=-4.6262 Corr=0.0579
# [Epoch 186] L=30 step 1/1 | D_loss=-8.1447 GP=1.3704 D_real=14.3252 D_fake=4.8101 | G_loss=-4.1363 Corr=0.0545
# [Epoch 186] L=40 step 1/1 | D_loss=-9.8482 GP=2.6754 D_real=16.7062 D_fake=4.1827 | G_loss=-3.6699 Corr=0.0497
# [Epoch 186] L=50 step 1/1 | D_loss=-11.6178 GP=2.6951 D_real=18.0732 D_fake=3.7604 | G_loss=-3.2223 Corr=0.0479
# [Epoch 186] L=60 step 1/1 | D_loss=-12.5067 GP=3.2560 D_real=19.4145 D_fake=3.6518 | G_loss=-3.1266 Corr=0.0486
# [Epoch 187] L=10 step 1/1 | D_loss=-4.4074 GP=0.3541 D_real=9.5889 D_fake=4.8274 | G_loss=-4.3480 Corr=0.0492
# [Epoch 187] L=20 step 1/1 | D_loss=-6.2696 GP=0.7843 D_real=11.6792 D_fake=4.6253 | G_loss=-4.1484 Corr=0.0420
# [Epoch 187] L=30 step 1/1 | D_loss=-8.2652 GP=1.7834 D_real=14.4917 D_fake=4.4432 | G_loss=-3.8914 Corr=0.0419
# [Epoch 187] L=40 step 1/1 | D_loss=-9.9560 GP=2.4272 D_real=16.3485 D_fake=3.9653 | G_loss=-3.5683 Corr=0.0463
# [Epoch 187] L=50 step 1/1 | D_loss=-11.6084 GP=3.0111 D_real=18.3418 D_fake=3.7224 | G_loss=-3.2450 Corr=0.0458
# [Epoch 187] L=60 step 1/1 | D_loss=-12.6126 GP=3.1079 D_real=19.4350 D_fake=3.7145 | G_loss=-3.3492 Corr=0.0447
# [Epoch 188] L=10 step 1/1 | D_loss=-4.1969 GP=0.3230 D_real=9.5749 D_fake=5.0550 | G_loss=-4.5535 Corr=0.0467
# [Epoch 188] L=20 step 1/1 | D_loss=-6.3053 GP=0.9041 D_real=11.8433 D_fake=4.6339 | G_loss=-4.0948 Corr=0.0469
# [Epoch 188] L=30 step 1/1 | D_loss=-8.1503 GP=1.5140 D_real=14.2552 D_fake=4.5908 | G_loss=-4.1972 Corr=0.0482
# [Epoch 188] L=40 step 1/1 | D_loss=-9.8867 GP=2.5701 D_real=16.8286 D_fake=4.3718 | G_loss=-3.8484 Corr=0.0428
# [Epoch 188] L=50 step 1/1 | D_loss=-11.1957 GP=2.3809 D_real=17.5154 D_fake=3.9388 | G_loss=-3.3881 Corr=0.0392
# [Epoch 188] L=60 step 1/1 | D_loss=-12.9641 GP=3.6180 D_real=20.0857 D_fake=3.5036 | G_loss=-3.2196 Corr=0.0352
# [Epoch 189] L=10 step 1/1 | D_loss=-4.1534 GP=0.4220 D_real=9.2471 D_fake=4.6716 | G_loss=-4.2694 Corr=0.0371
# [Epoch 189] L=20 step 1/1 | D_loss=-6.3753 GP=0.8566 D_real=11.6282 D_fake=4.3963 | G_loss=-4.0440 Corr=0.0350
# [Epoch 189] L=30 step 1/1 | D_loss=-8.1188 GP=1.4772 D_real=13.7725 D_fake=4.1765 | G_loss=-3.8906 Corr=0.0342
# [Epoch 189] L=40 step 1/1 | D_loss=-9.9332 GP=2.7458 D_real=16.8289 D_fake=4.1500 | G_loss=-3.7733 Corr=0.0346
# [Epoch 189] L=50 step 1/1 | D_loss=-11.3569 GP=2.2979 D_real=17.5999 D_fake=3.9452 | G_loss=-3.7152 Corr=0.0307
# [Epoch 189] L=60 step 1/1 | D_loss=-12.6300 GP=3.9797 D_real=20.3202 D_fake=3.7104 | G_loss=-3.5269 Corr=0.0309
# [Epoch 190] L=10 step 1/1 | D_loss=-4.0585 GP=0.2525 D_real=8.9975 D_fake=4.6865 | G_loss=-4.2880 Corr=0.0341
# [Epoch 190] L=20 step 1/1 | D_loss=-6.4247 GP=0.9795 D_real=12.0123 D_fake=4.6082 | G_loss=-4.2158 Corr=0.0301
# [Epoch 190] L=30 step 1/1 | D_loss=-7.9211 GP=1.6242 D_real=13.7787 D_fake=4.2334 | G_loss=-3.8175 Corr=0.0318
# [Epoch 190] L=40 step 1/1 | D_loss=-9.8598 GP=2.5137 D_real=16.3321 D_fake=3.9586 | G_loss=-3.6635 Corr=0.0321
# [Epoch 190] L=50 step 1/1 | D_loss=-11.5361 GP=3.4161 D_real=18.7199 D_fake=3.7677 | G_loss=-3.4735 Corr=0.0310
# [Epoch 190] L=60 step 1/1 | D_loss=-13.0790 GP=3.3486 D_real=20.2719 D_fake=3.8443 | G_loss=-3.4199 Corr=0.0335
# [Epoch 191] L=10 step 1/1 | D_loss=-4.1161 GP=0.2249 D_real=9.0576 D_fake=4.7166 | G_loss=-4.3660 Corr=0.0330
# [Epoch 191] L=20 step 1/1 | D_loss=-5.9719 GP=0.7526 D_real=11.2619 D_fake=4.5374 | G_loss=-4.2186 Corr=0.0304
# [Epoch 191] L=30 step 1/1 | D_loss=-8.1673 GP=1.8253 D_real=14.1576 D_fake=4.1650 | G_loss=-3.7630 Corr=0.0333
# [Epoch 191] L=40 step 1/1 | D_loss=-9.6339 GP=2.1123 D_real=15.4290 D_fake=3.6829 | G_loss=-3.4204 Corr=0.0331
# [Epoch 191] L=50 step 1/1 | D_loss=-11.3214 GP=2.7502 D_real=17.6654 D_fake=3.5938 | G_loss=-3.2694 Corr=0.0340
# [Epoch 191] L=60 step 1/1 | D_loss=-12.4607 GP=2.9267 D_real=19.0008 D_fake=3.6134 | G_loss=-3.4164 Corr=0.0334
# [Epoch 192] L=10 step 1/1 | D_loss=-4.0210 GP=0.5335 D_real=9.2350 D_fake=4.6805 | G_loss=-4.3252 Corr=0.0325
# [Epoch 192] L=20 step 1/1 | D_loss=-6.2461 GP=0.6513 D_real=11.4386 D_fake=4.5412 | G_loss=-4.2323 Corr=0.0324
# [Epoch 192] L=30 step 1/1 | D_loss=-7.7674 GP=1.7694 D_real=13.9336 D_fake=4.3967 | G_loss=-4.0832 Corr=0.0343
# [Epoch 192] L=40 step 1/1 | D_loss=-9.5739 GP=1.8782 D_real=15.8518 D_fake=4.3998 | G_loss=-4.1217 Corr=0.0292
# [Epoch 192] L=50 step 1/1 | D_loss=-10.8227 GP=2.9469 D_real=17.8221 D_fake=4.0526 | G_loss=-3.8038 Corr=0.0256
# [Epoch 192] L=60 step 1/1 | D_loss=-12.5159 GP=2.7771 D_real=19.2430 D_fake=3.9500 | G_loss=-3.4875 Corr=0.0305
# [Epoch 193] L=10 step 1/1 | D_loss=-4.1698 GP=0.5608 D_real=9.5277 D_fake=4.7971 | G_loss=-4.4195 Corr=0.0349
# [Epoch 193] L=20 step 1/1 | D_loss=-6.2065 GP=0.6050 D_real=11.3949 D_fake=4.5833 | G_loss=-4.2086 Corr=0.0287
# [Epoch 193] L=30 step 1/1 | D_loss=-7.9104 GP=1.7424 D_real=13.9752 D_fake=4.3224 | G_loss=-4.0708 Corr=0.0270
# [Epoch 193] L=40 step 1/1 | D_loss=-9.6790 GP=1.9544 D_real=16.0521 D_fake=4.4187 | G_loss=-4.1767 Corr=0.0274
# [Epoch 193] L=50 step 1/1 | D_loss=-10.9535 GP=2.8517 D_real=17.7515 D_fake=3.9463 | G_loss=-3.6603 Corr=0.0256
# [Epoch 193] L=60 step 1/1 | D_loss=-12.4632 GP=2.6539 D_real=18.8492 D_fake=3.7321 | G_loss=-3.5359 Corr=0.0266
# [Epoch 194] L=10 step 1/1 | D_loss=-3.9455 GP=0.3730 D_real=8.8887 D_fake=4.5702 | G_loss=-4.1702 Corr=0.0358
# [Epoch 194] L=20 step 1/1 | D_loss=-6.0831 GP=0.6153 D_real=10.8525 D_fake=4.1541 | G_loss=-3.8573 Corr=0.0261
# [Epoch 194] L=30 step 1/1 | D_loss=-8.0121 GP=1.6385 D_real=13.6699 D_fake=4.0193 | G_loss=-3.7731 Corr=0.0299
# [Epoch 194] L=40 step 1/1 | D_loss=-9.4183 GP=1.7879 D_real=15.1610 D_fake=3.9548 | G_loss=-3.6434 Corr=0.0292
# [Epoch 194] L=50 step 1/1 | D_loss=-10.5961 GP=2.8509 D_real=16.9614 D_fake=3.5145 | G_loss=-3.1262 Corr=0.0343
# [Epoch 194] L=60 step 1/1 | D_loss=-12.2984 GP=2.7767 D_real=18.8760 D_fake=3.8009 | G_loss=-3.4686 Corr=0.0386
# [Epoch 195] L=10 step 1/1 | D_loss=-4.0054 GP=0.5193 D_real=9.6420 D_fake=5.1173 | G_loss=-4.8608 Corr=0.0285
# [Epoch 195] L=20 step 1/1 | D_loss=-6.0396 GP=0.5773 D_real=11.8092 D_fake=5.1923 | G_loss=-4.9174 Corr=0.0243
# [Epoch 195] L=30 step 1/1 | D_loss=-7.7602 GP=1.7357 D_real=14.3341 D_fake=4.8381 | G_loss=-4.3368 Corr=0.0343
# [Epoch 195] L=40 step 1/1 | D_loss=-9.6525 GP=2.4617 D_real=16.2856 D_fake=4.1714 | G_loss=-3.7787 Corr=0.0403
# [Epoch 195] L=50 step 1/1 | D_loss=-10.9516 GP=2.9951 D_real=17.4559 D_fake=3.5092 | G_loss=-3.2305 Corr=0.0346
# [Epoch 195] L=60 step 1/1 | D_loss=-12.1283 GP=2.8240 D_real=18.6827 D_fake=3.7303 | G_loss=-3.4257 Corr=0.0344
# [Epoch 196] L=10 step 1/1 | D_loss=-4.0693 GP=0.3940 D_real=9.2171 D_fake=4.7538 | G_loss=-4.3865 Corr=0.0344
# [Epoch 196] L=20 step 1/1 | D_loss=-6.1261 GP=0.7249 D_real=11.3896 D_fake=4.5386 | G_loss=-4.1490 Corr=0.0318
# [Epoch 196] L=30 step 1/1 | D_loss=-7.9531 GP=1.7277 D_real=13.8185 D_fake=4.1376 | G_loss=-3.7688 Corr=0.0326
# [Epoch 196] L=40 step 1/1 | D_loss=-9.2046 GP=1.9677 D_real=14.9474 D_fake=3.7751 | G_loss=-3.4339 Corr=0.0316
# [Epoch 196] L=50 step 1/1 | D_loss=-11.2902 GP=2.8201 D_real=17.5854 D_fake=3.4752 | G_loss=-3.2819 Corr=0.0252
# [Epoch 196] L=60 step 1/1 | D_loss=-12.4046 GP=3.3094 D_real=19.2197 D_fake=3.5057 | G_loss=-3.2738 Corr=0.0231
# [Epoch 197] L=10 step 1/1 | D_loss=-4.0131 GP=0.4640 D_real=9.1558 D_fake=4.6787 | G_loss=-4.3404 Corr=0.0319
# [Epoch 197] L=20 step 1/1 | D_loss=-6.0942 GP=0.5893 D_real=11.2158 D_fake=4.5323 | G_loss=-4.2034 Corr=0.0298
# [Epoch 197] L=30 step 1/1 | D_loss=-7.9461 GP=1.3258 D_real=13.4954 D_fake=4.2235 | G_loss=-3.9228 Corr=0.0293
# [Epoch 197] L=40 step 1/1 | D_loss=-9.4669 GP=2.3696 D_real=15.8335 D_fake=3.9970 | G_loss=-3.7033 Corr=0.0313
# [Epoch 197] L=50 step 1/1 | D_loss=-10.7875 GP=2.4958 D_real=17.2124 D_fake=3.9291 | G_loss=-3.5683 Corr=0.0326
# [Epoch 197] L=60 step 1/1 | D_loss=-11.9859 GP=3.0969 D_real=18.2943 D_fake=3.2115 | G_loss=-2.7291 Corr=0.0356
# [Epoch 198] L=10 step 1/1 | D_loss=-4.0133 GP=0.3757 D_real=8.6617 D_fake=4.2727 | G_loss=-3.8899 Corr=0.0362
# [Epoch 198] L=20 step 1/1 | D_loss=-5.7343 GP=0.4151 D_real=10.3151 D_fake=4.1656 | G_loss=-3.7781 Corr=0.0327
# [Epoch 198] L=30 step 1/1 | D_loss=-7.6986 GP=1.5919 D_real=13.0655 D_fake=3.7751 | G_loss=-3.4925 Corr=0.0353
# [Epoch 198] L=40 step 1/1 | D_loss=-9.2793 GP=1.9324 D_real=15.5035 D_fake=4.2918 | G_loss=-4.0810 Corr=0.0350
# [Epoch 198] L=50 step 1/1 | D_loss=-10.6315 GP=2.6176 D_real=17.7070 D_fake=4.4579 | G_loss=-4.0541 Corr=0.0344
# [Epoch 198] L=60 step 1/1 | D_loss=-11.9635 GP=2.6531 D_real=18.3524 D_fake=3.7358 | G_loss=-3.4245 Corr=0.0298
# [Epoch 199] L=10 step 1/1 | D_loss=-3.8431 GP=0.5758 D_real=9.4862 D_fake=5.0674 | G_loss=-4.7629 Corr=0.0259
# [Epoch 199] L=20 step 1/1 | D_loss=-5.8928 GP=0.7003 D_real=11.4425 D_fake=4.8494 | G_loss=-4.5648 Corr=0.0210
# [Epoch 199] L=30 step 1/1 | D_loss=-7.7120 GP=1.7160 D_real=13.8875 D_fake=4.4595 | G_loss=-4.1887 Corr=0.0293
# [Epoch 199] L=40 step 1/1 | D_loss=-9.2309 GP=2.4314 D_real=15.9103 D_fake=4.2479 | G_loss=-3.7966 Corr=0.0371
# [Epoch 199] L=50 step 1/1 | D_loss=-11.1764 GP=2.7621 D_real=17.6471 D_fake=3.7086 | G_loss=-3.4049 Corr=0.0354
# [Epoch 199] L=60 step 1/1 | D_loss=-12.2975 GP=3.1944 D_real=19.2421 D_fake=3.7502 | G_loss=-3.4150 Corr=0.0228
# [Epoch 200] L=10 step 1/1 | D_loss=-4.0568 GP=0.4443 D_real=9.2830 D_fake=4.7820 | G_loss=-4.4666 Corr=0.0340
# [Epoch 200] L=20 step 1/1 | D_loss=-5.7832 GP=0.3913 D_real=10.6746 D_fake=4.5001 | G_loss=-4.1319 Corr=0.0279
# [Epoch 200] L=30 step 1/1 | D_loss=-8.0080 GP=1.7181 D_real=13.6755 D_fake=3.9494 | G_loss=-3.6449 Corr=0.0325
# [Epoch 200] L=40 step 1/1 | D_loss=-9.1743 GP=1.9926 D_real=15.0456 D_fake=3.8787 | G_loss=-3.5840 Corr=0.0319
# [Epoch 200] L=50 step 1/1 | D_loss=-10.9061 GP=2.0708 D_real=16.6281 D_fake=3.6513 | G_loss=-3.2670 Corr=0.0333
# [Epoch 200] L=60 step 1/1 | D_loss=-12.0762 GP=3.0191 D_real=18.1923 D_fake=3.0970 | G_loss=-2.6926 Corr=0.0364

# %%
seed_all()

loader60 = only10_60[60]
Real_Seqs = collect_loader_sequences(loader60)
F = int(max(dtype["index_end"]))
Generated_Len = 60

Real_Data = sample_and_flatten(Real_Seqs, seq_len=Generated_Len, max_rows=10_000)
Fake_Data = wgan_gp.generate_data(Generated_Len, num_samples=Real_Seqs.size(0))
Fake_Data = Fake_Data[: Real_Data.size(0) // Generated_Len].reshape(-1, F)

with torch.no_grad():
    Real_Data = Execute_C007(Real_Data, dtype_schema=dtype, transform_params=art_transformation_params)
    Fake_Data = Execute_C007(Fake_Data, dtype_schema=dtype, transform_params=art_transformation_params)

Real_Data = to_cpu(Real_Data)
Fake_Data = to_cpu(Fake_Data)

Replace_Names, _ = Execute_C008(dtype)
n_features = len(Replace_Names)
ncols = 4
nrows = (n_features + ncols - 1) // ncols
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(45, 10 * nrows))
axes = np.atleast_2d(axes)

for k, name in enumerate(Replace_Names):
    i, j = divmod(k, ncols)
    cur_ax = axes[i, j]
    cur_fake = Fake_Data[:, k].numpy()
    cur_real = Real_Data[:, k].numpy()

    if name in REAL_NAMES:
        df_all = make_df(name, cur_real, cur_fake, categorical=False)
        sns.kdeplot(data=df_all, x=name, hue="Type", fill=True, ax=cur_ax, legend=(k == 0), common_norm=False)
        if cur_ax.legend_:
            cur_ax.legend_.set_title(None)
        cur_ax.yaxis.set_visible(False)
        cur_ax.set(xlabel=name)
    else:
        df_all = make_df(name, cur_real, cur_fake, categorical=True)
        sns.histplot(
            data=df_all, x=name, hue="Type", multiple="dodge", stat="probability",
            shrink=0.8, alpha=0.3, linewidth=0, ax=cur_ax, legend=False, discrete=True
        )
        cur_ax.tick_params(axis="x", rotation=-45 if name in CATEGORY_LABELS and len(CATEGORY_LABELS[name]) > 3 else 0)
        cur_ax.yaxis.set_visible(False)
        cur_ax.set(xlabel=name)

for k in range(n_features, nrows * ncols):
    i, j = divmod(k, ncols)
    axes[i, j].axis("off")

plt.tight_layout(pad=1.0)
plt.show()

# %%
torch.save(wgan_gp.G.state_dict(), "YDZ002_G_StateDict_Epoch200")
torch.save(wgan_gp.D.state_dict(), "YDZ002_D_StateDict_Epoch200")
